# %%
#conv Neural Network
# tensorboard --logdir=/home/ncc/notebook/learn/tensorboard/log
"""
created by kim Seong jung

"""
import numpy as np 
import tensorflow as tf
import re
import random
import math
import time
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %% [markdown]
# # Load Image

# %% [markdown]
# # load Training , Validation , Test

# %%
in_ch =3
n_classes=10
img_row=32
img_col=32

# %%
with tf.device('/gpu:0'):
    def next_batch(batch_size , image , label):

        a=np.random.randint(np.shape(image)[0] -batch_size)
        batch_x = image[a:a+batch_size,:]
        batch_y= label[a:a+batch_size,:]
        return batch_x, batch_y

# %% [markdown]
# # define Variable , and placeholder

# %%
x_= tf.placeholder("float",shape=[None,img_row , img_col , in_ch],  name = 'x-input')
y_= tf.placeholder("float",shape=[None , n_classes] , name = 'y-input')
keep_prob = tf.placeholder("float")
x_image= tf.reshape(x_,[-1,img_row,img_col,in_ch])

# %%
"""def weight_variable(name,shape):
    #initial = tf.truncated_normal(shape , stddev=0.1)
    initial = tf.get_variable(name,shape=shape , initializer = tf.contrib.layers.xavier_initializer())
    return tf.Variable(initial)"""

def bias_variable(shape):
    initial = tf.constant(0.1 , shape=shape)
    return tf.Variable(initial)

# %%
"""def weight_variable(name,shape):
    #initial = tf.truncated_normal(shape , stddev=0.1)
    initial = tf.get_variable(name,shape=shape , initializer = tf.contrib.layers.xavier_initializer())
    return tf.Variable(initial)"""

def bias_variable(shape):
    initial = tf.constant(0.1 , shape=shape)
    return tf.Variable(initial)
def conv2d(x,w,strides_):
    return tf.nn.conv2d(x,w, strides = strides_, padding='SAME')

def max_pool(x , ksize , strides , padding='SAME'):
    return tf.nn.max_pool(x ,ksize , strides , padding )
def make_weights_biases(layer_name , w_name , ksize ,device_name,initializer='xavier'):
    if len(ksize)==4: # convolution filter shape [batch , row , col , color_ch]
        out_ch=ksize[3]
    elif len(ksize)==2: #fully connected layer shape [in_ch , output_ch]
        out_ch=ksize[1]
    with tf.device(device_name):
        with tf.variable_scope(layer_name) as scope:
            try:
                w_conv = tf.get_variable(w_name, ksize , initializer = tf.contrib.layers.xavier_initializer())
            except:
                scope.reuse_variables()
                w_conv = tf.get_variable(w_name, ksize , initializer = tf.contrib.layers.xavier_initializer())
        
        with tf.variable_scope(layer_name) as scope:
            try:
                b_conv = bias_variable([out_ch])
            except:
                scope.reuse_variables()
                b_conv = bias_variable([out_ch])
    return w_conv , b_conv

# %%
def STEM_A(x , device_):
    with tf.device(device_):
        in_ch=x.get_shape()[3]
        out_ch1=32 ; out_ch2=32;out_ch3=64;out_ch4=96;

        c_ksize1=[3,3,in_ch , out_ch1]
        c_ksize2=[3,3,out_ch1 , out_ch2]
        c_ksize3=[3,3,out_ch2 , out_ch3]
        c_ksize4=[3,3,out_ch3 , out_ch4]
        w_conv1 , b_conv1 =make_weights_biases('STEM_A' , 'W1' , c_ksize1 ,device_name = device_)
        w_conv2 , b_conv2= make_weights_biases('STEM_A' , 'W2' , c_ksize2 ,device_name = device_)
        w_conv3 , b_conv3= make_weights_biases('STEM_A' , 'W3' , c_ksize3 ,device_name = device_)
        w_conv4 , b_conv4= make_weights_biases('STEM_A' , 'W4' , c_ksize4 ,device_name = device_)

        c_strides1=[1,2,2,1]
        c_strides2=[1,1,1,1]
        c_strides3=[1,1,1,1]
        c_strides4=[1,2,2,1]

        c_pooling1='VALID'
        c_pooling2='VALID'
        c_pooling3='SAME'
        c_pooling4='VALID'

        b_p_ksize4=[1,3,3,1]
        b_p_strides4=[1,2,2,1]
        b_p_padding4 ='VALID'



        layer1=tf.nn.conv2d(    x ,      w_conv1, c_strides1, c_pooling1  )+b_conv1
        layer1=tf.nn.relu(layer1)
        layer2=tf.nn.conv2d(    layer1 , w_conv2, c_strides2, c_pooling2  )+b_conv2
        layer2=tf.nn.relu(layer2)
        layer3=tf.nn.conv2d(    layer2 , w_conv3, c_strides3, c_pooling3  )+b_conv3
        layer3=tf.nn.relu(layer3)
        layer4=tf.nn.conv2d(    layer3 , w_conv4, c_strides4, c_pooling4  )+b_conv4
        layer4=tf.nn.relu(layer4)


        b_layer4=tf.nn.max_pool(layer3 , b_p_ksize4, b_p_strides4, b_p_padding4 ) #b is branch
        b_layer4=tf.nn.relu(b_layer4)
        print layer1
        print layer2
        print layer3
        print layer4
        print b_layer4


        concat_layer=tf.concat(3 , [layer4 , b_layer4])
        ret_layer=concat_layer
        print concat_layer
        return ret_layer

# %%
def STEM_B( x , device_):
    with tf.device(device_):
        in_ch=x.get_shape()[3]


        #########################################################################
        out_ch1=64 ; out_ch2=64;out_ch3=64;out_ch4=96;
        ##############################right side##################################
        c_ksize1=[1,1,in_ch , out_ch1]
        c_ksize2=[7,1,out_ch1 , out_ch2]
        c_ksize3=[1,7,out_ch2 , out_ch3]
        c_ksize4=[3,3,out_ch3 , out_ch4]

        w_conv1 , b_conv1 =make_weights_biases('STEM_B' , 'W1' , c_ksize1 ,device_name = device_)
        w_conv2 , b_conv2= make_weights_biases('STEM_B' , 'W2' , c_ksize2 ,device_name = device_)
        w_conv3 , b_conv3= make_weights_biases('STEM_B' , 'W3' , c_ksize3 ,device_name = device_)
        w_conv4 , b_conv4= make_weights_biases('STEM_B' , 'W4' , c_ksize4 ,device_name = device_)

        c_strides1=[1,1,1,1]
        c_strides2=[1,1,1,1]
        c_strides3=[1,1,1,1]
        c_strides4=[1,1,1,1]

        c_pooling1='SAME'
        c_pooling2='SAME'
        c_pooling3='SAME'
        c_pooling4='VALID'
        
        layer1 = tf.nn.conv2d(x ,      w_conv1 , c_strides1 , c_pooling1)+b_conv1
        layer1 = tf.nn.relu(layer1)
        layer2 = tf.nn.conv2d(layer1 , w_conv2 , c_strides2 , c_pooling2)+b_conv2
        layer2 = tf.nn.relu(layer2)
        layer3 = tf.nn.conv2d(layer2 , w_conv3 , c_strides3 , c_pooling3)+b_conv3
        layer3 = tf.nn.relu(layer3)
        layer4 = tf.nn.conv2d(layer3 , w_conv4 , c_strides4 , c_pooling4)+b_conv4
        layer4 = tf.nn.relu(layer4)

        ##############################left side##################################
        b_out_ch1=64 ; b_out_ch2=96;    
        #########################################################################
        b_c_ksize1=[1,1,in_ch , b_out_ch1]
        b_c_ksize2=[3,3,b_out_ch1 , b_out_ch2]
        b_w_conv1 , b_b_conv1 =make_weights_biases('STEM_B' , 'b_W1' , b_c_ksize1 ,device_name = device_)
        b_w_conv2 , b_b_conv2= make_weights_biases('STEM_B' , 'b_W2' , b_c_ksize2 ,device_name = device_)

        b_c_strides1=[1,1,1,1]
        b_c_strides2=[1,1,1,1]

        b_c_pooling1='SAME'
        b_c_pooling2='VALID'
        
        b_layer1 =tf.nn.conv2d(    x ,      b_w_conv1, b_c_strides1, b_c_pooling1  ) + b_b_conv1
        b_layer1 = tf.nn.relu(layer1)
        b_layer2=tf.nn.conv2d(  b_layer1 , b_w_conv2, b_c_strides2, b_c_pooling2  ) + b_b_conv2

        ##############################concatenate layers###########################
        concat_layer=tf.concat(3 , [layer4 , b_layer2])
        ret_layer=concat_layer
    return ret_layer

# %%
def STEM_C( x , device_ ):
    with tf.device(device_):
        in_ch=x.get_shape()[3]
        #########################################################################

        out_ch = 192


        c_ksize=[3,3,in_ch,out_ch]
        w_conv , b_conv =make_weights_biases('STEM_C' , 'W1' , c_ksize ,device_name = device_)
        c_strides=[1,1,1,1]
        c_pooling='SAME'

        layer = tf.nn.conv2d(x , w_conv   , c_strides   , c_pooling)+b_conv
        layer = tf.nn.relu(layer)
        
        #########################################################################
        
        b_p_ksize=[1,2,2,1]
        b_p_strides=[1,1,1,1]
        b_p_pooling='SAME'

        b_layer = tf.nn.max_pool(x , b_p_ksize , b_p_strides , b_p_pooling)
        b_layer = tf.nn.relu(b_layer)
        #########################################################################

        print layer
        print b_layer

        concat_layer=tf.concat(3,[layer , b_layer])
        ret_layer = concat_layer
    return ret_layer

# %%
def FLAT(x):
    
    row=int(x.get_shape()[1])
    col=int(x.get_shape()[2])
    ch=int(x.get_shape()[3])
    
    res_x = tf.reshape(x , shape=[-1,row*col*ch])
    return res_x
    #connect fully connected layer

# %%
def FC_A(x , n_classes , device_ ,dropout_rate):
    with tf.device(device_):
    
        fully_ch1=1024; fully_ch2=1024

        fc_ksize1=[x.get_shape()[1],fully_ch1]
        fc_ksize2=[fully_ch1,fully_ch2]

        w_fc1 ,b_fc1 = make_weights_biases('fc1' , 'fc_W1' , fc_ksize1 ,  device_)
        w_fc2 ,b_fc2 = make_weights_biases('fc2' , 'fc_W2' , fc_ksize2 ,  device_)

        h_fc1=tf.matmul(x, w_fc1 )+b_fc1
        h_fc1=tf.nn.dropout(h_fc1 , dropout_rate)
        h_fc2=tf.matmul(h_fc1 , w_fc2 )+b_fc2
        h_fc2=tf.nn.dropout(h_fc2 , dropout_rate)
        end_fc=h_fc2

        end_ksize=[end_fc.get_shape()[1] , n_classes]   
        w_end ,b_end = make_weights_biases('fc_end' , 'fc_end_W' , end_ksize ,  device_)
        y_conv = tf.matmul(end_fc , w_end)+b_end

        print w_fc1.get_shape()
    return y_conv

# %%
def FC_B(x , n_classes , device_ ):
    with tf.device(device_):

        end_ksize=[x.get_shape()[1] , n_classes]   
        w_end ,b_end = make_weights_biases('fc_end' , 'fc_end_W' , end_ksize ,  device_)
        y_conv = tf.matmul(x , w_end)+b_end

   
    return y_conv

# %%
def INCEPTION_MODULE_A(x , device_ , layer_name = 'INCEPTION_MODULE_A'):

    """
    input X shape is [n_batch , row , col, out_ch]
    35 x 35 grid
    """

    #################################################################################
    in_ch=x.get_shape()[3]
    print x.get_shape()
    out_ch1=64 ; out_ch2= 96;
    c_ksize1 = [1 , 1 ,in_ch , out_ch1 ]
    c_ksize2 = [3 , 3 ,out_ch1 , out_ch2 ]
    w_conv1 , b_conv1 = make_weights_biases (layer_name , 'W1' , c_ksize1 ,device_)
    w_conv2 , b_conv2 = make_weights_biases(layer_name ,'W2' , c_ksize2 ,device_)

    c_strides1=[1,1,1,1]
    c_strides2=[1,1,1,1]
    
    c_pooling1='SAME'
    c_pooling2='SAME'
    layer1 = tf.nn.conv2d(x , w_conv1 , c_strides1 ,c_pooling1 )
    layer2 = tf.nn.conv2d(layer1 , w_conv2 , c_strides2 ,c_pooling2 )

    #################################################################################                     

    b1_p_ksize   =[1,2,2,1]
    b1_p_strides =[1,1,1,1]
    b1_p_pooling='SAME'


    b1_out_ch = 96;
    b1_c_ksize  =[1,1, in_ch , b1_out_ch]
    b1_c_strides=[1,1,1,1]
    b1_c_pooling ='SAME'

    b1_w_conv , b1_b_conv =make_weights_biases(layer_name,'b1_W',b1_c_ksize , device_)


    b1_layer1=tf.nn.avg_pool(x, b1_p_ksize , b1_p_strides,b1_p_pooling )
    b1_layer1=tf.nn.relu(b1_layer1)
    b1_layer2=tf.nn.conv2d(b1_layer1 , b1_w_conv , b1_c_strides , b1_c_pooling)+b1_b_conv
    b1_layer2=tf.nn.relu(b1_layer2)

    #################################################################################                     

    b2_out_ch=96
    b2_c_ksize = [1,1,in_ch , b2_out_ch ]
    b2_w_conv , b2_b_conv = make_weights_biases(layer_name,'b2_W',b2_c_ksize , device_)
    b2_c_strides=[1,1,1,1]
    b2_c_pooling='SAME'

    b2_layer = tf.nn.conv2d( x, b2_w_conv , b2_c_strides ,b2_c_pooling ) +b2_b_conv 
    b2_layer = tf.nn.relu(b2_layer)



    #################################################################################                     


    b3_out_ch1=64;b3_out_ch2=96;b3_out_ch3=96;
    b3_c_ksize1 =[1,1,in_ch , b3_out_ch1]
    b3_c_ksize2 =[3,3,b3_out_ch1 , b3_out_ch2]
    b3_c_ksize3 =[3,3,b3_out_ch2 , b3_out_ch3]
    b3_w_conv1 , b3_b_conv1 = make_weights_biases(layer_name,'b3_W1',b3_c_ksize1 , device_)
    b3_w_conv2 , b3_b_conv2 = make_weights_biases(layer_name,'b3_W2',b3_c_ksize2 , device_)
    b3_w_conv3 , b3_b_conv3 = make_weights_biases(layer_name,'b3_W3',b3_c_ksize3 , device_)
    b3_c_strides1=[1,1,1,1]
    b3_c_strides2=[1,1,1,1]
    b3_c_strides3=[1,1,1,1]
    b3_c_pooling1='SAME'
    b3_c_pooling2='SAME'
    b3_c_pooling3='SAME'

    b3_layer1 = tf.nn.conv2d(x , b3_w_conv1 , b3_c_strides1 ,b3_c_pooling1)+b3_b_conv1 
    b3_layer1 = tf.nn.relu(b3_layer1)
    b3_layer2 = tf.nn.conv2d(b3_layer1 , b3_w_conv2 , b3_c_strides2 ,b3_c_pooling2)+b3_b_conv2 
    b3_layer2 = tf.nn.relu(b3_layer2)
    b3_layer3 = tf.nn.conv2d(b3_layer2 , b3_w_conv3 , b3_c_strides3 ,b3_c_pooling3)+b3_b_conv3 
    b3_layer3 = tf.nn.relu(b3_layer3)

    #################################################################################                     
    concat_A=tf.concat(3,[layer2 , b1_layer2])
    concat_B=tf.concat(3,[concat_A , b2_layer])
    concat_C=tf.concat(3,[concat_B , b3_layer3])

    return concat_C

    #################################################################################

# %%
def INCEPTION_MODULE_B(x , device ,layer_name='INCEPTION_MODULE_B'):

    """
    for 17 X 17 grid 
    """
    in_ch =x.get_shape()[3]
    out_ch1 =192 ; out_ch2=224; out_ch3 =256
    c_ksize1 = [1,1, in_ch  ,out_ch1]
    c_ksize2 = [1,7, out_ch1,out_ch2]
    c_ksize3 = [7,1, out_ch2,out_ch3]

    w_conv1 , b_conv1 =make_weights_biases( layer_name,'W1' ,  c_ksize1 , device)
    w_conv2 , b_conv2 =make_weights_biases( layer_name ,'W2' ,  c_ksize2 , device)
    w_conv3 , b_conv3 =make_weights_biases( layer_name ,'W3' ,  c_ksize3 , device)
    
    c_strides1 =[1,1,1,1]
    c_strides2 =[1,1,1,1]
    c_strides3 =[1,1,1,1]
    
    c_pooling1 ='SAME'
    c_pooling2 ='SAME'
    c_pooling3 ='SAME'


    layer1 = tf.nn.conv2d(x, w_conv1,c_strides1 , c_pooling1 ) +b_conv1
    layer1 = tf.nn.relu(layer1)
    layer2 = tf.nn.conv2d(layer1, w_conv2,c_strides2 , c_pooling2 ) +b_conv2
    layer2 = tf.nn.relu(layer2)
    layer3 = tf.nn.conv2d(layer2, w_conv3,c_strides3 , c_pooling3 ) +b_conv3
    layer3 = tf.nn.relu(layer3)


    ################################################################################# 


    b1_p_ksize=[1,2,2,1]
    b1_p_strides=[1,1,1,1]
    b1_p_pooling ='SAME'

    b1_out_ch = 128
    b1_c_ksize=[1,1,in_ch,b1_out_ch]
    b1_w_conv , b1_b_conv = make_weights_biases(layer_name,'b1_W1',b1_c_ksize, device )
    b1_c_strides=[1,1,1,1]
    b1_c_pooling='SAME'


    b1_layer1=tf.nn.avg_pool(x , b1_p_ksize , b1_p_strides , b1_p_pooling )
    b1_layer1=tf.nn.relu(b1_layer1)
    b1_layer2 =tf.nn.conv2d(b1_layer1 ,b1_w_conv , b1_c_strides, b1_c_pooling )+b1_b_conv 
    b1_layer2 =tf.nn.relu(b1_layer2)

    ################################################################################# 
    b2_out_ch=384
    b2_c_ksize=[1,1,in_ch,b2_out_ch]
    b2_w_conv , b2_b_conv =make_weights_biases(layer_name,'b2_W1' ,b2_c_ksize , device)
    b2_c_strides=[1,1,1,1]
    b2_c_pooling='SAME'
    b2_layer = tf.nn.conv2d(x,b2_w_conv , b2_c_strides , b2_c_pooling)+b2_b_conv
    b2_layer = tf.nn.relu(b2_layer)
    ################################################################################# 


    b3_out_ch1=192; b3_out_ch2 =192; b3_out_ch3=224 ; b3_out_ch4=224 ; b3_out_ch5 =256
    b3_c_ksize1=[1,1,in_ch,b3_out_ch1]
    b3_c_ksize2=[1,7,b3_out_ch1 , b3_out_ch2]
    b3_c_ksize3=[7,1,b3_out_ch2 , b3_out_ch3]
    b3_c_ksize4=[1,7,b3_out_ch3 , b3_out_ch4]
    b3_c_ksize5=[7,1,b3_out_ch4 , b3_out_ch5]

    b3_w_conv1 , b3_b_conv1=make_weights_biases(layer_name,'b3_W1',b3_c_ksize1, device)
    b3_w_conv2 , b3_b_conv2=make_weights_biases(layer_name,'b3_W2',b3_c_ksize2, device)
    b3_w_conv3 , b3_b_conv3=make_weights_biases(layer_name,'b3_W3',b3_c_ksize3, device)
    b3_w_conv4 , b3_b_conv4=make_weights_biases(layer_name,'b3_W4',b3_c_ksize4, device)
    b3_w_conv5 , b3_b_conv5=make_weights_biases(layer_name,'b3_W5',b3_c_ksize5, device)


    b3_layer1 = tf.nn.conv2d(x,b3_w_conv1 , b2_c_strides , b2_c_pooling)+b3_b_conv1
    b3_layer1 = tf.nn.relu(b3_layer1)
    b3_layer2 = tf.nn.conv2d(b3_layer1,b3_w_conv2 , b2_c_strides , b2_c_pooling)+b3_b_conv2
    b3_layer2 = tf.nn.relu(b3_layer2)
    b3_layer3 = tf.nn.conv2d(b3_layer2,b3_w_conv3 , b2_c_strides , b2_c_pooling)+b3_b_conv3
    b3_layer3 = tf.nn.relu(b3_layer3)
    b3_layer4 = tf.nn.conv2d(b3_layer3,b3_w_conv4 , b2_c_strides , b2_c_pooling)+b3_b_conv4
    b3_layer4 = tf.nn.relu(b3_layer4)
    b3_layer5 = tf.nn.conv2d(b3_layer4,b3_w_conv5 , b2_c_strides , b2_c_pooling)+b3_b_conv5
    b3_layer5 = tf.nn.relu(b3_layer5)

    ################################################################################# 


    layerA=tf.concat(3, [layer3 , b1_layer2] )
    layerB=tf.concat(3, [layerA , b2_layer] )
    layerC=tf.concat(3, [layerB , b3_layer5] )

    print layerC
    return layerC

# %%
def INCEPTION_MODULE_C(x , device , layer_name='INCEPTION_MODULE_C'):

    """
    for 8 X 8 grid modules
    """
    print x.get_shape()
    in_ch=x.get_shape()[3]
    
    out_ch1 = 384 ; out_ch2_a =256 ;out_ch2_b = 256
    c_ksize1 = [1,1,in_ch , out_ch1]
    c_ksize2_a = [1,3,out_ch1 , out_ch2_a]
    c_ksize2_b = [3,1,out_ch1 , out_ch2_b]
    w_conv1 ,b_conv1=make_weights_biases(layer_name,'W1', c_ksize1 ,device)
    w_conv2_a ,b_conv2_a=make_weights_biases(layer_name,'W2_a', c_ksize2_a ,device)
    w_conv2_b ,b_conv2_b=make_weights_biases(layer_name,'W2_b', c_ksize2_b ,device)
    c_strides1=[1,1,1,1]
    c_strides2_a=[1,1,1,1]
    c_strides2_b=[1,1,1,1]
    c_pooling1='SAME'
    c_pooling2_a='SAME'
    c_pooling2_b='SAME'

    layer1 = tf.nn.conv2d(x, w_conv1 ,c_strides1 ,c_pooling1)+b_conv1
    layer1=tf.nn.relu(layer1)
    layer2_a = tf.nn.conv2d(layer1,  w_conv2_a ,c_strides2_a ,c_pooling2_a )+b_conv2_a
    layer2_a = tf.nn.relu(layer2_a)
    layer2_b = tf.nn.conv2d(layer1  , w_conv2_a ,c_strides2_a ,c_pooling2_b)+b_conv2_b
    layer2_b = tf.nn.relu(layer2_b)
    ################################################################################# 


    b1_p_ksize=[1,2,2,1]
    b1_p_strides=[1,1,1,1]
    b1_p_pooling='SAME'

    b1_out_ch =256
    b1_c_ksize=[1,1,in_ch , b1_out_ch]
    b1_w_conv , b1_b_conv= make_weights_biases(layer_name , 'b1_W1' , b1_c_ksize , device)
    b1_c_pooling = 'SAME';b1_c_strides = [1,1,1,1];
    
    b1_layer1 = tf.nn.avg_pool(x , b1_p_ksize , b1_p_strides , b1_p_pooling)
    b1_layer2 = tf.nn.conv2d(b1_layer1 , b1_w_conv , b1_c_strides  ,b1_c_pooling)+b1_b_conv
    b1_layer2 = tf.nn.relu(b1_layer2)
    ################################################################################# 
    b2_out_ch=256
    b2_c_ksize=[1,1,in_ch,b2_out_ch]
    b2_w_conv , b2_b_conv= make_weights_biases(layer_name , 'b2_W' , b2_c_ksize , device)
    b2_c_pooling = 'SAME';b2_c_strides=[1,1,1,1];
    b2_layer = tf.nn.conv2d(x , b2_w_conv , b2_c_strides  ,b2_c_pooling)+b2_b_conv
    b2_layer= tf.nn.relu(b2_layer)
   
    ################################################################################# 


    b3_out_ch1=384;b3_out_ch2=448;b3_out_ch3=512;b3_out_ch4_a=256;b3_out_ch4_b=256
    b3_c_ksize1 =[1,1,in_ch , b3_out_ch1]
    b3_c_ksize2 =[1,3,b3_out_ch1 , b3_out_ch2]
    b3_c_ksize3 =[3,1,b3_out_ch2 , b3_out_ch3]
    b3_c_ksize4_a =[3,1,b3_out_ch3 , b3_out_ch4_a]
    b3_c_ksize4_b =[1,3,b3_out_ch3, b3_out_ch4_b]

    b3_w_conv1 , b3_b_conv1 = make_weights_biases(layer_name,'b3_W1',b3_c_ksize1 , device)
    b3_w_conv2 , b3_b_conv2 = make_weights_biases(layer_name,'b3_W2',b3_c_ksize2 , device)
    b3_w_conv3 , b3_b_conv3 = make_weights_biases(layer_name,'b3_W3',b3_c_ksize3 , device)
    b3_w_conv4_a , b3_b_conv4_a = make_weights_biases(layer_name,'b3_W4_a',b3_c_ksize4_a , device)
    b3_w_conv4_b , b3_b_conv4_b = make_weights_biases(layer_name,'b3_W4_b',b3_c_ksize4_b , device)

    b3_c_strides1=[1,1,1,1]
    b3_c_strides2=[1,1,1,1]
    b3_c_strides3=[1,1,1,1]
    b3_c_strides4_a=[1,1,1,1]
    b3_c_strides4_b=[1,1,1,1]

    b3_c_pooling1='SAME'
    b3_c_pooling2='SAME'
    b3_c_pooling3='SAME'
    b3_c_pooling4_a='SAME'
    b3_c_pooling4_b='SAME'

    b3_laer1 = tf.nn.conv2d(x , b3_w_conv1 , b3_c_strides1 ,b3_c_pooling1)+b3_b_conv1 
    b3_layer1 = tf.nn.relu(b3_laer1)
    b3_layer2 = tf.nn.conv2d(b3_laer1 , b3_w_conv2 , b3_c_strides2 ,b3_c_pooling2)+b3_b_conv2 
    b3_layer2 = tf.nn.relu(b3_layer2)
    b3_layer3 = tf.nn.conv2d(b3_layer2 , b3_w_conv3 , b3_c_strides3 ,b3_c_pooling3)+b3_b_conv3 
    b3_layer3 = tf.nn.relu(b3_layer3)

    b3_layer4_a = tf.nn.conv2d(b3_layer3 , b3_w_conv4_a , b3_c_strides4_a ,b3_c_pooling4_a)+b3_b_conv4_a 
    b3_layer4_a = tf.nn.relu(b3_layer4_a)

    b3_layer4_b = tf.nn.conv2d(b3_layer3 , b3_w_conv4_b , b3_c_strides4_b ,b3_c_pooling4_b)+b3_b_conv4_b 
    b3_layer4_b = tf.nn.relu(b3_layer4_b)


    ################################################################################# 

    layerA = tf.concat(3 , [layer2_a, layer2_b])
    layerB = tf.concat(3 , [layerA  , b1_layer2])
    layerC = tf.concat(3 , [layerB  , b2_layer])
    layerD = tf.concat(3 , [layerC  , b3_layer4_a])
    layerE = tf.concat(3 , [layerD  , b3_layer4_b])

    return layerE

# %%
def INCEPTION_REDUCTION_A(x , device , layer_name = 'INCEPTION_REDUCTION_A'):
    ####################################################################################
   
    """
    usage:
    x shape =[ n_batch , row , col , ch] 
    """
    print x.get_shape()
    in_ch=x.get_shape()[3]
    out_ch = 384
    c_ksize= [3,3,in_ch , out_ch]
    w_conv , b_conv =make_weights_biases(layer_name,'W1',c_ksize,device)
    c_strides=[1,2,2,1]
    c_pooling='VALID'
    layer=tf.nn.conv2d(x,w_conv,c_strides , c_pooling)+b_conv
    layer=tf.nn.relu(layer)

    ####################################################################################
   
    b1_p_ksize=[1,3,3,1]
    b1_p_strides=[1,2,2,1]
    b1_p_pooling='VALID'
    b1_layer = tf.nn.max_pool(x,b1_p_ksize , b1_p_strides , b1_p_pooling)
    ####################################################################################
   
    b2_out_ch1 = 192; b2_out_ch2=288 ;b2_out_ch3 = 256;
    b2_c_ksize1=[1,1,in_ch,b2_out_ch1]
    b2_c_ksize2=[3,3,b2_out_ch1,b2_out_ch2]
    b2_c_ksize3=[3,3,b2_out_ch2,b2_out_ch3]
    b2_w_conv1 , b2_b_conv1 = make_weights_biases(layer_name ,'b2_W1' , b2_c_ksize1 , device)
    b2_w_conv2 , b2_b_conv2 = make_weights_biases(layer_name ,'b2_W2' , b2_c_ksize2 , device)
    b2_w_conv3 , b2_b_conv3 = make_weights_biases(layer_name ,'b2_W3' , b2_c_ksize3 , device)
    
    b2_c_strides1=[1,1,1,1]
    b2_c_strides2=[1,1,1,1]
    b2_c_strides3=[1,2,2,1]
    b2_c_pooling1='SAME'
    b2_c_pooling2='SAME'
    b2_c_pooling3='VALID'
    
    b2_layer1 = tf.nn.conv2d(x        , b2_w_conv1 ,b2_c_strides1 ,b2_c_pooling1)+b2_b_conv1
    b2_layer1 = tf.nn.relu(b2_layer1)
    b2_layer2 = tf.nn.conv2d(b2_layer1, b2_w_conv2 ,b2_c_strides2 ,b2_c_pooling2)+b2_b_conv2
    b2_layer2 = tf.nn.relu(b2_layer2)
    b2_layer3 = tf.nn.conv2d(b2_layer2, b2_w_conv3 ,b2_c_strides3 ,b2_c_pooling3)+b2_b_conv3
    b2_layer3 = tf.nn.relu(b2_layer3)
    
    print layer.get_shape()
    print b1_layer.get_shape()
    print b2_layer3.get_shape()
    ####################################################################################
   
    layerA=tf.concat(3 ,[layer ,b1_layer ])
    layerB=tf.concat(3 ,[layerA ,b2_layer3])
    
    
    
    return layerB

# %%
def INCEPTION_REDUCTION_B(x , device  , layer_name = 'INCEPTION_REDUCTION_B'):
    """
    
    """
    
    ####################################################################################
    in_ch=x.get_shape()[3]
    out_ch1=192 ; out_ch2=192;

    c_ksize1 =[1,1,in_ch , out_ch1]
    c_ksize2 =[3,3,out_ch1,out_ch2]
    w_conv1, b_conv1 = make_weights_biases(layer_name,'W1',c_ksize1,device)
    w_conv2, b_conv2 = make_weights_biases(layer_name,'W2',c_ksize2,device)
    
    c_strides1=[1,1,1,1]
    c_strides2=[1,2,2,1]
    
    c_pooling1='SAME'
    c_pooling2='VALID'
    
    layer1 = tf.nn.conv2d(x,w_conv1 , c_strides1, c_pooling1)
    layer2 = tf.nn.conv2d(layer1 , w_conv2 , c_strides2 , c_pooling2)    
    
    b1_p_ksize=[1,3,3,1]
    b1_p_strides=[1,2,2,1]
    b1_p_pooling='VALID'
    
    b1_layer1=tf.nn.max_pool(x ,b1_p_ksize , b1_p_strides , b1_p_pooling)
    
    ####################################################################################
    b2_out_ch1=256 ; b2_out_ch2 = 256 ; b2_out_ch3=320 ; b2_out_ch4=320;
    b2_p_ksize1 =[1,1,in_ch , b2_out_ch1]
    b2_p_ksize2 =[1,7,b2_out_ch1 , b2_out_ch2]
    b2_p_ksize3 =[7,1,b2_out_ch2 , b2_out_ch3]
    b2_p_ksize4 =[3,3,b2_out_ch3 , b2_out_ch4]
    
    b2_w_conv1, b2_b_conv1 = make_weights_biases(layer_name,'b2_W1' ,b2_c_ksize1,device)
    b2_w_conv2, b2_b_conv2 = make_weights_biases(layer_name,'b2_W2' ,b2_c_ksize2,device)
    b2_w_conv3, b2_b_conv3 = make_weights_biases(layer_name,'b2_W3' ,b2_c_ksize3,device)
    b2_w_conv4, b2_b_conv4 = make_weights_biases(layer_name,'b2_W4' ,b2_c_ksize4,device)
    
    b2_c_strides1=[1,1,1,1]
    b2_c_strides2=[1,1,1,1]
    b2_c_strides3=[1,1,1,1]
    b2_c_strides4=[1,1,1,1]
    
    b2_c_pooling1= 'SAME'
    b2_c_pooling2= 'SAME'
    b2_c_pooling3 = 'SAME'
    b2_c_pooling4 = 'VALID'
    
    b2_layer1 = tf.nn.conv2d(x, b2_w_conv1 , b2_c_strides1 , b2_c_pooling1 )+b2_b_conv1
    b2_layer2 = tf.nn.conv2d(b2_layer1, b2_w_conv2 , b2_c_strides2 , b2_c_pooling2 )+b2_b_conv2
    b2_layer3 = tf.nn.conv2d(b2_layer2, b2_w_conv3 , b2_c_strides3 , b2_c_pooling3 )+b2_b_conv3
    b2_layer4 = tf.nn.conv2d(b2_layer3, b2_w_conv4 , b2_c_strides4 , b2_c_pooling4 )+b2_b_conv4
    
    ####################################################################################

# %%
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split('(\d+)', text) ]

# %%
def get_batch_list(folder_path):
    """
    return ret_train_img_list ,ret_train_lab_list 
    
    """
    list_files=os.walk(folder_path).next()[2]
    ret_train_img_list=[]
    ret_train_lab_list=[]
    np_train_imgs=[]
    np_train_labs=[]
    for i , ele in enumerate(list_files):

        if 'train'  in ele and 'img'in ele:
            ret_train_img_list.append(ele)
        elif 'train' in ele  and  'lab' in ele:
            ret_train_lab_list.append(ele)
    
    ret_train_img_list.sort(key=natural_keys)
    ret_train_lab_list.sort(key = natural_keys)
    for i  in range(len(ret_train_img_list)):
        np_train_imgs.append(np.load(folder_path+ret_train_img_list[i]))
        np_train_labs.append(np.load(folder_path+ret_train_lab_list[i]))
    
    return np_train_imgs ,np_train_labs

# %%
def aug(np_img ,img_row ,img_col , color_ch, crop_img_row , crop_img_col , label):
    
    n_img = np.shape(np_img)[0] 
    n_ret_img = n_img*(img_row - crop_img_row) * (img_col - crop_img_col)*2
    ret_images = np.zeros([n_ret_img ,crop_img_row , crop_img_col,color_ch])
    len_label= np.shape(label)[1]
    ret_labels =  np.zeros([n_ret_img  ,len_label])
    #print "n_augmented image size : " , n_ret_img 
    #print "n classes :", len_label
    #copy label in factor by 2014
    
    if len(np.shape(np_img))==2:
        np_img=np.reshape(np_img , newshape = [np.shape(np_img)[0] , img_row , img_col ,color_ch])
        print np.shape(np_img)
    for n  in range(len(np_img)):
        ret_labels[n*2 , : ] = label[n,:]
        ret_labels[n*2+1 , : ] = label[n,:]
        for r in range(img_row - crop_img_row):
            for c in range(img_col - crop_img_col):
                
                cropped_img = np_img[n, r:crop_img_row +r , c:crop_img_col+c ,: ]
                
                ret_images[n*2,:,:,:]=cropped_img  
                ret_images[(n*2+1) , :,:,:] =np.fliplr(cropped_img )

    
    return ret_images ,ret_labels

# %%
def extract_test_img(np_img ,img_row ,img_col , color_ch, crop_img_row , crop_img_col ):
    left_top =(0,0)
    right_top =(  img_row  - crop_img_row  , 0 )
    center =  ((img_row  - crop_img_row)/2  , (img_col - crop_img_row)/2)
    left_buttom = (0,(img_col - crop_img_row)/2 )
    right_buttom =  (img_row  - crop_img_row , img_col - crop_img_row)
    
    left_top_images  = np_img[: , left_top[0]:crop_img_row+left_top[0] , left_top[1] : crop_img_col+left_top[1] , :  ]
    right_top_images = np_img[: , right_top[0]:crop_img_row +right_top[0], right_top[1] : crop_img_col +right_top[1], :  ]
    center_images    = np_img[: , center[0]:crop_img_row +center[0], center[1] : crop_img_col +center[1], :  ]
    left_buttom_images=np_img[: , left_buttom[0]:crop_img_row +left_buttom[0], left_buttom[1] : crop_img_col +left_buttom[1], :  ]
    right_buttom_images= np_img[: , right_buttom[0]:crop_img_row+right_buttom[0] , right_buttom[1] : crop_img_col +right_buttom[1] , :  ]

    
        
    return left_top_images , right_top_images , center_images , left_buttom_images , right_buttom_images

# %%
def TRAIN_STRUCTURE_A(y_conv , y_ , device_ ):
    """
    Return Value : cost , train_step ,correct_prediction , accuracy 
    
    """
    with tf.device(device_):
    #sm_conv= tf.nn.softmax(y_conv)
        #cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv))

        softmax=tf.nn.softmax(y_conv)
        regular=0.01*(tf.reduce_sum(tf.square(y_conv)))
        cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits( y_conv, y_))
    with tf.device(device_):
        cost = cost+regular
        train_step = tf.train.AdamOptimizer(1e-4).minimize(cost) #1e-4
        with tf.name_scope("accuracy"):
            with tf.name_scope('correct_prediction'):
                correct_prediction = tf.equal(tf.argmax(y_conv,1) ,tf.argmax(y_,1))
            with tf.name_scope('accuracy'):
                accuracy = tf.reduce_mean(tf.cast(correct_prediction , "float")) 
    return cost , train_step ,correct_prediction , accuracy,softmax

# %%
def START_SESS():
    sess = tf.Session()
    sess.run(tf.initialize_all_variables())
    return sess

# %% [markdown]
# # File Terminal Open

# %%
#dirname = '/home/ncc/notebook/mammo/result/'
def make_logdir(dirname):
  

    count=0
    while(True):
        if not os.path.isdir(dirname):
            os.mkdir(dirname)
            break
        elif not os.path.isdir(dirname + str(count)):
            dirname=dirname+str(count)
            os.mkdir(dirname)
            break
        else:
            count+=1
    print 'it is recorded at :'+str(count)

    f=open(dirname+"/log.txt",'w')
    return f

# %%
def write_log(step,train_acc, train_loss , val_acc , val_loss ,fp):
    """
    fp = File Pointer
    
    """
    #result = sess.run(sm_conv , feed_dict = {x:val_img , y_:batch_ys , keep_prob :1.0})
    print step
    print("step %d , training  accuracy %g" %(step,train_acc))
    print("step %d , loss : %g" %(step,train_loss))
    train_str = 'step:\t'+str(step)+'\ttrain_loss:\t'+str(train_loss) +'\ttrain_accuracy:\t'+str(train_acc)+'\n'

    print("step %d , validation  accuracy %g" %(step,val_acc))
    print("step %d , validation loss : %g" %(step,val_loss))
    val_str = 'step:\t'+str(step)+'\tval_loss:\t'+str(val_loss) +'\tval_accuracy:\t'+str(val_acc)+'\n'

    fp.write(train_str)
    fp.write(val_str)

# %%
def load_TVT(divide_flag,file_locate):
    if divide_flag == False:
        train_img=np.load(file_locate+'train_img.npy');
        train_lab=np.load(file_locate+'train_lab.npy');
        val_img= np.load(file_locate+'val_img.npy');
        val_lab = np.load(file_locate+'val_lab.npy');
        test_img=np.load(file_locate+'test_img.npy');
        test_lab=np.load(file_locate+'test_lab.npy');

        print "Training Data Image",np.shape(train_img)
        print "Training Data Label",np.shape(train_lab)
        print "Test Data Label",np.shape(test_lab)
        print "Test Data Image",np.shape(test_img)
        print "val Data Label" , np.shape(val_lab)
        print "val Data Image" , np.shape(val_img)
        
        n_train= np.shape(train_img)[0]
        n_train_lab = np.shape(train_lab)[0]
        return train_img ,train_lab,val_img,val_lab,test_img,test_lab
    if divide_flag == True:
        print '트레이닝 파일이 여러개로 분할되어 있습니다. 분할된 트레이닝 파일에 대한 조치가 필요합니다'
        train_images, train_labels =get_batch_list(file_locate)
        #print train_images ,train_labels
        val_img= np.load(file_locate+'val_img.npy');
        val_lab = np.load(file_locate+'val_lab.npy');
        test_img=np.load(file_locate+'test_img.npy');
        test_lab=np.load(file_locate+'test_lab.npy');
        print "the number of training image batch",len(train_images)
        print "the number of training label batch",len(train_labels)
        print "training Data Label",np.shape(train_labels[0])
        print "training Data Image",np.shape(train_images[0])
        print "Test Data Label",np.shape(test_lab)
        print "Test Data Image",np.shape(test_img)
        print "val Data Label" , np.shape(val_lab)
        print "val Data Image" , np.shape(val_img)
        return train_images, train_labels,val_img,val_lab,test_img,test_lab

# %%
def validate_from_images(sess, images , labels , tensor_info, place_info):
    
    """
    input : x-
    
    x type  : numpy 
    x shape : [n , row , col , ch]
    return  acc,  loss

    """
    print accuracy
    acc_list=[]
    loss_list=[]
    images_labels=zip(images,labels)
    for img_ind ,(img,lab)  in enumerate(images_labels):

        acc ,loss = sess.run( [tensor_info['accuracy'],tensor_info['cost']] ,\
                             feed_dict={place_info['x_']:img , place_info['y_']: lab , place_info['keep_prob']: 1.0})        
        acc_list.append(acc)
        loss_list.append(loss)

    acc_list=np.asarray(acc_list)
    loss_list=np.asarray(loss_list)
    acc=np.mean(acc_list)
    loss=np.mean(loss_list)
    
    return  acc,  loss

# %%
def validate(img , lab ,tensor_info , place_info): #default
    """
    return val_acc,  val_loss, train_acc, train_loss
    """    
    acc,loss = sess.run([tensor_info['accuracy'],tensor_info['cost']] , feed_dict={place_info['x_']:img , place_info['y_']:lab , place_info['keep_prob']: 1.0})        
    return acc,loss

# %%
def BATCH_TRAINING_DIVIDE_RANDOM(maxiter, batch_size,file_locate,tensor_info, place_info , fp):
    
    
    start_time = time.time()
    #with tf.device('/gpu:0'):
    train_imgs, train_labs,val_img,val_lab,test_img,test_lab=load_TVT(True,file_locate) #TVT is Train Validation Test  
    for step in range(maxiter):
        b_ind=random.randrange(0,len(train_imgs))
        train_img = train_imgs[b_ind]
        train_lab = train_labs[b_ind]
        
        batch_xs , batch_ys = next_batch(batch_size, train_img , train_lab)       
        if step%100 ==0: #여기 if loop에서 validate을 합니다 
            try:
                val_acc , val_loss= validate(val_img,val_lab,tensor_info,place_info)     
                train_acc , train_loss=validate(batch_xs,batch_ys,tensor_info,place_info)
            except:
                #한번에 트레이닝이 안되면 분할해서 validation한다.
                val_imgs, val_labs = divide_images(val_img , val_lab, batch_size)
                #print np.shape(val_imgs[0])
                val_acc, val_loss =validate_from_images(sess,val_imgs ,val_labs ,tensor_info ,place_info )
                train_acc , train_loss=validate(batch_xs,batch_ys,tensor_info ,place_info)
                
            write_log(step , train_acc, train_loss , val_acc, val_loss , fp)
            #softmax_=sess.run(softmax ,feed_dict ={ x:batch_xs , y_:batch_ys , keep_prob:1.0 })
            #print softmax_
        training(batch_xs,batch_ys,tensor_info,place_info)

    ############################################aug_and_training############################
    print("--- Training Time : %s ---" % (time.time() - start_time))
    train_time="--- Training Time : ---:\t" +str(time.time() - start_time)
    
    try:
        test_acc , test_loss=validate(test_img , test_lab)
    except:
        #한번에 트레이닝이 안되면 분할해서 validation한다.
        test_imgs, test_labs = divide_images(test_img ,test_lab, batch_size)
        #print np.shape(val_imgs[0])
        test_acc, test_loss =validate_from_images(sess,test_imgs ,test_labs ,tensor_info,place_info )
    print "test accuracy {0} , test loss {1}".format(test_acc, test_loss)
    fp.write(train_time)
    fp.close()
    sess.close()

# %%
def BATCH_TRAINING_RANDOM(maxiter, batch_size, file_locate, tensor_info , place_info, fp):
    
    start_time = time.time()
    #with tf.device('/gpu:0'):
    train_img, train_lab,val_img,val_lab,test_img,test_lab=load_TVT(False,file_locate) #TVT is Train Validation Test  
    for step in range(maxiter):    
        batch_xs , batch_ys = next_batch(batch_size, train_img , train_lab)       
        if step%100 ==0: #여기 if loop에서 validate을 합니다 
            try:
                val_acc , val_loss = validate(val_img , val_lab)
                train_acc , train_loss = validate(batch_xs,batch_ys)
                
         
            except:
                #한번에 트레이닝이 안되면 분할해서 validation한다.
                val_imgs, val_labs = divide_images(val_img , val_lab, batch_size)
                #print np.shape(val_imgs[0])
                val_acc, val_loss =validate_from_images(sess, val_imgs ,val_labs ,tensor_info ,place_info)
                train_acc , train_loss=validate(batch_xs,batch_ys,tensor_info ,place_info)
                       
            write_log(step , train_acc, train_loss , val_acc, val_loss , fp)
            #softmax_=sess.run(softmax ,feed_dict ={ x:batch_xs , y_:batch_ys , keep_prob:1.0 })
            #print softmax_
        training(batch_xs,batch_ys,tensor_info , place_info)

    ############################################aug_and_training############################
    print("--- Training Time : %s ---" % (time.time() - start_time))
    train_time="--- Training Time : ---:\t" +str(time.time() - start_time)
    
    try:
        test_acc , test_loss=validate(test_img , test_lab)
    except:
        #한번에 트레이닝이 안되면 분할해서 validation한다.
        test_imgs, test_labs = divide_images(test_img ,test_lab, batch_size)
        #print np.shape(val_imgs[0])
        test_acc, test_loss =validate_from_images(sess,test_imgs ,test_labs ,tensor_info,place_info )
    print "test accuracy {0} , test loss {1}".format(test_acc, test_loss)
    fp.write(train_time)
    fp.close()

# %%
def BATCH_TRAINING_MANUAL(maxiter  , batch_size,file_locate, tensor_info, place_info , fp ):
    start_time = time.time()
#with tf.device('/gpu:0'):
    train_img, train_lab,val_img,val_lab,test_img,test_lab\
    =load_TVT(divide_flag,file_locate)
    train_images , train_labels=divide_images(train_img , train_lab , batch_size)
    train_images_labels=zip(train_images , train_labels)
    
    for step,(batch_xs , batch_ys) in train_images_labels:
        if step%100 ==0:
            try:
                val_acc , val_loss=validate(val_img , val_lab)
                train_acc , train_loss=validate(batch_xs,batch_ys)
            except:
                #한번에 트레이닝이 안되면 분할해서 validation한다.
                val_imgs, val_labs = divide_images(val_img , val_lab, batch_size)
                val_acc, val_loss =validate_from_images(val_imgs ,val_labs ,accuracy, cost )
                train_acc , train_loss=validate(batch_xs,batch_ys,accuracy, cost)
            write_log(step , train_acc, train_loss , val_acc, val_loss , fp)
            np.save('./result/batch_xs' ,batch_xs)
            np.save('./result/batch_ys' ,batch_ys)
        else:
            list_aud_x = aug_8_times(batch_xs)
            for ele in list_aug_x:
                training(ele ,batch_ys)                    


############################################aug_and_training############################
    print("--- Training Time : %s ---" % (time.time() - start_time))
    train_time="--- Training Time : ---:\t" +str(time.time() - start_time)
    fp.write(train_time)
    fp.close()

# %%
def divide_images(images , labels,batch_size):
    """
    return list_images,list_labels
    """
    n_divide=len(images)/batch_size

    list_images=[]
    list_labels=[]
    for ind in range(n_divide):
        # j*batch_size :(j+1)*batch_size
        image =images[ ind*batch_size :(ind+1)*batch_size] 
        label =labels[ ind*batch_size :(ind+1)*batch_size]
        list_images.append(image)
        list_labels.append(label)

    #right above code have to modify
    image = images[ (ind+1)*batch_size :  ] 
    label = labels[ (ind+1)*batch_size :  ]
    list_images.append(image)
    list_labels.append(label)

    return list_images,list_labels

# %%
  
def validate_extract_imgs(val_img , val_lab , train_img , train_lab ):
    """
    extract patch from ori-image
    """
    color_ch = in_ch
    val_images  =extract_test_img(val_img , 128 , 128 , color_ch   ,crop_img_row =118 , crop_img_col =118 )
    train_images=extract_test_img(train_img ,128 , 128 , color_ch   ,crop_img_row =118 , crop_img_col =118 )
    val_acc, val_loss =validate_from_images(sess, val_images , val_lab , accuracy ,cost )
    train_acc , train_loss =validate_from_images(sess, train_images , train_lab ,accuracy , cost)
    
    return val_acc , val_loss, train_acc ,train_loss

# %%
def training(batch_xs , batch_ys , tensor_info , place_info):
    sess.run(tensor_info['train_step'] ,feed_dict={place_info['x_']: batch_xs, place_info['y_']:batch_ys , place_info['keep_prob'] : 0.5})

# %%
def aug_8_times(x):
    """
    
    
    x shape is [n_batch , row ,col , color_ch ]
    x type is numpy 
    this code need too many time to run 
    we should find solution using parallel method to less run time maybe 
    
    return x,np_rot90,np_rot180,np_rot270,lr_x,np_lr_rot90 ,np_lr_rot180 , np_lr_rot270 
    
    """

    n_batch,row,col,ch=np.shape(x)
    lr_x = np.flipud(x)

    np_rot90 =np.zeros(shape =[n_batch , row ,col ,ch] )
    np_rot180=np.zeros(shape =[n_batch , row ,col ,ch] )
    np_rot270=np.zeros(shape =[n_batch , row ,col ,ch] )

    np_lr_rot90 =np.zeros(shape =[n_batch , row ,col ,ch] )
    np_lr_rot180=np.zeros(shape =[n_batch , row ,col ,ch] )
    np_lr_rot270=np.zeros(shape =[n_batch , row ,col ,ch] )
    
    

    for batch_ind in range(n_batch):

        rot90=np.rot90(x[batch_ind,:,:,:])
        rot180=np.rot90(rot90)
        rot270=np.rot90(rot180)

        np_rot90[batch_ind,:,:,:] = rot90
        np_rot180[batch_ind,:,:,:]=rot180
        np_rot270[batch_ind,:,:,:]=rot270

        lr_rot90=np.rot90(lr_x[batch_ind,:,:,:])
        lr_rot180=np.rot90(lr_rot90)
        lr_rot270=np.rot90(lr_rot180)

        np_lr_rot90[batch_ind,:,:,:]=lr_rot90
        np_lr_rot180[batch_ind,:,:,:]=lr_rot180
        np_lr_rot90[batch_ind,:,:,:]=lr_rot270
    return x,np_rot90,np_rot180,np_rot270,lr_x,np_lr_rot90 ,np_lr_rot180 , np_lr_rot270

# %%
def aug_crop(np_img ,img_row ,img_col , color_ch, crop_img_row , crop_img_col , label):
    n_img = np.shape(np_img)[0] 
    n_ret_img = n_img*(img_row - crop_img_row) * (img_col - crop_img_col)*2
    ret_images = np.zeros([n_ret_img ,crop_img_row , crop_img_col,color_ch])
    len_label= np.shape(label)[1]
    ret_labels =  np.zeros([n_ret_img  ,len_label])
    #print "n_augmented image size : " , n_ret_img 
    #print "n classes :", len_label
    #copy label in factor by 2014

    if len(np.shape(np_img))==2:
        np_img=np.reshape(np_img , newshape = [np.shape(np_img)[0] , img_row , img_col ,color_ch])
        print np.shape(np_img)
    for n  in range(len(np_img)):
        ret_labels[n*2 , : ] = label[n,:]
        ret_labels[n*2+1 , : ] = label[n,:]
        for r in range(img_row - crop_img_row):
            for c in range(img_col - crop_img_col):

                cropped_img = np_img[n, r:crop_img_row +r , c:crop_img_col+c ,: ]

                ret_images[n*2,:,:,:]=cropped_img  
                ret_images[(n*2+1) , :,:,:] =np.fliplr(cropped_img )


    return ret_images ,ret_labels

# %%
def OPEN_TENSORBOARD(sess,tensor_info , logdir ):
    tb_acc=tf.scalar_summary("accuarcy" ,tensor_info['accuracy'] )
    tb_acc=tf.scalar_summary("loss" ,tensor_info['cost'] )
    
    writer=tf.train.SummaryWriter(logdir , sess.graph_def )

# %%
tensor_info={};place_info={}
file_locate='/media/seongjung/Seagate Backup Plus Drive/data/cifar/cifar-10-images_labels/merge_training_batch/'
dirname='./result/'
A=STEM_A(x_ , 'gpu:0')
B=STEM_B(A , 'gpu:0')
C=STEM_C(B , 'gpu:0')
D=INCEPTION_MODULE_A(C,'gpu:0', 'INCEPTION_MODULE_A_1')
E=INCEPTION_MODULE_A(D,'gpu:0', 'INCEPTION_MODULE_A_2')
F=INCEPTION_MODULE_A(E,'gpu:0', 'INCEPTION_MODULE_A_3')
G=INCEPTION_MODULE_A(F,'gpu:0', 'INCEPTION_MODULE_A_4')
H=INCEPTION_REDUCTION_A(G,'gpu:0' , 'INCEPTION_REDUCTION_A_1')
I=INCEPTION_MODULE_B(H,'gpu:0' , 'INCEPTION_REDUCTION_B_1')
J=INCEPTION_MODULE_B(I,'gpu:0' , 'INCEPTION_REDUCTION_B_2')
K=INCEPTION_MODULE_B(G,'gpu:0' , 'INCEPTION_REDUCTION_B_3')
L=INCEPTION_MODULE_B(G,'gpu:0' , 'INCEPTION_REDUCTION_B_4')
M=INCEPTION_MODULE_B(G,'gpu:0' , 'INCEPTION_REDUCTION_B_5')


flat_=FLAT(M)
y_conv=FC_A(flat_ , n_classes ,'/gpu:0' ,dropout_rate=keep_prob)
cost , train_step ,correct_prediction , accuracy ,softmax = TRAIN_STRUCTURE_A(y_conv , y_ , '/gpu:0')

tensor_info['cost']=cost
tensor_info['train_step']=train_step
tensor_info['correct_prediction']=correct_prediction
tensor_info['accuracy']=accuracy
tensor_info['softmax']=softmax

place_info['x_']=x_
place_info['y_']=y_
place_info['keep_prob']=keep_prob


sess=START_SESS()
fp=make_logdir(dirname)
BATCH_TRAINING_RANDOM(100000 , 30,file_locate , tensor_info,place_info ,fp)
#BATCH_TRAINING_DIVIDE_RANDOM(100000 , 30,file_locate , tensor_info,place_info ,fp)
# Out:
# Tensor("Relu_285:0", shape=(?, 15, 15, 32), dtype=float32, device=/device:GPU:0)
# Tensor("Relu_286:0", shape=(?, 13, 13, 32), dtype=float32, device=/device:GPU:0)
# Tensor("Relu_287:0", shape=(?, 13, 13, 64), dtype=float32, device=/device:GPU:0)
# Tensor("Relu_288:0", shape=(?, 6, 6, 96), dtype=float32, device=/device:GPU:0)
# Tensor("Relu_289:0", shape=(?, 6, 6, 64), dtype=float32, device=/device:GPU:0)
# Tensor("concat_102:0", shape=(?, 6, 6, 160), dtype=float32, device=/device:GPU:0)
# Tensor("Relu_295:0", shape=(?, 4, 4, 192), dtype=float32, device=/device:GPU:0)
# Tensor("Relu_296:0", shape=(?, 4, 4, 192), dtype=float32, device=/device:GPU:0)
# (?, 4, 4, 384)
# (?, 4, 4, 384)
# (?, 4, 4, 384)
# (?, 4, 4, 384)
# (?, 4, 4, 384)
# (?, 1, 1, 384)
# (?, 1, 1, 384)
# (?, 1, 1, 256)
# Tensor("concat_121:0", shape=(?, 1, 1, 1024), dtype=float32)
# Tensor("concat_124:0", shape=(?, 1, 1, 1024), dtype=float32)
# Tensor("concat_127:0", shape=(?, 4, 4, 1024), dtype=float32)
# Tensor("concat_130:0", shape=(?, 4, 4, 1024), dtype=float32)
# Tensor("concat_133:0", shape=(?, 4, 4, 1024), dtype=float32)
# (16384, 1024)
# WARNING:tensorflow:From <ipython-input-23-8df76ab5861c>:3 in START_SESS.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# it is recorded at :17
# Training Data Image (50000, 32, 32, 3)
# Training Data Label (50000, 10)
# Test Data Label (5000, 10)
# Test Data Image (5000, 32, 32, 3)
# val Data Label (5000, 10)
# val Data Image (5000, 32, 32, 3)
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 0
# step 0 , training  accuracy 0.0333333
# step 0 , loss : 8.60755
# step 0 , validation  accuracy 0.0979042
# step 0 , validation loss : 9.35198
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 100
# step 100 , training  accuracy 0.233333
# step 100 , loss : 2.29241
# step 100 , validation  accuracy 0.190519
# step 100 , validation loss : 2.32356
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 200
# step 200 , training  accuracy 0.333333
# step 200 , loss : 2.29026
# step 200 , validation  accuracy 0.249002
# step 200 , validation loss : 2.28791
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 300
# step 300 , training  accuracy 0.4
# step 300 , loss : 2.2423
# step 300 , validation  accuracy 0.264371
# step 300 , validation loss : 2.26961
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 400
# step 400 , training  accuracy 0.266667
# step 400 , loss : 2.27225
# step 400 , validation  accuracy 0.267066
# step 400 , validation loss : 2.27126
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 500
# step 500 , training  accuracy 0.3
# step 500 , loss : 2.27784
# step 500 , validation  accuracy 0.282735
# step 500 , validation loss : 2.27139
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 600
# step 600 , training  accuracy 0.1
# step 600 , loss : 2.29392
# step 600 , validation  accuracy 0.305788
# step 600 , validation loss : 2.2474
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 700
# step 700 , training  accuracy 0.366667
# step 700 , loss : 2.20064
# step 700 , validation  accuracy 0.307086
# step 700 , validation loss : 2.24715
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 800
# step 800 , training  accuracy 0.2
# step 800 , loss : 2.25033
# step 800 , validation  accuracy 0.318663
# step 800 , validation loss : 2.2407
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 900
# step 900 , training  accuracy 0.433333
# step 900 , loss : 2.1997
# step 900 , validation  accuracy 0.316068
# step 900 , validation loss : 2.24129
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 1000
# step 1000 , training  accuracy 0.233333
# step 1000 , loss : 2.27303
# step 1000 , validation  accuracy 0.319162
# step 1000 , validation loss : 2.23997
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 1100
# step 1100 , training  accuracy 0.366667
# step 1100 , loss : 2.26945
# step 1100 , validation  accuracy 0.329641
# step 1100 , validation loss : 2.24073
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 1200
# step 1200 , training  accuracy 0.3
# step 1200 , loss : 2.25246
# step 1200 , validation  accuracy 0.319561
# step 1200 , validation loss : 2.2371
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 1300
# step 1300 , training  accuracy 0.4
# step 1300 , loss : 2.25006
# step 1300 , validation  accuracy 0.328044
# step 1300 , validation loss : 2.23542
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 1400
# step 1400 , training  accuracy 0.333333
# step 1400 , loss : 2.19993
# step 1400 , validation  accuracy 0.343613
# step 1400 , validation loss : 2.22747
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 1500
# step 1500 , training  accuracy 0.3
# step 1500 , loss : 2.25105
# step 1500 , validation  accuracy 0.330639
# step 1500 , validation loss : 2.23947
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 1600
# step 1600 , training  accuracy 0.4
# step 1600 , loss : 2.22134
# step 1600 , validation  accuracy 0.350599
# step 1600 , validation loss : 2.22466
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 1700
# step 1700 , training  accuracy 0.333333
# step 1700 , loss : 2.22149
# step 1700 , validation  accuracy 0.350998
# step 1700 , validation loss : 2.22436
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 1800
# step 1800 , training  accuracy 0.4
# step 1800 , loss : 2.20833
# step 1800 , validation  accuracy 0.357385
# step 1800 , validation loss : 2.22241
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 1900
# step 1900 , training  accuracy 0.5
# step 1900 , loss : 2.20538
# step 1900 , validation  accuracy 0.353992
# step 1900 , validation loss : 2.23174
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 2000
# step 2000 , training  accuracy 0.333333
# step 2000 , loss : 2.2617
# step 2000 , validation  accuracy 0.358783
# step 2000 , validation loss : 2.21627
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 2100
# step 2100 , training  accuracy 0.4
# step 2100 , loss : 2.20936
# step 2100 , validation  accuracy 0.366268
# step 2100 , validation loss : 2.22188
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 2200
# step 2200 , training  accuracy 0.333333
# step 2200 , loss : 2.23847
# step 2200 , validation  accuracy 0.36487
# step 2200 , validation loss : 2.21428
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 2300
# step 2300 , training  accuracy 0.466667
# step 2300 , loss : 2.16429
# step 2300 , validation  accuracy 0.372156
# step 2300 , validation loss : 2.21175
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 2400
# step 2400 , training  accuracy 0.466667
# step 2400 , loss : 2.17858
# step 2400 , validation  accuracy 0.375349
# step 2400 , validation loss : 2.21264
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 2500
# step 2500 , training  accuracy 0.333333
# step 2500 , loss : 2.22554
# step 2500 , validation  accuracy 0.374052
# step 2500 , validation loss : 2.22007
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 2600
# step 2600 , training  accuracy 0.333333
# step 2600 , loss : 2.23029
# step 2600 , validation  accuracy 0.370659
# step 2600 , validation loss : 2.2096
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 2700
# step 2700 , training  accuracy 0.333333
# step 2700 , loss : 2.21226
# step 2700 , validation  accuracy 0.370459
# step 2700 , validation loss : 2.20742
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 2800
# step 2800 , training  accuracy 0.366667
# step 2800 , loss : 2.1911
# step 2800 , validation  accuracy 0.376447
# step 2800 , validation loss : 2.20583
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 2900
# step 2900 , training  accuracy 0.6
# step 2900 , loss : 2.12065
# step 2900 , validation  accuracy 0.381437
# step 2900 , validation loss : 2.20898
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 3000
# step 3000 , training  accuracy 0.333333
# step 3000 , loss : 2.21432
# step 3000 , validation  accuracy 0.383932
# step 3000 , validation loss : 2.21082
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 3100
# step 3100 , training  accuracy 0.4
# step 3100 , loss : 2.15641
# step 3100 , validation  accuracy 0.400998
# step 3100 , validation loss : 2.19729
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 3200
# step 3200 , training  accuracy 0.333333
# step 3200 , loss : 2.20901
# step 3200 , validation  accuracy 0.391916
# step 3200 , validation loss : 2.1969
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 3300
# step 3300 , training  accuracy 0.4
# step 3300 , loss : 2.16895
# step 3300 , validation  accuracy 0.397006
# step 3300 , validation loss : 2.1961
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 3400
# step 3400 , training  accuracy 0.3
# step 3400 , loss : 2.24893
# step 3400 , validation  accuracy 0.396407
# step 3400 , validation loss : 2.19252
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 3500
# step 3500 , training  accuracy 0.366667
# step 3500 , loss : 2.23565
# step 3500 , validation  accuracy 0.398004
# step 3500 , validation loss : 2.19572
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 3600
# step 3600 , training  accuracy 0.533333
# step 3600 , loss : 2.17372
# step 3600 , validation  accuracy 0.387026
# step 3600 , validation loss : 2.19637
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 3700
# step 3700 , training  accuracy 0.466667
# step 3700 , loss : 2.17554
# step 3700 , validation  accuracy 0.399501
# step 3700 , validation loss : 2.19473
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 3800
# step 3800 , training  accuracy 0.3
# step 3800 , loss : 2.2253
# step 3800 , validation  accuracy 0.38493
# step 3800 , validation loss : 2.20016
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 3900
# step 3900 , training  accuracy 0.466667
# step 3900 , loss : 2.1713
# step 3900 , validation  accuracy 0.374251
# step 3900 , validation loss : 2.20465
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 4000
# step 4000 , training  accuracy 0.6
# step 4000 , loss : 2.16823
# step 4000 , validation  accuracy 0.396208
# step 4000 , validation loss : 2.19868
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 4100
# step 4100 , training  accuracy 0.6
# step 4100 , loss : 2.1314
# step 4100 , validation  accuracy 0.392016
# step 4100 , validation loss : 2.19685
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 4200
# step 4200 , training  accuracy 0.333333
# step 4200 , loss : 2.17317
# step 4200 , validation  accuracy 0.416866
# step 4200 , validation loss : 2.18612
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 4300
# step 4300 , training  accuracy 0.5
# step 4300 , loss : 2.13801
# step 4300 , validation  accuracy 0.413473
# step 4300 , validation loss : 2.18377
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 4400
# step 4400 , training  accuracy 0.433333
# step 4400 , loss : 2.18943
# step 4400 , validation  accuracy 0.389321
# step 4400 , validation loss : 2.1953
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 4500
# step 4500 , training  accuracy 0.266667
# step 4500 , loss : 2.24244
# step 4500 , validation  accuracy 0.41008
# step 4500 , validation loss : 2.1919
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 4600
# step 4600 , training  accuracy 0.433333
# step 4600 , loss : 2.15759
# step 4600 , validation  accuracy 0.417864
# step 4600 , validation loss : 2.17911
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 4700
# step 4700 , training  accuracy 0.466667
# step 4700 , loss : 2.12522
# step 4700 , validation  accuracy 0.406886
# step 4700 , validation loss : 2.186
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 4800
# step 4800 , training  accuracy 0.5
# step 4800 , loss : 2.09799
# step 4800 , validation  accuracy 0.427745
# step 4800 , validation loss : 2.17658
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 4900
# step 4900 , training  accuracy 0.466667
# step 4900 , loss : 2.22019
# step 4900 , validation  accuracy 0.396407
# step 4900 , validation loss : 2.18973
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 5000
# step 5000 , training  accuracy 0.366667
# step 5000 , loss : 2.18237
# step 5000 , validation  accuracy 0.426347
# step 5000 , validation loss : 2.17532
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 5100
# step 5100 , training  accuracy 0.333333
# step 5100 , loss : 2.18887
# step 5100 , validation  accuracy 0.428443
# step 5100 , validation loss : 2.17103
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 5200
# step 5200 , training  accuracy 0.5
# step 5200 , loss : 2.12576
# step 5200 , validation  accuracy 0.423254
# step 5200 , validation loss : 2.17516
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 5300
# step 5300 , training  accuracy 0.466667
# step 5300 , loss : 2.11663
# step 5300 , validation  accuracy 0.440319
# step 5300 , validation loss : 2.16612
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 5400
# step 5400 , training  accuracy 0.466667
# step 5400 , loss : 2.17605
# step 5400 , validation  accuracy 0.437924
# step 5400 , validation loss : 2.16788
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 5500
# step 5500 , training  accuracy 0.7
# step 5500 , loss : 2.07212
# step 5500 , validation  accuracy 0.433932
# step 5500 , validation loss : 2.17167
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 5600
# step 5600 , training  accuracy 0.466667
# step 5600 , loss : 2.1646
# step 5600 , validation  accuracy 0.436527
# step 5600 , validation loss : 2.16777
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 5700
# step 5700 , training  accuracy 0.433333
# step 5700 , loss : 2.16658
# step 5700 , validation  accuracy 0.437226
# step 5700 , validation loss : 2.16475
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 5800
# step 5800 , training  accuracy 0.466667
# step 5800 , loss : 2.19172
# step 5800 , validation  accuracy 0.438024
# step 5800 , validation loss : 2.16833
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 5900
# step 5900 , training  accuracy 0.433333
# step 5900 , loss : 2.20409
# step 5900 , validation  accuracy 0.443713
# step 5900 , validation loss : 2.16556
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 6000
# step 6000 , training  accuracy 0.666667
# step 6000 , loss : 2.05128
# step 6000 , validation  accuracy 0.450798
# step 6000 , validation loss : 2.16033
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 6100
# step 6100 , training  accuracy 0.466667
# step 6100 , loss : 2.1599
# step 6100 , validation  accuracy 0.445609
# step 6100 , validation loss : 2.16282
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 6200
# step 6200 , training  accuracy 0.566667
# step 6200 , loss : 2.0931
# step 6200 , validation  accuracy 0.452595
# step 6200 , validation loss : 2.15816
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 6300
# step 6300 , training  accuracy 0.566667
# step 6300 , loss : 2.11115
# step 6300 , validation  accuracy 0.458882
# step 6300 , validation loss : 2.15973
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 6400
# step 6400 , training  accuracy 0.533333
# step 6400 , loss : 2.11926
# step 6400 , validation  accuracy 0.438024
# step 6400 , validation loss : 2.16593
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 6500
# step 6500 , training  accuracy 0.533333
# step 6500 , loss : 2.09834
# step 6500 , validation  accuracy 0.460579
# step 6500 , validation loss : 2.15489
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 6600
# step 6600 , training  accuracy 0.4
# step 6600 , loss : 2.14775
# step 6600 , validation  accuracy 0.449601
# step 6600 , validation loss : 2.15882
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 6700
# step 6700 , training  accuracy 0.4
# step 6700 , loss : 2.17718
# step 6700 , validation  accuracy 0.444611
# step 6700 , validation loss : 2.15896
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 6800
# step 6800 , training  accuracy 0.466667
# step 6800 , loss : 2.15197
# step 6800 , validation  accuracy 0.447006
# step 6800 , validation loss : 2.15873
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 6900
# step 6900 , training  accuracy 0.633333
# step 6900 , loss : 2.03931
# step 6900 , validation  accuracy 0.46008
# step 6900 , validation loss : 2.1556
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 7000
# step 7000 , training  accuracy 0.633333
# step 7000 , loss : 2.07408
# step 7000 , validation  accuracy 0.446906
# step 7000 , validation loss : 2.16333
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 7100
# step 7100 , training  accuracy 0.533333
# step 7100 , loss : 2.1089
# step 7100 , validation  accuracy 0.455589
# step 7100 , validation loss : 2.15101
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 7200
# step 7200 , training  accuracy 0.5
# step 7200 , loss : 2.11724
# step 7200 , validation  accuracy 0.461178
# step 7200 , validation loss : 2.15294
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 7300
# step 7300 , training  accuracy 0.566667
# step 7300 , loss : 2.08228
# step 7300 , validation  accuracy 0.471158
# step 7300 , validation loss : 2.15012
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 7400
# step 7400 , training  accuracy 0.533333
# step 7400 , loss : 2.15462
# step 7400 , validation  accuracy 0.467864
# step 7400 , validation loss : 2.14859
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 7500
# step 7500 , training  accuracy 0.366667
# step 7500 , loss : 2.17325
# step 7500 , validation  accuracy 0.460978
# step 7500 , validation loss : 2.158
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 7600
# step 7600 , training  accuracy 0.533333
# step 7600 , loss : 2.107
# step 7600 , validation  accuracy 0.477844
# step 7600 , validation loss : 2.14683
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 7700
# step 7700 , training  accuracy 0.533333
# step 7700 , loss : 2.12302
# step 7700 , validation  accuracy 0.459282
# step 7700 , validation loss : 2.15401
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 7800
# step 7800 , training  accuracy 0.533333
# step 7800 , loss : 2.08435
# step 7800 , validation  accuracy 0.454491
# step 7800 , validation loss : 2.15328
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 7900
# step 7900 , training  accuracy 0.466667
# step 7900 , loss : 2.11722
# step 7900 , validation  accuracy 0.448104
# step 7900 , validation loss : 2.15606
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 8000
# step 8000 , training  accuracy 0.766667
# step 8000 , loss : 2.00232
# step 8000 , validation  accuracy 0.468563
# step 8000 , validation loss : 2.14826
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 8100
# step 8100 , training  accuracy 0.4
# step 8100 , loss : 2.12069
# step 8100 , validation  accuracy 0.465369
# step 8100 , validation loss : 2.15271
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 8200
# step 8200 , training  accuracy 0.566667
# step 8200 , loss : 2.06876
# step 8200 , validation  accuracy 0.464072
# step 8200 , validation loss : 2.15124
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 8300
# step 8300 , training  accuracy 0.666667
# step 8300 , loss : 2.0878
# step 8300 , validation  accuracy 0.457884
# step 8300 , validation loss : 2.16011
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 8400
# step 8400 , training  accuracy 0.5
# step 8400 , loss : 2.10936
# step 8400 , validation  accuracy 0.462276
# step 8400 , validation loss : 2.14721
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 8500
# step 8500 , training  accuracy 0.533333
# step 8500 , loss : 2.09792
# step 8500 , validation  accuracy 0.458583
# step 8500 , validation loss : 2.14768
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 8600
# step 8600 , training  accuracy 0.433333
# step 8600 , loss : 2.17609
# step 8600 , validation  accuracy 0.461976
# step 8600 , validation loss : 2.14944
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 8700
# step 8700 , training  accuracy 0.366667
# step 8700 , loss : 2.1718
# step 8700 , validation  accuracy 0.459281
# step 8700 , validation loss : 2.1552
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 8800
# step 8800 , training  accuracy 0.466667
# step 8800 , loss : 2.15698
# step 8800 , validation  accuracy 0.466767
# step 8800 , validation loss : 2.15265
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 8900
# step 8900 , training  accuracy 0.566667
# step 8900 , loss : 2.11198
# step 8900 , validation  accuracy 0.472555
# step 8900 , validation loss : 2.14139
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 9000
# step 9000 , training  accuracy 0.533333
# step 9000 , loss : 2.09958
# step 9000 , validation  accuracy 0.449102
# step 9000 , validation loss : 2.1584
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 9100
# step 9100 , training  accuracy 0.666667
# step 9100 , loss : 2.00613
# step 9100 , validation  accuracy 0.475649
# step 9100 , validation loss : 2.14224
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 9200
# step 9200 , training  accuracy 0.5
# step 9200 , loss : 2.10892
# step 9200 , validation  accuracy 0.470659
# step 9200 , validation loss : 2.14356
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 9300
# step 9300 , training  accuracy 0.566667
# step 9300 , loss : 2.04613
# step 9300 , validation  accuracy 0.475549
# step 9300 , validation loss : 2.13903
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 9400
# step 9400 , training  accuracy 0.533333
# step 9400 , loss : 2.08256
# step 9400 , validation  accuracy 0.485629
# step 9400 , validation loss : 2.13897
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 9500
# step 9500 , training  accuracy 0.6
# step 9500 , loss : 2.09949
# step 9500 , validation  accuracy 0.484232
# step 9500 , validation loss : 2.13716
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 9600
# step 9600 , training  accuracy 0.633333
# step 9600 , loss : 2.03986
# step 9600 , validation  accuracy 0.490419
# step 9600 , validation loss : 2.13547
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 9700
# step 9700 , training  accuracy 0.633333
# step 9700 , loss : 2.05647
# step 9700 , validation  accuracy 0.482735
# step 9700 , validation loss : 2.13687
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 9800
# step 9800 , training  accuracy 0.5
# step 9800 , loss : 2.13016
# step 9800 , validation  accuracy 0.476048
# step 9800 , validation loss : 2.14204
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 9900
# step 9900 , training  accuracy 0.5
# step 9900 , loss : 2.14267
# step 9900 , validation  accuracy 0.481737
# step 9900 , validation loss : 2.14036
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 10000
# step 10000 , training  accuracy 0.466667
# step 10000 , loss : 2.10215
# step 10000 , validation  accuracy 0.463773
# step 10000 , validation loss : 2.15449
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 10100
# step 10100 , training  accuracy 0.566667
# step 10100 , loss : 2.10174
# step 10100 , validation  accuracy 0.473453
# step 10100 , validation loss : 2.14295
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 10200
# step 10200 , training  accuracy 0.566667
# step 10200 , loss : 2.09959
# step 10200 , validation  accuracy 0.487226
# step 10200 , validation loss : 2.14097
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 10300
# step 10300 , training  accuracy 0.5
# step 10300 , loss : 2.06951
# step 10300 , validation  accuracy 0.495709
# step 10300 , validation loss : 2.13535
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 10400
# step 10400 , training  accuracy 0.766667
# step 10400 , loss : 1.98077
# step 10400 , validation  accuracy 0.496707
# step 10400 , validation loss : 2.13004
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 10500
# step 10500 , training  accuracy 0.566667
# step 10500 , loss : 2.07556
# step 10500 , validation  accuracy 0.494112
# step 10500 , validation loss : 2.1313
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 10600
# step 10600 , training  accuracy 0.466667
# step 10600 , loss : 2.10324
# step 10600 , validation  accuracy 0.489421
# step 10600 , validation loss : 2.13492
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 10700
# step 10700 , training  accuracy 0.5
# step 10700 , loss : 2.13112
# step 10700 , validation  accuracy 0.476946
# step 10700 , validation loss : 2.1501
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 10800
# step 10800 , training  accuracy 0.6
# step 10800 , loss : 2.0618
# step 10800 , validation  accuracy 0.496707
# step 10800 , validation loss : 2.1361
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 10900
# step 10900 , training  accuracy 0.466667
# step 10900 , loss : 2.14701
# step 10900 , validation  accuracy 0.484631
# step 10900 , validation loss : 2.14563
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 11000
# step 11000 , training  accuracy 0.566667
# step 11000 , loss : 2.10341
# step 11000 , validation  accuracy 0.497405
# step 11000 , validation loss : 2.13113
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 11100
# step 11100 , training  accuracy 0.633333
# step 11100 , loss : 2.03018
# step 11100 , validation  accuracy 0.512076
# step 11100 , validation loss : 2.12056
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 11200
# step 11200 , training  accuracy 0.533333
# step 11200 , loss : 2.11065
# step 11200 , validation  accuracy 0.497305
# step 11200 , validation loss : 2.13338
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 11300
# step 11300 , training  accuracy 0.4
# step 11300 , loss : 2.1517
# step 11300 , validation  accuracy 0.488224
# step 11300 , validation loss : 2.14294
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 11400
# step 11400 , training  accuracy 0.7
# step 11400 , loss : 1.98959
# step 11400 , validation  accuracy 0.500499
# step 11400 , validation loss : 2.13569
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 11500
# step 11500 , training  accuracy 0.7
# step 11500 , loss : 1.98898
# step 11500 , validation  accuracy 0.5001
# step 11500 , validation loss : 2.1283
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 11600
# step 11600 , training  accuracy 0.5
# step 11600 , loss : 2.10279
# step 11600 , validation  accuracy 0.497904
# step 11600 , validation loss : 2.13055
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 11700
# step 11700 , training  accuracy 0.466667
# step 11700 , loss : 2.13868
# step 11700 , validation  accuracy 0.511677
# step 11700 , validation loss : 2.12353
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 11800
# step 11800 , training  accuracy 0.433333
# step 11800 , loss : 2.15767
# step 11800 , validation  accuracy 0.503593
# step 11800 , validation loss : 2.13535
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 11900
# step 11900 , training  accuracy 0.533333
# step 11900 , loss : 2.10208
# step 11900 , validation  accuracy 0.498703
# step 11900 , validation loss : 2.13742
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 12000
# step 12000 , training  accuracy 0.7
# step 12000 , loss : 2.00548
# step 12000 , validation  accuracy 0.492116
# step 12000 , validation loss : 2.13852
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 12100
# step 12100 , training  accuracy 0.766667
# step 12100 , loss : 1.95452
# step 12100 , validation  accuracy 0.508184
# step 12100 , validation loss : 2.12659
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 12200
# step 12200 , training  accuracy 0.7
# step 12200 , loss : 2.05459
# step 12200 , validation  accuracy 0.497405
# step 12200 , validation loss : 2.12807
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 12300
# step 12300 , training  accuracy 0.533333
# step 12300 , loss : 2.06459
# step 12300 , validation  accuracy 0.506387
# step 12300 , validation loss : 2.12694
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 12400
# step 12400 , training  accuracy 0.6
# step 12400 , loss : 2.01928
# step 12400 , validation  accuracy 0.501697
# step 12400 , validation loss : 2.13525
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 12500
# step 12500 , training  accuracy 0.733333
# step 12500 , loss : 1.96712
# step 12500 , validation  accuracy 0.506886
# step 12500 , validation loss : 2.12846
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 12600
# step 12600 , training  accuracy 0.8
# step 12600 , loss : 1.95572
# step 12600 , validation  accuracy 0.505289
# step 12600 , validation loss : 2.13448
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 12700
# step 12700 , training  accuracy 0.666667
# step 12700 , loss : 1.98937
# step 12700 , validation  accuracy 0.481337
# step 12700 , validation loss : 2.15065
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 12800
# step 12800 , training  accuracy 0.7
# step 12800 , loss : 1.97557
# step 12800 , validation  accuracy 0.508084
# step 12800 , validation loss : 2.12578
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 12900
# step 12900 , training  accuracy 0.633333
# step 12900 , loss : 1.98252
# step 12900 , validation  accuracy 0.506387
# step 12900 , validation loss : 2.12943
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 13000
# step 13000 , training  accuracy 0.633333
# step 13000 , loss : 2.04916
# step 13000 , validation  accuracy 0.497305
# step 13000 , validation loss : 2.1305
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 13100
# step 13100 , training  accuracy 0.533333
# step 13100 , loss : 2.07059
# step 13100 , validation  accuracy 0.493214
# step 13100 , validation loss : 2.14282
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 13200
# step 13200 , training  accuracy 0.666667
# step 13200 , loss : 2.01152
# step 13200 , validation  accuracy 0.516766
# step 13200 , validation loss : 2.12527
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 13300
# step 13300 , training  accuracy 0.766667
# step 13300 , loss : 1.94755
# step 13300 , validation  accuracy 0.51008
# step 13300 , validation loss : 2.12721
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 13400
# step 13400 , training  accuracy 0.7
# step 13400 , loss : 1.97205
# step 13400 , validation  accuracy 0.488024
# step 13400 , validation loss : 2.1382
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 13500
# step 13500 , training  accuracy 0.4
# step 13500 , loss : 2.18671
# step 13500 , validation  accuracy 0.508583
# step 13500 , validation loss : 2.13226
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 13600
# step 13600 , training  accuracy 0.6
# step 13600 , loss : 2.04745
# step 13600 , validation  accuracy 0.497106
# step 13600 , validation loss : 2.14491
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 13700
# step 13700 , training  accuracy 0.7
# step 13700 , loss : 1.98031
# step 13700 , validation  accuracy 0.50998
# step 13700 , validation loss : 2.13892
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 13800
# step 13800 , training  accuracy 0.666667
# step 13800 , loss : 2.02915
# step 13800 , validation  accuracy 0.514671
# step 13800 , validation loss : 2.12524
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 13900
# step 13900 , training  accuracy 0.766667
# step 13900 , loss : 1.93457
# step 13900 , validation  accuracy 0.508184
# step 13900 , validation loss : 2.13387
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 14000
# step 14000 , training  accuracy 0.733333
# step 14000 , loss : 1.98683
# step 14000 , validation  accuracy 0.49022
# step 14000 , validation loss : 2.15229
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 14100
# step 14100 , training  accuracy 0.5
# step 14100 , loss : 2.09028
# step 14100 , validation  accuracy 0.507485
# step 14100 , validation loss : 2.1299
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 14200
# step 14200 , training  accuracy 0.733333
# step 14200 , loss : 1.97114
# step 14200 , validation  accuracy 0.507784
# step 14200 , validation loss : 2.12787
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 14300
# step 14300 , training  accuracy 0.7
# step 14300 , loss : 1.98258
# step 14300 , validation  accuracy 0.507086
# step 14300 , validation loss : 2.13592
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 14400
# step 14400 , training  accuracy 0.8
# step 14400 , loss : 1.87795
# step 14400 , validation  accuracy 0.518064
# step 14400 , validation loss : 2.13059
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 14500
# step 14500 , training  accuracy 0.5
# step 14500 , loss : 2.07556
# step 14500 , validation  accuracy 0.514471
# step 14500 , validation loss : 2.12773
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 14600
# step 14600 , training  accuracy 0.566667
# step 14600 , loss : 1.99731
# step 14600 , validation  accuracy 0.51497
# step 14600 , validation loss : 2.13061
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 14700
# step 14700 , training  accuracy 0.566667
# step 14700 , loss : 2.07545
# step 14700 , validation  accuracy 0.520858
# step 14700 , validation loss : 2.13429
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 14800
# step 14800 , training  accuracy 0.733333
# step 14800 , loss : 1.94591
# step 14800 , validation  accuracy 0.524152
# step 14800 , validation loss : 2.12509
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 14900
# step 14900 , training  accuracy 0.7
# step 14900 , loss : 1.96329
# step 14900 , validation  accuracy 0.513174
# step 14900 , validation loss : 2.1354
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 15000
# step 15000 , training  accuracy 0.666667
# step 15000 , loss : 2.06342
# step 15000 , validation  accuracy 0.506387
# step 15000 , validation loss : 2.13089
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 15100
# step 15100 , training  accuracy 0.766667
# step 15100 , loss : 1.92865
# step 15100 , validation  accuracy 0.514471
# step 15100 , validation loss : 2.12726
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 15200
# step 15200 , training  accuracy 0.8
# step 15200 , loss : 1.9501
# step 15200 , validation  accuracy 0.518264
# step 15200 , validation loss : 2.13145
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 15300
# step 15300 , training  accuracy 0.533333
# step 15300 , loss : 2.11725
# step 15300 , validation  accuracy 0.499102
# step 15300 , validation loss : 2.13511
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 15400
# step 15400 , training  accuracy 0.766667
# step 15400 , loss : 1.97093
# step 15400 , validation  accuracy 0.50509
# step 15400 , validation loss : 2.13671
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 15500
# step 15500 , training  accuracy 0.666667
# step 15500 , loss : 2.04011
# step 15500 , validation  accuracy 0.515868
# step 15500 , validation loss : 2.12269
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 15600
# step 15600 , training  accuracy 0.666667
# step 15600 , loss : 2.0445
# step 15600 , validation  accuracy 0.4999
# step 15600 , validation loss : 2.13716
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 15700
# step 15700 , training  accuracy 0.633333
# step 15700 , loss : 2.03137
# step 15700 , validation  accuracy 0.515569
# step 15700 , validation loss : 2.13302
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 15800
# step 15800 , training  accuracy 0.7
# step 15800 , loss : 1.98726
# step 15800 , validation  accuracy 0.528743
# step 15800 , validation loss : 2.12982
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 15900
# step 15900 , training  accuracy 0.666667
# step 15900 , loss : 1.97267
# step 15900 , validation  accuracy 0.502295
# step 15900 , validation loss : 2.1441
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 16000
# step 16000 , training  accuracy 0.566667
# step 16000 , loss : 2.04036
# step 16000 , validation  accuracy 0.520958
# step 16000 , validation loss : 2.1326
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 16100
# step 16100 , training  accuracy 0.833333
# step 16100 , loss : 1.87116
# step 16100 , validation  accuracy 0.508283
# step 16100 , validation loss : 2.13492
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 16200
# step 16200 , training  accuracy 0.6
# step 16200 , loss : 2.00426
# step 16200 , validation  accuracy 0.508383
# step 16200 , validation loss : 2.13106
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 16300
# step 16300 , training  accuracy 0.733333
# step 16300 , loss : 1.97284
# step 16300 , validation  accuracy 0.515669
# step 16300 , validation loss : 2.13622
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 16400
# step 16400 , training  accuracy 0.466667
# step 16400 , loss : 2.14655
# step 16400 , validation  accuracy 0.516766
# step 16400 , validation loss : 2.13816
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 16500
# step 16500 , training  accuracy 0.666667
# step 16500 , loss : 1.9709
# step 16500 , validation  accuracy 0.527246
# step 16500 , validation loss : 2.12442
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 16600
# step 16600 , training  accuracy 0.8
# step 16600 , loss : 1.93804
# step 16600 , validation  accuracy 0.529142
# step 16600 , validation loss : 2.12448
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 16700
# step 16700 , training  accuracy 0.9
# step 16700 , loss : 1.853
# step 16700 , validation  accuracy 0.528343
# step 16700 , validation loss : 2.12711
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 16800
# step 16800 , training  accuracy 0.8
# step 16800 , loss : 1.87421
# step 16800 , validation  accuracy 0.515269
# step 16800 , validation loss : 2.13908
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 16900
# step 16900 , training  accuracy 0.9
# step 16900 , loss : 1.88037
# step 16900 , validation  accuracy 0.513673
# step 16900 , validation loss : 2.13024
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 17000
# step 17000 , training  accuracy 0.766667
# step 17000 , loss : 1.92293
# step 17000 , validation  accuracy 0.528343
# step 17000 , validation loss : 2.1296
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 17100
# step 17100 , training  accuracy 0.766667
# step 17100 , loss : 1.99323
# step 17100 , validation  accuracy 0.519561
# step 17100 , validation loss : 2.12861
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 17200
# step 17200 , training  accuracy 0.733333
# step 17200 , loss : 1.92641
# step 17200 , validation  accuracy 0.506487
# step 17200 , validation loss : 2.13638
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 17300
# step 17300 , training  accuracy 0.933333
# step 17300 , loss : 1.84586
# step 17300 , validation  accuracy 0.526747
# step 17300 , validation loss : 2.1316
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 17400
# step 17400 , training  accuracy 0.833333
# step 17400 , loss : 1.93012
# step 17400 , validation  accuracy 0.51976
# step 17400 , validation loss : 2.13066
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 17500
# step 17500 , training  accuracy 0.866667
# step 17500 , loss : 1.87978
# step 17500 , validation  accuracy 0.516367
# step 17500 , validation loss : 2.13675
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 17600
# step 17600 , training  accuracy 0.9
# step 17600 , loss : 1.85338
# step 17600 , validation  accuracy 0.515669
# step 17600 , validation loss : 2.12929
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 17700
# step 17700 , training  accuracy 0.866667
# step 17700 , loss : 1.89572
# step 17700 , validation  accuracy 0.51487
# step 17700 , validation loss : 2.14174
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 17800
# step 17800 , training  accuracy 0.866667
# step 17800 , loss : 1.84633
# step 17800 , validation  accuracy 0.520359
# step 17800 , validation loss : 2.14158
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 17900
# step 17900 , training  accuracy 0.633333
# step 17900 , loss : 2.00112
# step 17900 , validation  accuracy 0.519162
# step 17900 , validation loss : 2.13798
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 18000
# step 18000 , training  accuracy 0.933333
# step 18000 , loss : 1.84377
# step 18000 , validation  accuracy 0.516467
# step 18000 , validation loss : 2.13858
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 18100
# step 18100 , training  accuracy 0.966667
# step 18100 , loss : 1.81481
# step 18100 , validation  accuracy 0.511377
# step 18100 , validation loss : 2.14769
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 18200
# step 18200 , training  accuracy 0.766667
# step 18200 , loss : 1.91109
# step 18200 , validation  accuracy 0.519062
# step 18200 , validation loss : 2.13479
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 18300
# step 18300 , training  accuracy 0.833333
# step 18300 , loss : 1.86753
# step 18300 , validation  accuracy 0.509681
# step 18300 , validation loss : 2.14648
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 18400
# step 18400 , training  accuracy 0.966667
# step 18400 , loss : 1.82017
# step 18400 , validation  accuracy 0.518064
# step 18400 , validation loss : 2.13727
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 18500
# step 18500 , training  accuracy 0.966667
# step 18500 , loss : 1.82531
# step 18500 , validation  accuracy 0.526347
# step 18500 , validation loss : 2.13433
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 18600
# step 18600 , training  accuracy 0.8
# step 18600 , loss : 1.86831
# step 18600 , validation  accuracy 0.520459
# step 18600 , validation loss : 2.13523
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 18700
# step 18700 , training  accuracy 0.6
# step 18700 , loss : 2.04543
# step 18700 , validation  accuracy 0.518763
# step 18700 , validation loss : 2.13499
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 18800
# step 18800 , training  accuracy 0.733333
# step 18800 , loss : 1.93881
# step 18800 , validation  accuracy 0.508982
# step 18800 , validation loss : 2.13648
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 18900
# step 18900 , training  accuracy 0.566667
# step 18900 , loss : 2.03206
# step 18900 , validation  accuracy 0.52485
# step 18900 , validation loss : 2.13942
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 19000
# step 19000 , training  accuracy 0.8
# step 19000 , loss : 1.92558
# step 19000 , validation  accuracy 0.514172
# step 19000 , validation loss : 2.1429
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 19100
# step 19100 , training  accuracy 0.8
# step 19100 , loss : 1.90266
# step 19100 , validation  accuracy 0.506986
# step 19100 , validation loss : 2.14008
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 19200
# step 19200 , training  accuracy 0.833333
# step 19200 , loss : 1.8754
# step 19200 , validation  accuracy 0.511577
# step 19200 , validation loss : 2.14344
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 19300
# step 19300 , training  accuracy 0.9
# step 19300 , loss : 1.84583
# step 19300 , validation  accuracy 0.518463
# step 19300 , validation loss : 2.14195
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 19400
# step 19400 , training  accuracy 0.833333
# step 19400 , loss : 1.88481
# step 19400 , validation  accuracy 0.518762
# step 19400 , validation loss : 2.14451
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 19500
# step 19500 , training  accuracy 0.833333
# step 19500 , loss : 1.86612
# step 19500 , validation  accuracy 0.517066
# step 19500 , validation loss : 2.13836
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 19600
# step 19600 , training  accuracy 0.833333
# ...
# 93300
# step 93300 , training  accuracy 0.933333
# step 93300 , loss : 1.76924
# step 93300 , validation  accuracy 0.513273
# step 93300 , validation loss : 2.20908
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 93400
# step 93400 , training  accuracy 1
# step 93400 , loss : 1.71757
# step 93400 , validation  accuracy 0.515868
# step 93400 , validation loss : 2.20294
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 93500
# step 93500 , training  accuracy 1
# step 93500 , loss : 1.70036
# step 93500 , validation  accuracy 0.512475
# step 93500 , validation loss : 2.20305
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 93600
# step 93600 , training  accuracy 1
# step 93600 , loss : 1.70207
# step 93600 , validation  accuracy 0.513273
# step 93600 , validation loss : 2.21195
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 93700
# step 93700 , training  accuracy 0.9
# step 93700 , loss : 1.77634
# step 93700 , validation  accuracy 0.498104
# step 93700 , validation loss : 2.21206
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 93800
# step 93800 , training  accuracy 1
# step 93800 , loss : 1.70995
# step 93800 , validation  accuracy 0.507784
# step 93800 , validation loss : 2.20057
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 93900
# step 93900 , training  accuracy 0.966667
# step 93900 , loss : 1.71232
# step 93900 , validation  accuracy 0.511577
# step 93900 , validation loss : 2.20212
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 94000
# step 94000 , training  accuracy 0.966667
# step 94000 , loss : 1.74509
# step 94000 , validation  accuracy 0.515269
# step 94000 , validation loss : 2.19771
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 94100
# step 94100 , training  accuracy 0.966667
# step 94100 , loss : 1.72834
# step 94100 , validation  accuracy 0.503094
# step 94100 , validation loss : 2.21401
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 94200
# step 94200 , training  accuracy 1
# step 94200 , loss : 1.71467
# step 94200 , validation  accuracy 0.516866
# step 94200 , validation loss : 2.19798
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 94300
# step 94300 , training  accuracy 1
# step 94300 , loss : 1.71522
# step 94300 , validation  accuracy 0.507485
# step 94300 , validation loss : 2.20673
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 94400
# step 94400 , training  accuracy 0.966667
# step 94400 , loss : 1.74463
# step 94400 , validation  accuracy 0.506687
# step 94400 , validation loss : 2.20837
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 94500
# step 94500 , training  accuracy 1
# step 94500 , loss : 1.70444
# step 94500 , validation  accuracy 0.511876
# step 94500 , validation loss : 2.20023
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 94600
# step 94600 , training  accuracy 1
# step 94600 , loss : 1.70283
# step 94600 , validation  accuracy 0.511776
# step 94600 , validation loss : 2.20732
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 94700
# step 94700 , training  accuracy 0.966667
# step 94700 , loss : 1.71678
# step 94700 , validation  accuracy 0.521258
# step 94700 , validation loss : 2.19449
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 94800
# step 94800 , training  accuracy 0.966667
# step 94800 , loss : 1.72793
# step 94800 , validation  accuracy 0.505888
# step 94800 , validation loss : 2.20964
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 94900
# step 94900 , training  accuracy 1
# step 94900 , loss : 1.72271
# step 94900 , validation  accuracy 0.500299
# step 94900 , validation loss : 2.2241
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 95000
# step 95000 , training  accuracy 1
# step 95000 , loss : 1.70808
# step 95000 , validation  accuracy 0.515269
# step 95000 , validation loss : 2.18902
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 95100
# step 95100 , training  accuracy 0.966667
# step 95100 , loss : 1.72136
# step 95100 , validation  accuracy 0.507186
# step 95100 , validation loss : 2.21294
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 95200
# step 95200 , training  accuracy 1
# step 95200 , loss : 1.71079
# step 95200 , validation  accuracy 0.504691
# step 95200 , validation loss : 2.20657
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 95300
# step 95300 , training  accuracy 0.966667
# step 95300 , loss : 1.7475
# step 95300 , validation  accuracy 0.50509
# step 95300 , validation loss : 2.21797
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 95400
# step 95400 , training  accuracy 1
# step 95400 , loss : 1.71642
# step 95400 , validation  accuracy 0.515269
# step 95400 , validation loss : 2.20967
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 95500
# step 95500 , training  accuracy 0.966667
# step 95500 , loss : 1.74622
# step 95500 , validation  accuracy 0.51018
# step 95500 , validation loss : 2.21003
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 95600
# step 95600 , training  accuracy 1
# step 95600 , loss : 1.70658
# step 95600 , validation  accuracy 0.498104
# step 95600 , validation loss : 2.21593
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 95700
# step 95700 , training  accuracy 1
# step 95700 , loss : 1.69842
# step 95700 , validation  accuracy 0.500499
# step 95700 , validation loss : 2.21017
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 95800
# step 95800 , training  accuracy 0.966667
# step 95800 , loss : 1.71902
# step 95800 , validation  accuracy 0.494711
# step 95800 , validation loss : 2.21971
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 95900
# step 95900 , training  accuracy 0.933333
# step 95900 , loss : 1.75194
# step 95900 , validation  accuracy 0.513872
# step 95900 , validation loss : 2.21104
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 96000
# step 96000 , training  accuracy 1
# step 96000 , loss : 1.7216
# step 96000 , validation  accuracy 0.516168
# step 96000 , validation loss : 2.20829
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 96100
# step 96100 , training  accuracy 1
# step 96100 , loss : 1.71115
# step 96100 , validation  accuracy 0.501697
# step 96100 , validation loss : 2.21349
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 96200
# step 96200 , training  accuracy 1
# step 96200 , loss : 1.70064
# step 96200 , validation  accuracy 0.499701
# step 96200 , validation loss : 2.21835
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 96300
# step 96300 , training  accuracy 0.966667
# step 96300 , loss : 1.75455
# step 96300 , validation  accuracy 0.499202
# step 96300 , validation loss : 2.22563
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 96400
# step 96400 , training  accuracy 1
# step 96400 , loss : 1.71396
# step 96400 , validation  accuracy 0.494511
# step 96400 , validation loss : 2.22578
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 96500
# step 96500 , training  accuracy 0.9
# step 96500 , loss : 1.79551
# step 96500 , validation  accuracy 0.510579
# step 96500 , validation loss : 2.20665
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 96600
# step 96600 , training  accuracy 1
# step 96600 , loss : 1.69771
# step 96600 , validation  accuracy 0.506587
# step 96600 , validation loss : 2.22002
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 96700
# step 96700 , training  accuracy 1
# step 96700 , loss : 1.70252
# step 96700 , validation  accuracy 0.51018
# step 96700 , validation loss : 2.21
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 96800
# step 96800 , training  accuracy 0.966667
# step 96800 , loss : 1.72577
# step 96800 , validation  accuracy 0.50479
# step 96800 , validation loss : 2.21408
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 96900
# step 96900 , training  accuracy 1
# step 96900 , loss : 1.72229
# step 96900 , validation  accuracy 0.50489
# step 96900 , validation loss : 2.20746
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 97000
# step 97000 , training  accuracy 0.933333
# step 97000 , loss : 1.77453
# step 97000 , validation  accuracy 0.512375
# step 97000 , validation loss : 2.2085
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 97100
# step 97100 , training  accuracy 0.966667
# step 97100 , loss : 1.73165
# step 97100 , validation  accuracy 0.510479
# step 97100 , validation loss : 2.21333
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 97200
# step 97200 , training  accuracy 0.966667
# step 97200 , loss : 1.72329
# step 97200 , validation  accuracy 0.503293
# step 97200 , validation loss : 2.21
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 97300
# step 97300 , training  accuracy 0.866667
# step 97300 , loss : 1.80512
# step 97300 , validation  accuracy 0.503593
# step 97300 , validation loss : 2.21165
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 97400
# step 97400 , training  accuracy 1
# step 97400 , loss : 1.69861
# step 97400 , validation  accuracy 0.503194
# step 97400 , validation loss : 2.21141
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 97500
# step 97500 , training  accuracy 1
# step 97500 , loss : 1.70685
# step 97500 , validation  accuracy 0.503094
# step 97500 , validation loss : 2.21199
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 97600
# step 97600 , training  accuracy 0.966667
# step 97600 , loss : 1.76194
# step 97600 , validation  accuracy 0.510479
# step 97600 , validation loss : 2.21492
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 97700
# step 97700 , training  accuracy 1
# step 97700 , loss : 1.71972
# step 97700 , validation  accuracy 0.507086
# step 97700 , validation loss : 2.21656
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 97800
# step 97800 , training  accuracy 1
# step 97800 , loss : 1.71165
# step 97800 , validation  accuracy 0.506487
# step 97800 , validation loss : 2.21161
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 97900
# step 97900 , training  accuracy 1
# step 97900 , loss : 1.70926
# step 97900 , validation  accuracy 0.513573
# step 97900 , validation loss : 2.20901
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 98000
# step 98000 , training  accuracy 0.966667
# step 98000 , loss : 1.73089
# step 98000 , validation  accuracy 0.500998
# step 98000 , validation loss : 2.20408
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 98100
# step 98100 , training  accuracy 1
# step 98100 , loss : 1.71315
# step 98100 , validation  accuracy 0.501198
# step 98100 , validation loss : 2.22397
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 98200
# step 98200 , training  accuracy 0.966667
# step 98200 , loss : 1.72556
# step 98200 , validation  accuracy 0.50499
# step 98200 , validation loss : 2.21411
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 98300
# step 98300 , training  accuracy 1
# step 98300 , loss : 1.69944
# step 98300 , validation  accuracy 0.498004
# step 98300 , validation loss : 2.22167
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 98400
# step 98400 , training  accuracy 1
# step 98400 , loss : 1.71443
# step 98400 , validation  accuracy 0.506886
# step 98400 , validation loss : 2.21506
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 98500
# step 98500 , training  accuracy 0.933333
# step 98500 , loss : 1.74841
# step 98500 , validation  accuracy 0.507784
# step 98500 , validation loss : 2.21506
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 98600
# step 98600 , training  accuracy 1
# step 98600 , loss : 1.71063
# step 98600 , validation  accuracy 0.509481
# step 98600 , validation loss : 2.22039
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 98700
# step 98700 , training  accuracy 1
# step 98700 , loss : 1.70799
# step 98700 , validation  accuracy 0.511976
# step 98700 , validation loss : 2.22211
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 98800
# step 98800 , training  accuracy 0.966667
# step 98800 , loss : 1.73467
# step 98800 , validation  accuracy 0.501896
# step 98800 , validation loss : 2.21469
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 98900
# step 98900 , training  accuracy 0.933333
# step 98900 , loss : 1.77203
# step 98900 , validation  accuracy 0.501896
# step 98900 , validation loss : 2.21069
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 99000
# step 99000 , training  accuracy 1
# step 99000 , loss : 1.70292
# step 99000 , validation  accuracy 0.511577
# step 99000 , validation loss : 2.20953
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 99100
# step 99100 , training  accuracy 1
# step 99100 , loss : 1.70537
# step 99100 , validation  accuracy 0.500699
# step 99100 , validation loss : 2.22438
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 99200
# step 99200 , training  accuracy 1
# step 99200 , loss : 1.70058
# step 99200 , validation  accuracy 0.513373
# step 99200 , validation loss : 2.2154
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 99300
# step 99300 , training  accuracy 1
# step 99300 , loss : 1.70039
# step 99300 , validation  accuracy 0.509681
# step 99300 , validation loss : 2.20917
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 99400
# step 99400 , training  accuracy 0.966667
# step 99400 , loss : 1.73144
# step 99400 , validation  accuracy 0.508383
# step 99400 , validation loss : 2.20514
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 99500
# step 99500 , training  accuracy 0.966667
# step 99500 , loss : 1.73267
# step 99500 , validation  accuracy 0.515768
# step 99500 , validation loss : 2.20505
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 99600
# step 99600 , training  accuracy 0.966667
# step 99600 , loss : 1.74193
# step 99600 , validation  accuracy 0.493114
# step 99600 , validation loss : 2.22509
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 99700
# step 99700 , training  accuracy 1
# step 99700 , loss : 1.70189
# step 99700 , validation  accuracy 0.50978
# step 99700 , validation loss : 2.2108
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 99800
# step 99800 , training  accuracy 0.966667
# step 99800 , loss : 1.72679
# step 99800 , validation  accuracy 0.514371
# step 99800 , validation loss : 2.2055
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# 99900
# step 99900 , training  accuracy 1
# step 99900 , loss : 1.70885
# step 99900 , validation  accuracy 0.510778
# step 99900 , validation loss : 2.20887
# --- Training Time : 4611.03522801 ---
# Tensor("accuracy_3/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:0)
# test accuracy 0.532634735107 , test loss 2.19732928276
