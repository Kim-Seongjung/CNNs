# %%
#conv Neural Network
# tensorboard --logdir=/home/ncc/notebook/learn/tensorboard/log
"""
created by kim Seong jung

"""
import numpy as np 
import tensorflow as tf
import re
import random
import math
import time
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %% [markdown]
# # Load Image

# %% [markdown]
# # load Training , Validation , Test

# %%
in_ch =3
n_classes=10
img_row=32
img_col=32

# %%
with tf.device('/gpu:0'):
    def next_batch(batch_size , image , label):

        a=np.random.randint(np.shape(image)[0] -batch_size)
        batch_x = image[a:a+batch_size,:]
        batch_y= label[a:a+batch_size,:]
        return batch_x, batch_y

# %% [markdown]
# # define Variable , and placeholder

# %%
x_= tf.placeholder("float",shape=[None,img_row , img_col , in_ch],  name = 'x-input')
y_= tf.placeholder("float",shape=[None , n_classes] , name = 'y-input')
keep_prob = tf.placeholder("float")
x_image= tf.reshape(x_,[-1,img_row,img_col,in_ch])

# %%
"""def weight_variable(name,shape):
    #initial = tf.truncated_normal(shape , stddev=0.1)
    initial = tf.get_variable(name,shape=shape , initializer = tf.contrib.layers.xavier_initializer())
    return tf.Variable(initial)"""
def bias_variable(shape , name):
    initial = tf.constant(0.1 , shape=shape , )
    return tf.Variable(initial , name=name)

def conv2d(x,w,strides_ , name):
    return tf.nn.conv2d(x,w, strides = strides_, padding='SAME' , name = name)

def max_pool(x , ksize , strides , padding , name ):
    return tf.nn.max_pool(x ,ksize , strides , padding ,name=name)
def make_weights_biases(layer_name , w_name , b_name,ksize ,device_name,initializer='xavier'):
    if len(ksize)==4: # convolution filter shape [batch , row , col , color_ch]
        out_ch=ksize[3]
    elif len(ksize)==2: #fully connected layer shape [in_ch , output_ch]
        out_ch=ksize[1]
    with tf.device(device_name):
        with tf.variable_scope(layer_name) as scope:
            try:
                w_conv = tf.get_variable(w_name, ksize , initializer = tf.contrib.layers.xavier_initializer())
            except:
                scope.reuse_variables()
                w_conv = tf.get_variable(w_name, ksize , initializer = tf.contrib.layers.xavier_initializer())
        
            try:
                b_conv = bias_variable([out_ch] , name=b_name)
            except:
                scope.reuse_variables()
                b_conv = bias_variable([out_ch],name=b_name)
    return w_conv , b_conv

# %%
def STEM_A(x , device_):
    with tf.device(device_):
        in_ch=x.get_shape()[3]
        out_ch1=32 ; out_ch2=32;out_ch3=64;out_ch4=96;

        
        c_ksize1=[3,3,in_ch , out_ch1]
        c_ksize2=[3,3,out_ch1 , out_ch2]
        c_ksize3=[3,3,out_ch2 , out_ch3]
        c_ksize4=[3,3,out_ch3 , out_ch4]
        w_conv1 , b_conv1 =make_weights_biases('STEM_A_1' , 'W1' ,'B1', c_ksize1 ,device_name = device_)
        w_conv2 , b_conv2= make_weights_biases('STEM_A_2' , 'W2' ,'B2',c_ksize2 ,device_name = device_)
        w_conv3 , b_conv3= make_weights_biases('STEM_A_3' , 'W3' ,'B3' ,c_ksize3 ,device_name = device_)
        w_conv4 , b_conv4= make_weights_biases('STEM_A_4' , 'W4' ,'B4', c_ksize4 ,device_name = device_)

        
        c_strides1=[1,2,2,1]
        c_strides2=[1,1,1,1]
        c_strides3=[1,1,1,1]
        c_strides4=[1,2,2,1]

        
        c_pooling1='VALID'
        c_pooling2='VALID'
        c_pooling3='SAME'
        c_pooling4='VALID'

        b_p_ksize4=[1,3,3,1]
        b_p_strides4=[1,2,2,1]
        b_p_padding4 ='VALID'

        with tf.variable_scope('STEM_A_layer1') as scope:
            layer1=tf.nn.conv2d(    x ,      w_conv1, c_strides1, c_pooling1 ,name='layer1'  )+b_conv1
            layer1_relu=tf.nn.relu(layer1,name='layer1_relu')
        with tf.variable_scope('STEM_A_layer2') as scope:
            layer2=tf.nn.conv2d(    layer1_relu , w_conv2, c_strides2, c_pooling2,name='layer2'  )+b_conv2
            layer2_relu=tf.nn.relu(layer2,name='layer2_relu')
        with tf.variable_scope('STEM_A_layer3') as scope:
            layer3=tf.nn.conv2d(    layer2_relu , w_conv3, c_strides3, c_pooling3,name='layer3'  )+b_conv3
            layer3_relu=tf.nn.relu(layer3 , name='layer3_relu')
        with tf.variable_scope('STEM_A_layer4') as scope:
            layer4=tf.nn.conv2d(    layer3_relu , w_conv4, c_strides4, c_pooling4 ,name='layer4' )+b_conv4
            layer4_relu=tf.nn.relu(layer4,name='layer4_relu')


        with tf.variable_scope('STEM_A_layer') as scope:
            b_layer4=tf.nn.max_pool(layer3 , b_p_ksize4, b_p_strides4, b_p_padding4 ,name='b_layer4') #b is branch
            b_layer4_relu=tf.nn.relu(b_layer4 , name = 'b_layer_relu')
        print layer1
        print layer2
        print layer3
        print layer4
        print b_layer4


        concat_layer=tf.concat(3 , [layer4_relu , b_layer4_relu] , name='CONCAT')
        return concat_layer

# %%
def STEM_B( x , device_):
    with tf.device(device_):

        in_ch=x.get_shape()[3]
        #########################################################################
        out_ch1=64 ; out_ch2=64;out_ch3=64;out_ch4=96;
        ##############################right side##################################
        c_ksize1=[1,1,in_ch , out_ch1]
        c_ksize2=[7,1,out_ch1 , out_ch2]
        c_ksize3=[1,7,out_ch2 , out_ch3]
        c_ksize4=[3,3,out_ch3 , out_ch4]

        w_conv1 , b_conv1 =make_weights_biases('STEM_B_1' , 'W1' ,'B1', c_ksize1 ,device_name = device_)
        w_conv2 , b_conv2= make_weights_biases('STEM_B_2' , 'W2' ,'B2',c_ksize2 ,device_name = device_)
        w_conv3 , b_conv3= make_weights_biases('STEM_B_3' , 'W3' ,'B3' ,c_ksize3 ,device_name = device_)
        w_conv4 , b_conv4= make_weights_biases('STEM_B_4' , 'W4' ,'B4', c_ksize4 ,device_name = device_)


        c_strides1=[1,1,1,1]
        c_strides2=[1,1,1,1]
        c_strides3=[1,1,1,1]
        c_strides4=[1,1,1,1]

        c_pooling1='SAME'
        c_pooling2='SAME'
        c_pooling3='SAME'
        c_pooling4='VALID'
        
        with tf.variable_scope('STEM_B_conv1') as scope:
            layer1 = tf.nn.conv2d(x ,      w_conv1 , c_strides1 , c_pooling1 ,name='STEM_B_layer1')+b_conv1
            layer1 = tf.nn.relu(layer1,name='STEM_B_layer1_relu')
        with tf.variable_scope('STEM_B_conv1') as scope:
            layer2 = tf.nn.conv2d(layer1 , w_conv2 , c_strides2 , c_pooling2 , name='STEM_B_layer2')+b_conv2
            layer2 = tf.nn.relu(layer2,name='STEM_B_layer2_relu')
        with tf.variable_scope('STEM_B_conv1') as scope:
            layer3 = tf.nn.conv2d(layer2 , w_conv3 , c_strides3 , c_pooling3,name='STEM_B_layer3')+b_conv3
            layer3 = tf.nn.relu(layer3,name='STEM_B_layer3_relu')
        with tf.variable_scope('STEM_B_conv1') as scope:
            layer4 = tf.nn.conv2d(layer3 , w_conv4 , c_strides4 , c_pooling4,name='STEM_B_layer4')+b_conv4
            layer4 = tf.nn.relu(layer4,name='STEM_B_layer4_relu')

        ##############################left side##################################
        b_out_ch1=64 ; b_out_ch2=96;    
        #########################################################################
        b_c_ksize1=[1,1,in_ch , b_out_ch1]
        b_c_ksize2=[3,3,b_out_ch1 , b_out_ch2]
 
        b_w_conv1 , b_b_conv1 =make_weights_biases('STEM_B_b_1' , 'b_W1' , 'b_B1',b_c_ksize1 ,device_name = device_)
        b_w_conv2 , b_b_conv2= make_weights_biases('STEM_B_b_2' , 'b_W2' , 'b_B2',b_c_ksize2 ,device_name = device_)

        b_c_strides1=[1,1,1,1]
        b_c_strides2=[1,1,1,1]

        b_c_pooling1='SAME'
        b_c_pooling2='VALID'
        with tf.variable_scope('STEM_B_b_conv1') as scope:
            b_layer1 =tf.nn.conv2d(    x ,      b_w_conv1, b_c_strides1, b_c_pooling1,name='STEM_B_b_layer1'  ) + b_b_conv1
            b_layer1 = tf.nn.relu(b_layer1,name='STEM_B_b_layer1_relu')
        with tf.variable_scope('STEM_B_b_conv2') as scope:
            b_layer2=tf.nn.conv2d(  b_layer1 , b_w_conv2, b_c_strides2, b_c_pooling2,name='STEM_B_b_layer2'  ) + b_b_conv2
            b_layer2= tf.nn.relu(b_layer2 , name='STEM_B_b_layer2_relu')
        ##############################concatenate layers###########################
        concat_layer=tf.concat(3 , [layer4 , b_layer2] , name="STEM_B_CONCAT")
        ret_layer=concat_layer
    return ret_layer

# %%
def STEM_C( x , device_ ):
    with tf.device(device_):
        in_ch=x.get_shape()[3]
        #########################################################################

        out_ch = 192


        c_ksize=[3,3,in_ch,out_ch]
        w_conv , b_conv =make_weights_biases('STEM_C' , 'W1' , c_ksize ,device_name = device_)
        c_strides=[1,1,1,1]
        c_pooling='SAME'

        layer = tf.nn.conv2d(x , w_conv   , c_strides   , c_pooling)+b_conv
        layer = tf.nn.relu(layer)
        
        #########################################################################
        
        b_p_ksize=[1,2,2,1]
        b_p_strides=[1,1,1,1]
        b_p_pooling='SAME'

        b_layer = tf.nn.max_pool(x , b_p_ksize , b_p_strides , b_p_pooling)
        b_layer = tf.nn.relu(b_layer)
        #########################################################################

        print layer
        print b_layer

        concat_layer=tf.concat(3,[layer , b_layer])
        ret_layer = concat_layer
    return ret_layer

# %%
def FLAT(x):
    
    row=int(x.get_shape()[1])
    col=int(x.get_shape()[2])
    ch=int(x.get_shape()[3])
    
    res_x = tf.reshape(x , shape=[-1,row*col*ch] ,name='flat_layer');
    return res_x
    #connect fully connected layer

# %%
def FC_A(x , n_classes , device_ ,dropout_rate):
    with tf.device(device_):
    
        fully_ch1=1024; fully_ch2=1024

        fc_ksize1=[x.get_shape()[1],fully_ch1]
        fc_ksize2=[fully_ch1,fully_ch2]

        w_fc1 ,b_fc1 = make_weights_biases('fc1' , 'fc_W1' ,'fc_B1' ,fc_ksize1 ,  device_)
        w_fc2 ,b_fc2 = make_weights_biases('fc2' , 'fc_W2' ,'fc_B2' ,fc_ksize2 ,  device_)
    
        h_fc1=tf.matmul(x, w_fc1 ,name='h_fc1')+b_fc1
        h_fc1=tf.nn.dropout(h_fc1 , dropout_rate , name='h_fc1_dropout')
        h_fc2=tf.matmul(h_fc1 , w_fc2 ,name='h_fc2')+b_fc2
        h_fc2=tf.nn.dropout(h_fc2 , dropout_rate,name='h_fc2_dropout')
        end_fc=h_fc2

        end_ksize=[end_fc.get_shape()[1] , n_classes]   
        w_end ,b_end = make_weights_biases('fc_end' , 'fc_end_W' , 'fc_end_B' ,end_ksize ,  device_)
        y_conv = tf.matmul(end_fc , w_end)+b_end

        print w_fc1.get_shape()
    return y_conv

# %%
def FC_B(x , n_classes , device_ ):
    with tf.device(device_):

        end_ksize=[x.get_shape()[1] , n_classes]   
        w_end ,b_end = make_weights_biases('fc_end' , 'fc_end_W','fc_end_B' , end_ksize ,  device_)
        y_conv = tf.matmul(x , w_end)+b_end

   
    return y_conv

# %%
def MAX_POOLING():
    """
    pooling :  
    
    """

# %%
def AVG_POOLING():
    """
    pooling 
    
    """

# %%
def CONV_6(x , device_ , layer_name , n_nodes , kernel_size ,strides ,pooling):
    """ 
    k_row=kernel_size[0]  
    k_col=kernel_size[0] 
    
    """
    in_ch = x.get_shape()[3]
    k_row=kernel_size[0]  
    k_col=kernel_size[1] 
    
    
    out_ch1=n_nodes
    out_ch2=n_nodes
    out_ch3=n_nodes
    out_ch4=n_nodes
    out_ch5=n_nodes
    out_ch6=n_nodes
    
    c_ksize1=[k_row,k_col , in_ch   , out_ch1]
    c_ksize2=[k_row,k_col , out_ch1 , out_ch2]
    c_ksize3=[k_row,k_col , out_ch2 , out_ch3]
    c_ksize4=[k_row,k_col , out_ch3 , out_ch4]
    c_ksize5=[k_row,k_col , out_ch4 , out_ch5]
    c_ksize6=[k_row,k_col , out_ch5 , out_ch6]
    
    c_strides1=strides
    c_strides2=strides
    c_strides3=strides
    c_strides4=strides
    c_strides5=strides
    c_strides6=strides
    
    c_pooling1=pooling
    c_pooling2=pooling
    c_pooling3=pooling
    c_pooling4=pooling
    c_pooling5=pooling
    c_pooling6=pooling
    
    w_conv1 , b_conv1 =make_weights_biases(layer_name+str(1), 'W1' ,'B1', c_ksize1 ,device_name = device_)
    w_conv2 , b_conv2= make_weights_biases(layer_name+str(2), 'W2' ,'B2',c_ksize2 ,device_name = device_)
    w_conv3 , b_conv3= make_weights_biases(layer_name+str(3) , 'W3' ,'B3' ,c_ksize3 ,device_name = device_)
    w_conv4 , b_conv4= make_weights_biases(layer_name+str(4) , 'W4' ,'B4', c_ksize4 ,device_name = device_)
    w_conv5 , b_conv5= make_weights_biases(layer_name+str(5) , 'W5' ,'B5', c_ksize5 ,device_name = device_)
    w_conv6 , b_conv6= make_weights_biases(layer_name+str(6) , 'W6' ,'B6', c_ksize5 ,device_name = device_)

    with tf.variable_scope(layer_name+'conv1') as scope:
        layer1 = tf.nn.conv2d(x ,      w_conv1 , c_strides1 , c_pooling1 ,name='layer1')+b_conv1
        layer1 = tf.nn.relu(layer1,name='layer1_relu')
    with tf.variable_scope(layer_name+'conv2') as scope:
        layer2 = tf.nn.conv2d(layer1 , w_conv2 , c_strides2 , c_pooling2 , name='layer2')+b_conv2
        layer2 = tf.nn.relu(layer2,name='layer2_relu')
    with tf.variable_scope(layer_name+'conv2') as scope:
        layer3 = tf.nn.conv2d(layer2 , w_conv3 , c_strides3 , c_pooling3,name='layer3')+b_conv3
        layer3 = tf.nn.relu(layer3,name='layer3_relu')
    with tf.variable_scope(layer_name+'conv4') as scope:
        layer4 = tf.nn.conv2d(layer3 , w_conv4 , c_strides4 , c_pooling4,name='layer4')+b_conv4
        layer4 = tf.nn.relu(layer4,name='layer4_relu')
    with tf.variable_scope(layer_name+'conv5') as scope:
        layer5 = tf.nn.conv2d(layer4 , w_conv5 , c_strides5 , c_pooling5,name='layer5')+b_conv5
        layer5 = tf.nn.relu(layer5,name='layer5_relu')
    with tf.variable_scope(layer_name+'conv6') as scope:
        layer6 = tf.nn.conv2d(layer5 , w_conv6 , c_strides6 , c_pooling6,name='layer6')+b_conv6
        layer6 = tf.nn.relu(layer5,name='layer6_relu')

    return layer6

# %%
def CONV_5(x , device_ , layer_name , n_nodes , kernel_size ,strides ,pooling):
    """ 
    k_row=kernel_size[0]  
    k_col=kernel_size[0] 
    
    """
    in_ch = x.get_shape()[3]
    k_row=kernel_size[0]  
    k_col=kernel_size[1] 
    
    
    out_ch1=n_nodes
    out_ch2=n_nodes
    out_ch3=n_nodes
    out_ch4=n_nodes
    out_ch5=n_nodes
    
    c_ksize1=[k_row,k_col , in_ch   , out_ch1]
    c_ksize2=[k_row,k_col , out_ch1 , out_ch2]
    c_ksize3=[k_row,k_col , out_ch2 , out_ch3]
    c_ksize4=[k_row,k_col , out_ch3 , out_ch4]
    c_ksize5=[k_row,k_col , out_ch4 , out_ch5]
    
    c_strides1=strides
    c_strides2=strides
    c_strides3=strides
    c_strides4=strides
    c_strides5=strides
    
    c_pooling1=pooling
    c_pooling2=pooling
    c_pooling3=pooling
    c_pooling4=pooling
    c_pooling5=pooling
    
    w_conv1 , b_conv1 =make_weights_biases(layer_name+str(1), 'W1' ,'B1' , c_ksize1 ,device_name = device_)
    w_conv2 , b_conv2= make_weights_biases(layer_name+str(2), 'W2' ,'B2' , c_ksize2 ,device_name = device_)
    w_conv3 , b_conv3= make_weights_biases(layer_name+str(3), 'W3' ,'B3' , c_ksize3 ,device_name = device_)
    w_conv4 , b_conv4= make_weights_biases(layer_name+str(4), 'W4' ,'B4' , c_ksize4 ,device_name = device_)
    w_conv5 , b_conv5= make_weights_biases(layer_name+str(5), 'W5' ,'B5' , c_ksize5 ,device_name = device_)

    with tf.variable_scope(layer_name+'conv1') as scope:
        layer1 = tf.nn.conv2d(x ,      w_conv1 , c_strides1 , c_pooling1 ,name='layer1')+b_conv1
        layer1 = tf.nn.relu(layer1,name='layer1_relu')
    with tf.variable_scope(layer_name+'conv2') as scope:
        layer2 = tf.nn.conv2d(layer1 , w_conv2 , c_strides2 , c_pooling2 , name='layer2')+b_conv2
        layer2 = tf.nn.relu(layer2,name='layer2_relu')
    with tf.variable_scope(layer_name+'conv2') as scope:
        layer3 = tf.nn.conv2d(layer2 , w_conv3 , c_strides3 , c_pooling3,name='layer3')+b_conv3
        layer3 = tf.nn.relu(layer3,name='layer3_relu')
    with tf.variable_scope(layer_name+'conv4') as scope:
        layer4 = tf.nn.conv2d(layer3 , w_conv4 , c_strides4 , c_pooling4,name='layer4')+b_conv4
        layer4 = tf.nn.relu(layer4,name='layer4_relu')
    with tf.variable_scope(layer_name+'conv5') as scope:
        layer5 = tf.nn.conv2d(layer4 , w_conv5 , c_strides5 , c_pooling5,name='layer5')+b_conv5
        layer5 = tf.nn.relu(layer5,name='layer4_relu')

    return layer5

# %%
def CONV_3(x , device_ , layer_name , n_nodes , kernel_size ,strides,pooling):
    """
    c_ksize1=[k_row,k_col , in_ch   , out_ch1]
    c_ksize2=[k_row,k_col , out_ch1 , out_ch2]
    c_ksize3=[k_row,k_col , out_ch2 , out_ch3]
    """
    
    in_ch = x.get_shape()[3]
    k_row=kernel_size[0]  
    k_col=kernel_size[1]     
    
    c_ksize1=[k_row,k_col , in_ch   , n_nodes]
    c_ksize2=[k_row,k_col , n_nodes , n_nodes]
    c_ksize3=[k_row,k_col , n_nodes , n_nodes]
    
    c_strides1=strides
    c_strides2=strides
    c_strides3=strides
        
    c_pooling1=pooling
    c_pooling2=pooling
    c_pooling3=pooling
    
    w_conv1 , b_conv1 =make_weights_biases(layer_name+str(1) , 'W1' ,'B1', c_ksize1 ,device_name = device_)
    w_conv2 , b_conv2= make_weights_biases(layer_name+str(2) , 'W2' ,'B2',c_ksize2 ,device_name = device_)
    w_conv3 , b_conv3= make_weights_biases(layer_name+str(3) , 'W3' ,'B3' ,c_ksize3 ,device_name = device_)
    
    with tf.variable_scope(layer_name+'conv1') as scope:
        layer1 = tf.nn.conv2d(x ,      w_conv1 , c_strides1 , c_pooling1 ,name='layer1')+b_conv1
        layer1 = tf.nn.relu(layer1,name='layer1_relu')
    with tf.variable_scope(layer_name+'conv2') as scope:
        layer2 = tf.nn.conv2d(layer1 , w_conv2 , c_strides2 , c_pooling2 , name='layer2')+b_conv2
        layer2 = tf.nn.relu(layer2,name='layer2_relu')
    with tf.variable_scope(layer_name+'conv2') as scope:
        layer3 = tf.nn.conv2d(layer2 , w_conv3 , c_strides3 , c_pooling3,name='layer3')+b_conv3
        layer3 = tf.nn.relu(layer3,name='layer3_relu')
    return layer3

# %%
def CONV_1(x , device_ , layer_name , n_nodes , kernel_size ,strides,pooling):
    """
    c_ksize1=[k_row,k_col , in_ch   , out_ch1]
    c_ksize2=[k_row,k_col , out_ch1 , out_ch2]
    c_ksize3=[k_row,k_col , out_ch2 , out_ch3]
    """
    
    in_ch = x.get_shape()[3]
    k_row=kernel_size[0]  
    k_col=kernel_size[1]     
    
    c_ksize1=[k_row,k_col , in_ch   , n_nodes]
    c_strides1=strides        
    c_pooling1=pooling
    
    w_conv1 , b_conv1 =make_weights_biases(layer_name+str(1) , 'W1' ,'B1', c_ksize1 ,device_name = device_)
    
    with tf.variable_scope(layer_name+'conv1') as scope:
        layer1 = tf.nn.conv2d(x ,      w_conv1 , c_strides1 , c_pooling1 ,name='layer1')+b_conv1
        layer1 = tf.nn.relu(layer1,name='layer1_relu')
    return layer1

# %%
def INCEPTION_MODULE_A(x , device_ , layer_name = 'INCEPTION_MODULE_A'):

    """
    input X shape is [n_batch , row , col, out_ch]
    35 x 35 grid
    """

    #################################################################################
    in_ch=x.get_shape()[3]
    print x.get_shape()
    out_ch1=64 ; out_ch2= 96;
    c_ksize1 = [1 , 1 ,in_ch , out_ch1 ]
    c_ksize2 = [3 , 3 ,out_ch1 , out_ch2 ]
    w_conv1 , b_conv1 = make_weights_biases (layer_name , 'W1' , c_ksize1 ,device_)
    w_conv2 , b_conv2 = make_weights_biases(layer_name ,'W2' , c_ksize2 ,device_)

    c_strides1=[1,1,1,1]
    c_strides2=[1,1,1,1]
    
    c_pooling1='SAME'
    c_pooling2='SAME'
    layer1 = tf.nn.conv2d(x , w_conv1 , c_strides1 ,c_pooling1 )
    layer2 = tf.nn.conv2d(layer1 , w_conv2 , c_strides2 ,c_pooling2 )

    #################################################################################                     

    b1_p_ksize   =[1,2,2,1]
    b1_p_strides =[1,1,1,1]
    b1_p_pooling='SAME'


    b1_out_ch = 96;
    b1_c_ksize  =[1,1, in_ch , b1_out_ch]
    b1_c_strides=[1,1,1,1]
    b1_c_pooling ='SAME'

    b1_w_conv , b1_b_conv =make_weights_biases(layer_name,'b1_W',b1_c_ksize , device_)


    b1_layer1=tf.nn.avg_pool(x, b1_p_ksize , b1_p_strides,b1_p_pooling )
    b1_layer1=tf.nn.relu(b1_layer1)
    b1_layer2=tf.nn.conv2d(b1_layer1 , b1_w_conv , b1_c_strides , b1_c_pooling)+b1_b_conv
    b1_layer2=tf.nn.relu(b1_layer2)

    #################################################################################                     

    b2_out_ch=96
    b2_c_ksize = [1,1,in_ch , b2_out_ch ]
    b2_w_conv , b2_b_conv = make_weights_biases(layer_name,'b2_W',b2_c_ksize , device_)
    b2_c_strides=[1,1,1,1]
    b2_c_pooling='SAME'

    b2_layer = tf.nn.conv2d( x, b2_w_conv , b2_c_strides ,b2_c_pooling ) +b2_b_conv 
    b2_layer = tf.nn.relu(b2_layer)



    #################################################################################                     


    b3_out_ch1=64;b3_out_ch2=96;b3_out_ch3=96;
    b3_c_ksize1 =[1,1,in_ch , b3_out_ch1]
    b3_c_ksize2 =[3,3,b3_out_ch1 , b3_out_ch2]
    b3_c_ksize3 =[3,3,b3_out_ch2 , b3_out_ch3]
    b3_w_conv1 , b3_b_conv1 = make_weights_biases(layer_name,'b3_W1',b3_c_ksize1 , device_)
    b3_w_conv2 , b3_b_conv2 = make_weights_biases(layer_name,'b3_W2',b3_c_ksize2 , device_)
    b3_w_conv3 , b3_b_conv3 = make_weights_biases(layer_name,'b3_W3',b3_c_ksize3 , device_)
    b3_c_strides1=[1,1,1,1]
    b3_c_strides2=[1,1,1,1]
    b3_c_strides3=[1,1,1,1]
    b3_c_pooling1='SAME'
    b3_c_pooling2='SAME'
    b3_c_pooling3='SAME'

    b3_layer1 = tf.nn.conv2d(x , b3_w_conv1 , b3_c_strides1 ,b3_c_pooling1)+b3_b_conv1 
    b3_layer1 = tf.nn.relu(b3_layer1)
    b3_layer2 = tf.nn.conv2d(b3_layer1 , b3_w_conv2 , b3_c_strides2 ,b3_c_pooling2)+b3_b_conv2 
    b3_layer2 = tf.nn.relu(b3_layer2)
    b3_layer3 = tf.nn.conv2d(b3_layer2 , b3_w_conv3 , b3_c_strides3 ,b3_c_pooling3)+b3_b_conv3 
    b3_layer3 = tf.nn.relu(b3_layer3)

    #################################################################################                     
    concat_A=tf.concat(3,[layer2 , b1_layer2])
    concat_B=tf.concat(3,[concat_A , b2_layer])
    concat_C=tf.concat(3,[concat_B , b3_layer3])

    return concat_C

    #################################################################################

# %%
def INCEPTION_MODULE_B(x , device ,layer_name='INCEPTION_MODULE_B'):

    """
    for 17 X 17 grid 
    """
    in_ch =x.get_shape()[3]
    out_ch1 =192 ; out_ch2=224; out_ch3 =256
    c_ksize1 = [1,1, in_ch  ,out_ch1]
    c_ksize2 = [1,7, out_ch1,out_ch2]
    c_ksize3 = [7,1, out_ch2,out_ch3]

    w_conv1 , b_conv1 =make_weights_biases( layer_name,'W1' ,  c_ksize1 , device)
    w_conv2 , b_conv2 =make_weights_biases( layer_name ,'W2' ,  c_ksize2 , device)
    w_conv3 , b_conv3 =make_weights_biases( layer_name ,'W3' ,  c_ksize3 , device)
    
    c_strides1 =[1,1,1,1]
    c_strides2 =[1,1,1,1]
    c_strides3 =[1,1,1,1]
    
    c_pooling1 ='SAME'
    c_pooling2 ='SAME'
    c_pooling3 ='SAME'


    layer1 = tf.nn.conv2d(x, w_conv1,c_strides1 , c_pooling1 ) +b_conv1
    layer1 = tf.nn.relu(layer1)
    layer2 = tf.nn.conv2d(layer1, w_conv2,c_strides2 , c_pooling2 ) +b_conv2
    layer2 = tf.nn.relu(layer2)
    layer3 = tf.nn.conv2d(layer2, w_conv3,c_strides3 , c_pooling3 ) +b_conv3
    layer3 = tf.nn.relu(layer3)


    ################################################################################# 


    b1_p_ksize=[1,2,2,1]
    b1_p_strides=[1,1,1,1]
    b1_p_pooling ='SAME'

    b1_out_ch = 128
    b1_c_ksize=[1,1,in_ch,b1_out_ch]
    b1_w_conv , b1_b_conv = make_weights_biases(layer_name,'b1_W1',b1_c_ksize, device )
    b1_c_strides=[1,1,1,1]
    b1_c_pooling='SAME'


    b1_layer1=tf.nn.avg_pool(x , b1_p_ksize , b1_p_strides , b1_p_pooling )
    b1_layer1=tf.nn.relu(b1_layer1)
    b1_layer2 =tf.nn.conv2d(b1_layer1 ,b1_w_conv , b1_c_strides, b1_c_pooling )+b1_b_conv 
    b1_layer2 =tf.nn.relu(b1_layer2)

    ################################################################################# 
    b2_out_ch=384
    b2_c_ksize=[1,1,in_ch,b2_out_ch]
    b2_w_conv , b2_b_conv =make_weights_biases(layer_name,'b2_W1' ,b2_c_ksize , device)
    b2_c_strides=[1,1,1,1]
    b2_c_pooling='SAME'
    b2_layer = tf.nn.conv2d(x,b2_w_conv , b2_c_strides , b2_c_pooling)+b2_b_conv
    b2_layer = tf.nn.relu(b2_layer)
    ################################################################################# 


    b3_out_ch1=192; b3_out_ch2 =192; b3_out_ch3=224 ; b3_out_ch4=224 ; b3_out_ch5 =256
    b3_c_ksize1=[1,1,in_ch,b3_out_ch1]
    b3_c_ksize2=[1,7,b3_out_ch1 , b3_out_ch2]
    b3_c_ksize3=[7,1,b3_out_ch2 , b3_out_ch3]
    b3_c_ksize4=[1,7,b3_out_ch3 , b3_out_ch4]
    b3_c_ksize5=[7,1,b3_out_ch4 , b3_out_ch5]

    b3_w_conv1 , b3_b_conv1=make_weights_biases(layer_name,'b3_W1',b3_c_ksize1, device)
    b3_w_conv2 , b3_b_conv2=make_weights_biases(layer_name,'b3_W2',b3_c_ksize2, device)
    b3_w_conv3 , b3_b_conv3=make_weights_biases(layer_name,'b3_W3',b3_c_ksize3, device)
    b3_w_conv4 , b3_b_conv4=make_weights_biases(layer_name,'b3_W4',b3_c_ksize4, device)
    b3_w_conv5 , b3_b_conv5=make_weights_biases(layer_name,'b3_W5',b3_c_ksize5, device)


    b3_layer1 = tf.nn.conv2d(x,b3_w_conv1 , b2_c_strides , b2_c_pooling)+b3_b_conv1
    b3_layer1 = tf.nn.relu(b3_layer1)
    b3_layer2 = tf.nn.conv2d(b3_layer1,b3_w_conv2 , b2_c_strides , b2_c_pooling)+b3_b_conv2
    b3_layer2 = tf.nn.relu(b3_layer2)
    b3_layer3 = tf.nn.conv2d(b3_layer2,b3_w_conv3 , b2_c_strides , b2_c_pooling)+b3_b_conv3
    b3_layer3 = tf.nn.relu(b3_layer3)
    b3_layer4 = tf.nn.conv2d(b3_layer3,b3_w_conv4 , b2_c_strides , b2_c_pooling)+b3_b_conv4
    b3_layer4 = tf.nn.relu(b3_layer4)
    b3_layer5 = tf.nn.conv2d(b3_layer4,b3_w_conv5 , b2_c_strides , b2_c_pooling)+b3_b_conv5
    b3_layer5 = tf.nn.relu(b3_layer5)

    ################################################################################# 


    layerA=tf.concat(3, [layer3 , b1_layer2] )
    layerB=tf.concat(3, [layerA , b2_layer] )
    layerC=tf.concat(3, [layerB , b3_layer5] )

    print layerC
    return layerC

# %%
def INCEPTION_MODULE_C(x , device , layer_name='INCEPTION_MODULE_C'):

    """
    for 8 X 8 grid modules
    """
    print x.get_shape()
    in_ch=x.get_shape()[3]
    
    out_ch1 = 384 ; out_ch2_a =256 ;out_ch2_b = 256
    c_ksize1 = [1,1,in_ch , out_ch1]
    c_ksize2_a = [1,3,out_ch1 , out_ch2_a]
    c_ksize2_b = [3,1,out_ch1 , out_ch2_b]
    w_conv1 ,b_conv1=make_weights_biases(layer_name,'W1', c_ksize1 ,device)
    w_conv2_a ,b_conv2_a=make_weights_biases(layer_name,'W2_a', c_ksize2_a ,device)
    w_conv2_b ,b_conv2_b=make_weights_biases(layer_name,'W2_b', c_ksize2_b ,device)
    c_strides1=[1,1,1,1]
    c_strides2_a=[1,1,1,1]
    c_strides2_b=[1,1,1,1]
    c_pooling1='SAME'
    c_pooling2_a='SAME'
    c_pooling2_b='SAME'

    layer1 = tf.nn.conv2d(x, w_conv1 ,c_strides1 ,c_pooling1)+b_conv1
    layer1=tf.nn.relu(layer1)
    layer2_a = tf.nn.conv2d(layer1,  w_conv2_a ,c_strides2_a ,c_pooling2_a )+b_conv2_a
    layer2_a = tf.nn.relu(layer2_a)
    layer2_b = tf.nn.conv2d(layer1  , w_conv2_a ,c_strides2_a ,c_pooling2_b)+b_conv2_b
    layer2_b = tf.nn.relu(layer2_b)
    ################################################################################# 


    b1_p_ksize=[1,2,2,1]
    b1_p_strides=[1,1,1,1]
    b1_p_pooling='SAME'

    b1_out_ch =256
    b1_c_ksize=[1,1,in_ch , b1_out_ch]
    b1_w_conv , b1_b_conv= make_weights_biases(layer_name , 'b1_W1' , b1_c_ksize , device)
    b1_c_pooling = 'SAME';b1_c_strides = [1,1,1,1];
    
    b1_layer1 = tf.nn.avg_pool(x , b1_p_ksize , b1_p_strides , b1_p_pooling)
    b1_layer2 = tf.nn.conv2d(b1_layer1 , b1_w_conv , b1_c_strides  ,b1_c_pooling)+b1_b_conv
    b1_layer2 = tf.nn.relu(b1_layer2)
    ################################################################################# 
    b2_out_ch=256
    b2_c_ksize=[1,1,in_ch,b2_out_ch]
    b2_w_conv , b2_b_conv= make_weights_biases(layer_name , 'b2_W' , b2_c_ksize , device)
    b2_c_pooling = 'SAME';b2_c_strides=[1,1,1,1];
    b2_layer = tf.nn.conv2d(x , b2_w_conv , b2_c_strides  ,b2_c_pooling)+b2_b_conv
    b2_layer= tf.nn.relu(b2_layer)
   
    ################################################################################# 


    b3_out_ch1=384;b3_out_ch2=448;b3_out_ch3=512;b3_out_ch4_a=256;b3_out_ch4_b=256
    b3_c_ksize1 =[1,1,in_ch , b3_out_ch1]
    b3_c_ksize2 =[1,3,b3_out_ch1 , b3_out_ch2]
    b3_c_ksize3 =[3,1,b3_out_ch2 , b3_out_ch3]
    b3_c_ksize4_a =[3,1,b3_out_ch3 , b3_out_ch4_a]
    b3_c_ksize4_b =[1,3,b3_out_ch3, b3_out_ch4_b]

    b3_w_conv1 , b3_b_conv1 = make_weights_biases(layer_name,'b3_W1',b3_c_ksize1 , device)
    b3_w_conv2 , b3_b_conv2 = make_weights_biases(layer_name,'b3_W2',b3_c_ksize2 , device)
    b3_w_conv3 , b3_b_conv3 = make_weights_biases(layer_name,'b3_W3',b3_c_ksize3 , device)
    b3_w_conv4_a , b3_b_conv4_a = make_weights_biases(layer_name,'b3_W4_a',b3_c_ksize4_a , device)
    b3_w_conv4_b , b3_b_conv4_b = make_weights_biases(layer_name,'b3_W4_b',b3_c_ksize4_b , device)

    b3_c_strides1=[1,1,1,1]
    b3_c_strides2=[1,1,1,1]
    b3_c_strides3=[1,1,1,1]
    b3_c_strides4_a=[1,1,1,1]
    b3_c_strides4_b=[1,1,1,1]

    b3_c_pooling1='SAME'
    b3_c_pooling2='SAME'
    b3_c_pooling3='SAME'
    b3_c_pooling4_a='SAME'
    b3_c_pooling4_b='SAME'

    b3_laer1 = tf.nn.conv2d(x , b3_w_conv1 , b3_c_strides1 ,b3_c_pooling1)+b3_b_conv1 
    b3_layer1 = tf.nn.relu(b3_laer1)
    b3_layer2 = tf.nn.conv2d(b3_laer1 , b3_w_conv2 , b3_c_strides2 ,b3_c_pooling2)+b3_b_conv2 
    b3_layer2 = tf.nn.relu(b3_layer2)
    b3_layer3 = tf.nn.conv2d(b3_layer2 , b3_w_conv3 , b3_c_strides3 ,b3_c_pooling3)+b3_b_conv3 
    b3_layer3 = tf.nn.relu(b3_layer3)

    b3_layer4_a = tf.nn.conv2d(b3_layer3 , b3_w_conv4_a , b3_c_strides4_a ,b3_c_pooling4_a)+b3_b_conv4_a 
    b3_layer4_a = tf.nn.relu(b3_layer4_a)

    b3_layer4_b = tf.nn.conv2d(b3_layer3 , b3_w_conv4_b , b3_c_strides4_b ,b3_c_pooling4_b)+b3_b_conv4_b 
    b3_layer4_b = tf.nn.relu(b3_layer4_b)


    ################################################################################# 

    layerA = tf.concat(3 , [layer2_a, layer2_b])
    layerB = tf.concat(3 , [layerA  , b1_layer2])
    layerC = tf.concat(3 , [layerB  , b2_layer])
    layerD = tf.concat(3 , [layerC  , b3_layer4_a])
    layerE = tf.concat(3 , [layerD  , b3_layer4_b])

    return layerE

# %%
def INCEPTION_REDUCTION_A(x , device , layer_name = 'INCEPTION_REDUCTION_A'):
    ####################################################################################
   
    """
    usage:
    x shape =[ n_batch , row , col , ch] 
    """
    print x.get_shape()
    in_ch=x.get_shape()[3]
    out_ch = 384
    c_ksize= [3,3,in_ch , out_ch]
    w_conv , b_conv =make_weights_biases(layer_name,'W1',c_ksize,device)
    c_strides=[1,2,2,1]
    c_pooling='VALID'
    layer=tf.nn.conv2d(x,w_conv,c_strides , c_pooling)+b_conv
    layer=tf.nn.relu(layer)

    ####################################################################################
   
    b1_p_ksize=[1,3,3,1]
    b1_p_strides=[1,2,2,1]
    b1_p_pooling='VALID'
    b1_layer = tf.nn.max_pool(x,b1_p_ksize , b1_p_strides , b1_p_pooling)
    ####################################################################################
   
    b2_out_ch1 = 192; b2_out_ch2=288 ;b2_out_ch3 = 256;
    b2_c_ksize1=[1,1,in_ch,b2_out_ch1]
    b2_c_ksize2=[3,3,b2_out_ch1,b2_out_ch2]
    b2_c_ksize3=[3,3,b2_out_ch2,b2_out_ch3]
    b2_w_conv1 , b2_b_conv1 = make_weights_biases(layer_name ,'b2_W1' , b2_c_ksize1 , device)
    b2_w_conv2 , b2_b_conv2 = make_weights_biases(layer_name ,'b2_W2' , b2_c_ksize2 , device)
    b2_w_conv3 , b2_b_conv3 = make_weights_biases(layer_name ,'b2_W3' , b2_c_ksize3 , device)
    
    b2_c_strides1=[1,1,1,1]
    b2_c_strides2=[1,1,1,1]
    b2_c_strides3=[1,2,2,1]
    b2_c_pooling1='SAME'
    b2_c_pooling2='SAME'
    b2_c_pooling3='VALID'
    
    b2_layer1 = tf.nn.conv2d(x        , b2_w_conv1 ,b2_c_strides1 ,b2_c_pooling1)+b2_b_conv1
    b2_layer1 = tf.nn.relu(b2_layer1)
    b2_layer2 = tf.nn.conv2d(b2_layer1, b2_w_conv2 ,b2_c_strides2 ,b2_c_pooling2)+b2_b_conv2
    b2_layer2 = tf.nn.relu(b2_layer2)
    b2_layer3 = tf.nn.conv2d(b2_layer2, b2_w_conv3 ,b2_c_strides3 ,b2_c_pooling3)+b2_b_conv3
    b2_layer3 = tf.nn.relu(b2_layer3)
    
    print layer.get_shape()
    print b1_layer.get_shape()
    print b2_layer3.get_shape()
    ####################################################################################
   
    layerA=tf.concat(3 ,[layer ,b1_layer ])
    layerB=tf.concat(3 ,[layerA ,b2_layer3])
    
    
    
    return layerB

# %%
def INCEPTION_REDUCTION_B(x , device  , layer_name = 'INCEPTION_REDUCTION_B'):
    """
    
    """
    
    ####################################################################################
    in_ch=x.get_shape()[3]
    out_ch1=192 ; out_ch2=192;

    c_ksize1 =[1,1,in_ch , out_ch1]
    c_ksize2 =[3,3,out_ch1,out_ch2]
    w_conv1, b_conv1 = make_weights_biases(layer_name,'W1',c_ksize1,device)
    w_conv2, b_conv2 = make_weights_biases(layer_name,'W2',c_ksize2,device)
    
    c_strides1=[1,1,1,1]
    c_strides2=[1,2,2,1]
    
    c_pooling1='SAME'
    c_pooling2='VALID'
    
    layer1 = tf.nn.conv2d(x,w_conv1 , c_strides1, c_pooling1)
    layer2 = tf.nn.conv2d(layer1 , w_conv2 , c_strides2 , c_pooling2)    
    
    b1_p_ksize=[1,3,3,1]
    b1_p_strides=[1,2,2,1]
    b1_p_pooling='VALID'
    
    b1_layer1=tf.nn.max_pool(x ,b1_p_ksize , b1_p_strides , b1_p_pooling)
    
    ####################################################################################
    b2_out_ch1=256 ; b2_out_ch2 = 256 ; b2_out_ch3=320 ; b2_out_ch4=320;
    b2_p_ksize1 =[1,1,in_ch , b2_out_ch1]
    b2_p_ksize2 =[1,7,b2_out_ch1 , b2_out_ch2]
    b2_p_ksize3 =[7,1,b2_out_ch2 , b2_out_ch3]
    b2_p_ksize4 =[3,3,b2_out_ch3 , b2_out_ch4]
    
    b2_w_conv1, b2_b_conv1 = make_weights_biases(layer_name,'b2_W1' ,b2_c_ksize1,device)
    b2_w_conv2, b2_b_conv2 = make_weights_biases(layer_name,'b2_W2' ,b2_c_ksize2,device)
    b2_w_conv3, b2_b_conv3 = make_weights_biases(layer_name,'b2_W3' ,b2_c_ksize3,device)
    b2_w_conv4, b2_b_conv4 = make_weights_biases(layer_name,'b2_W4' ,b2_c_ksize4,device)
    
    b2_c_strides1=[1,1,1,1]
    b2_c_strides2=[1,1,1,1]
    b2_c_strides3=[1,1,1,1]
    b2_c_strides4=[1,1,1,1]
    
    b2_c_pooling1= 'SAME'
    b2_c_pooling2= 'SAME'
    b2_c_pooling3 = 'SAME'
    b2_c_pooling4 = 'VALID'
    
    b2_layer1 = tf.nn.conv2d(x, b2_w_conv1 , b2_c_strides1 , b2_c_pooling1 )+b2_b_conv1
    b2_layer2 = tf.nn.conv2d(b2_layer1, b2_w_conv2 , b2_c_strides2 , b2_c_pooling2 )+b2_b_conv2
    b2_layer3 = tf.nn.conv2d(b2_layer2, b2_w_conv3 , b2_c_strides3 , b2_c_pooling3 )+b2_b_conv3
    b2_layer4 = tf.nn.conv2d(b2_layer3, b2_w_conv4 , b2_c_strides4 , b2_c_pooling4 )+b2_b_conv4
    
    ####################################################################################

# %%
def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split('(\d+)', text) ]

# %%
def get_batch_list(folder_path):
    """
    return ret_train_img_list ,ret_train_lab_list 
    
    """
    list_files=os.walk(folder_path).next()[2]
    ret_train_img_list=[]
    ret_train_lab_list=[]
    np_train_imgs=[]
    np_train_labs=[]
    for i , ele in enumerate(list_files):

        if 'train'  in ele and 'img'in ele:
            ret_train_img_list.append(ele)
        elif 'train' in ele  and  'lab' in ele:
            ret_train_lab_list.append(ele)
    
    ret_train_img_list.sort(key=natural_keys)
    ret_train_lab_list.sort(key = natural_keys)
    for i  in range(len(ret_train_img_list)):
        np_train_imgs.append(np.load(folder_path+ret_train_img_list[i]))
        np_train_labs.append(np.load(folder_path+ret_train_lab_list[i]))
    
    return np_train_imgs ,np_train_labs

# %%
def aug(np_img ,img_row ,img_col , color_ch, crop_img_row , crop_img_col , label):
    
    n_img = np.shape(np_img)[0] 
    n_ret_img = n_img*(img_row - crop_img_row) * (img_col - crop_img_col)*2
    ret_images = np.zeros([n_ret_img ,crop_img_row , crop_img_col,color_ch])
    len_label= np.shape(label)[1]
    ret_labels =  np.zeros([n_ret_img  ,len_label])
    #print "n_augmented image size : " , n_ret_img 
    #print "n classes :", len_label
    #copy label in factor by 2014
    
    if len(np.shape(np_img))==2:
        np_img=np.reshape(np_img , newshape = [np.shape(np_img)[0] , img_row , img_col ,color_ch])
        print np.shape(np_img)
    for n  in range(len(np_img)):
        ret_labels[n*2 , : ] = label[n,:]
        ret_labels[n*2+1 , : ] = label[n,:]
        for r in range(img_row - crop_img_row):
            for c in range(img_col - crop_img_col):
                
                cropped_img = np_img[n, r:crop_img_row +r , c:crop_img_col+c ,: ]
                
                ret_images[n*2,:,:,:]=cropped_img  
                ret_images[(n*2+1) , :,:,:] =np.fliplr(cropped_img )

    
    return ret_images ,ret_labels

# %%
def extract_test_img(np_img ,img_row ,img_col , color_ch, crop_img_row , crop_img_col ):
    left_top =(0,0)
    right_top =(  img_row  - crop_img_row  , 0 )
    center =  ((img_row  - crop_img_row)/2  , (img_col - crop_img_row)/2)
    left_buttom = (0,(img_col - crop_img_row)/2 )
    right_buttom =  (img_row  - crop_img_row , img_col - crop_img_row)
    
    left_top_images  = np_img[: , left_top[0]:crop_img_row+left_top[0] , left_top[1] : crop_img_col+left_top[1] , :  ]
    right_top_images = np_img[: , right_top[0]:crop_img_row +right_top[0], right_top[1] : crop_img_col +right_top[1], :  ]
    center_images    = np_img[: , center[0]:crop_img_row +center[0], center[1] : crop_img_col +center[1], :  ]
    left_buttom_images=np_img[: , left_buttom[0]:crop_img_row +left_buttom[0], left_buttom[1] : crop_img_col +left_buttom[1], :  ]
    right_buttom_images= np_img[: , right_buttom[0]:crop_img_row+right_buttom[0] , right_buttom[1] : crop_img_col +right_buttom[1] , :  ]

    
        
    return left_top_images , right_top_images , center_images , left_buttom_images , right_buttom_images

# %%
def TRAIN_STRUCTURE_A(y_conv , y_ , device_,learning_rate=1e-4 ):
    """
    Return Value : cost , train_step ,correct_prediction , accuracy 
    
    """
    with tf.device(device_):
    #sm_conv= tf.nn.softmax(y_conv)
        #cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv))

        softmax=tf.nn.softmax(y_conv)
        regular=0.01*(tf.reduce_sum(tf.square(y_conv)))
        cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits( y_conv, y_))
    with tf.device(device_):
        cost = cost+regular
        train_step = tf.train.AdamOptimizer(learning_rate).minimize(cost) #1e-4
        with tf.name_scope("accuracy"):
            with tf.name_scope('correct_prediction'):
                correct_prediction = tf.equal(tf.argmax(y_conv,1) ,tf.argmax(y_,1))
            with tf.name_scope('accuracy'):
                accuracy = tf.reduce_mean(tf.cast(correct_prediction , "float")) 
    return cost , train_step ,correct_prediction , accuracy,softmax

# %%
def START_SESS():
    sess = tf.Session()
  
    sess.run(tf.initialize_all_variables())
    return sess

# %% [markdown]
# # File Terminal Open

# %%
#dirname = '/home/ncc/notebook/mammo/result/'
def make_logdir(dirname):
  

    count=0
    while(True):
        if not os.path.isdir(dirname):
            os.mkdir(dirname)
            break
        elif not os.path.isdir(dirname + str(count)):
            dirname=dirname+str(count)
            os.mkdir(dirname)
            break
        else:
            count+=1
    print 'it is recorded at :'+str(count)

    f=open(dirname+"/log.txt",'w')
    return f

# %%
def write_log(step,train_acc, train_loss , val_acc , val_loss ,fp):
    """
    fp = File Pointer
    
    """
    #result = sess.run(sm_conv , feed_dict = {x:val_img , y_:batch_ys , keep_prob :1.0})
    print step
    print("step %d , training  accuracy %g" %(step,train_acc))
    print("step %d , loss : %g" %(step,train_loss))
    train_str = 'step:\t'+str(step)+'\ttrain_loss:\t'+str(train_loss) +'\ttrain_accuracy:\t'+str(train_acc)+'\n'

    print("step %d , validation  accuracy %g" %(step,val_acc))
    print("step %d , validation loss : %g" %(step,val_loss))
    val_str = 'step:\t'+str(step)+'\tval_loss:\t'+str(val_loss) +'\tval_accuracy:\t'+str(val_acc)+'\n'

    fp.write(train_str)
    fp.write(val_str)

# %%
def load_TVT(divide_flag,file_locate):
    if divide_flag == False:
        train_img=np.load(file_locate+'train_img.npy');
        train_lab=np.load(file_locate+'train_lab.npy');
        val_img= np.load(file_locate+'val_img.npy');
        val_lab = np.load(file_locate+'val_lab.npy');
        test_img=np.load(file_locate+'test_img.npy');
        test_lab=np.load(file_locate+'test_lab.npy');

        print "Training Data Image",np.shape(train_img)
        print "Training Data Label",np.shape(train_lab)
        print "Test Data Label",np.shape(test_lab)
        print "Test Data Image",np.shape(test_img)
        print "val Data Label" , np.shape(val_lab)
        print "val Data Image" , np.shape(val_img)
        
        n_train= np.shape(train_img)[0]
        n_train_lab = np.shape(train_lab)[0]
        return train_img ,train_lab,val_img,val_lab,test_img,test_lab
    if divide_flag == True:
        print '트레이닝 파일이 여러개로 분할되어 있습니다. 분할된 트레이닝 파일에 대한 조치가 필요합니다'
        train_images, train_labels =get_batch_list(file_locate)
        #print train_images ,train_labels
        val_img= np.load(file_locate+'val_img.npy');
        val_lab = np.load(file_locate+'val_lab.npy');
        test_img=np.load(file_locate+'test_img.npy');
        test_lab=np.load(file_locate+'test_lab.npy');
        print "the number of training image batch",len(train_images)
        print "the number of training label batch",len(train_labels)
        print "training Data Label",np.shape(train_labels[0])
        print "training Data Image",np.shape(train_images[0])
        print "Test Data Label",np.shape(test_lab)
        print "Test Data Image",np.shape(test_img)
        print "val Data Label" , np.shape(val_lab)
        print "val Data Image" , np.shape(val_img)
        return train_images, train_labels,val_img,val_lab,test_img,test_lab

# %%
def validate_from_images(sess, images , labels , tensor_info, place_info , tensorboard_info = None):    
    """
    input : x-
    
    x type  : numpy 
    x shape : [n , row , col , ch]
    return  acc,  loss

    """
    
    print accuracy
    acc_list=[]
    loss_list=[]
    images_labels=zip(images,labels)
    for img_ind ,(img,lab)  in enumerate(images_labels):

        acc ,loss = sess.run( [tensor_info['accuracy'],tensor_info['cost']] ,\
                             feed_dict={place_info['x_']:img , place_info['y_']: lab , place_info['keep_prob']: 1.0})        
        acc_list.append(acc)
        loss_list.append(loss)

    acc_list=np.asarray(acc_list)
    loss_list=np.asarray(loss_list)
    acc=np.mean(acc_list)
    loss=np.mean(loss_list)
    
    
    
    return  acc,  loss

# %%
def validate(img , lab ,tensor_info , place_info,tensorboard_info=None , step=None): #default
    """
    return val_acc,  val_loss, train_acc, train_loss
    tensorboard_info['writer']
    tensorboard_info['merge']    
    """    
    print 'validate tensorboard' , tensorboard_info
    if tensorboard_info ==None:
        print 'b'
        acc,loss = sess.run([tensor_info['accuracy'],tensor_info['cost']] , feed_dict={place_info['x_']:img , place_info['y_']:lab , place_info['keep_prob']: 1.0})        
    else:
        print 'a'
        summary,acc,loss = sess.run([tensorboard_info['merge'],tensor_info['accuracy'],tensor_info['cost']] , feed_dict={place_info['x_']:img , place_info['y_']:lab , place_info['keep_prob']: 1.0})        
        tensorboard_info['writer'].add_summary(summary , step)
        
        
    return acc,loss

# %%
def BATCH_TRAINING_DIVIDE_RANDOM(maxiter, batch_size,file_locate,tensor_info, place_info , fp):
    
    
    start_time = time.time()
    #with tf.device('/gpu:0'):
    train_imgs, train_labs,val_img,val_lab,test_img,test_lab=load_TVT(True,file_locate) #TVT is Train Validation Test  
    for step in range(maxiter):
        b_ind=random.randrange(0,len(train_imgs))
        train_img = train_imgs[b_ind]
        train_lab = train_labs[b_ind]
        
        batch_xs , batch_ys = next_batch(batch_size, train_img , train_lab)       
        if step%100 ==0: #여기 if loop에서 validate을 합니다 
            try:
                val_acc , val_loss= validate(val_img,val_lab,tensor_info,place_info)     
                train_acc , train_loss=validate(batch_xs,batch_ys,tensor_info,place_info)
            except:
                #한번에 트레이닝이 안되면 분할해서 validation한다.
                val_imgs, val_labs = divide_images(val_img , val_lab, batch_size)
                #print np.shape(val_imgs[0])
                val_acc, val_loss =validate_from_images(sess,val_imgs ,val_labs ,tensor_info ,place_info )
                train_acc , train_loss=validate(batch_xs,batch_ys,tensor_info ,place_info)
                
            write_log(step , train_acc, train_loss , val_acc, val_loss , fp)
            #softmax_=sess.run(softmax ,feed_dict ={ x:batch_xs , y_:batch_ys , keep_prob:1.0 })
            #print softmax_
        training(batch_xs,batch_ys,tensor_info,place_info)

    ############################################aug_and_training############################
    print("--- Training Time : %s ---" % (time.time() - start_time))
    train_time="--- Training Time : ---:\t" +str(time.time() - start_time)
    
    try:
        test_acc , test_loss=validate(test_img , test_lab)
    except:
        #한번에 트레이닝이 안되면 분할해서 validation한다.
        test_imgs, test_labs = divide_images(test_img ,test_lab, batch_size)
        #print np.shape(val_imgs[0])
        test_acc, test_loss =validate_from_images(sess,test_imgs ,test_labs ,tensor_info,place_info )
    print "test accuracy {0} , test loss {1}".format(test_acc, test_loss)
    fp.write(train_time)
    fp.close()
    sess.close()

# %%
def BATCH_TRAINING_RANDOM(maxiter, batch_size, file_locate, tensor_info , place_info, fp , tensorboard_info=None):
    print tensorboard_info
    start_time = time.time()
    #with tf.device('/gpu:0'):
    train_img, train_lab,val_img,val_lab,test_img,test_lab=load_TVT(False,file_locate) #TVT is Train Validation Test  
    for step in range(maxiter):    
        batch_xs , batch_ys = next_batch(batch_size, train_img , train_lab)       
        if step%100 ==0: #여기 if loop에서 validate을 합니다 
            try:
                if tensorboard_info == None:
                    print 'none'
                    val_acc , val_loss = validate(val_img , val_lab,tensor_info,place_info,tensorboard_info ,step)
                    train_acc , train_loss = validate(batch_xs,batch_ys,tensor_info,place_info)
                
                else: 
                    val_acc , val_loss = validate(val_img , val_lab ,tensor_info,place_info,tensorboard_info ,step)
                    train_acc , train_loss = validate(batch_xs,batch_ys )
                
            except:
                #한번에 트레이닝이 안되면 분할해서 validation한다.
                val_imgs, val_labs = divide_images(val_img , val_lab, batch_size)
                #print np.shape(val_imgs[0])
                val_acc, val_loss =validate_from_images(sess, val_imgs ,val_labs ,tensor_info ,place_info,tensorboard_info)
                train_acc , train_loss=validate(batch_xs,batch_ys,tensor_info ,place_info)
                       
            write_log(step , train_acc, train_loss , val_acc, val_loss , fp)
            #softmax_=sess.run(softmax ,feed_dict ={ x:batch_xs , y_:batch_ys , keep_prob:1.0 })
            #print softmax_
        training(batch_xs,batch_ys,tensor_info , place_info)

    ############################################aug_and_training############################
    print("--- Training Time : %s ---" % (time.time() - start_time))
    train_time="--- Training Time : ---:\t" +str(time.time() - start_time)
    
    try:
        test_acc , test_loss=validate(test_img , test_lab)
    except:
        #한번에 트레이닝이 안되면 분할해서 validation한다.
        test_imgs, test_labs = divide_images(test_img ,test_lab, batch_size)
        #print np.shape(val_imgs[0])
        test_acc, test_loss =validate_from_images(sess,test_imgs ,test_labs ,tensor_info,place_info )
    print "test accuracy {0} , test loss {1}".format(test_acc, test_loss)
    fp.write(train_time)
    fp.close()

# %%
def BATCH_TRAINING_MANUAL(maxiter  , batch_size,file_locate, tensor_info, place_info , fp ):
    start_time = time.time()
#with tf.device('/gpu:0'):
    train_img, train_lab,val_img,val_lab,test_img,test_lab\
    =load_TVT(divide_flag,file_locate)
    train_images , train_labels=divide_images(train_img , train_lab , batch_size)
    train_images_labels=zip(train_images , train_labels)
    
    for step,(batch_xs , batch_ys) in train_images_labels:
        if step%100 ==0:
            try:
                val_acc , val_loss=validate(val_img , val_lab)
                train_acc , train_loss=validate(batch_xs,batch_ys)
            except:
                #한번에 트레이닝이 안되면 분할해서 validation한다.
                val_imgs, val_labs = divide_images(val_img , val_lab, batch_size)
                val_acc, val_loss =validate_from_images(val_imgs ,val_labs ,accuracy, cost )
                train_acc , train_loss=validate(batch_xs,batch_ys,accuracy, cost)
            write_log(step , train_acc, train_loss , val_acc, val_loss , fp)
            np.save('./result/batch_xs' ,batch_xs)
            np.save('./result/batch_ys' ,batch_ys)
        else:
            list_aud_x = aug_8_times(batch_xs)
            for ele in list_aug_x:
                training(ele ,batch_ys)                    


############################################aug_and_training############################
    print("--- Training Time : %s ---" % (time.time() - start_time))
    train_time="--- Training Time : ---:\t" +str(time.time() - start_time)
    fp.write(train_time)
    fp.close()

# %%
def divide_images(images , labels,batch_size):
    """
    return list_images,list_labels
    """
    n_divide=len(images)/batch_size

    list_images=[]
    list_labels=[]
    for ind in range(n_divide):
        # j*batch_size :(j+1)*batch_size
        image =images[ ind*batch_size :(ind+1)*batch_size] 
        label =labels[ ind*batch_size :(ind+1)*batch_size]
        list_images.append(image)
        list_labels.append(label)

    #right above code have to modify
    image = images[ (ind+1)*batch_size :  ] 
    label = labels[ (ind+1)*batch_size :  ]
    list_images.append(image)
    list_labels.append(label)

    return list_images,list_labels

# %%
  
def validate_extract_imgs(val_img , val_lab , train_img , train_lab ):
    """
    extract patch from ori-image
    """
    color_ch = in_ch
    val_images  =extract_test_img(val_img , 128 , 128 , color_ch   ,crop_img_row =118 , crop_img_col =118 )
    train_images=extract_test_img(train_img ,128 , 128 , color_ch   ,crop_img_row =118 , crop_img_col =118 )
    val_acc, val_loss =validate_from_images(sess, val_images , val_lab , accuracy ,cost )
    train_acc , train_loss =validate_from_images(sess, train_images , train_lab ,accuracy , cost)
    
    return val_acc , val_loss, train_acc ,train_loss

# %%
def training(batch_xs , batch_ys , tensor_info , place_info):
    sess.run(tensor_info['train_step'] ,feed_dict={place_info['x_']: batch_xs, place_info['y_']:batch_ys , place_info['keep_prob'] : 0.5})

# %%
def aug_8_times(x):
    """
    
    
    x shape is [n_batch , row ,col , color_ch ]
    x type is numpy 
    this code need too many time to run 
    we should find solution using parallel method to less run time maybe 
    
    return x,np_rot90,np_rot180,np_rot270,lr_x,np_lr_rot90 ,np_lr_rot180 , np_lr_rot270 
    
    """

    n_batch,row,col,ch=np.shape(x)
    lr_x = np.flipud(x)

    np_rot90 =np.zeros(shape =[n_batch , row ,col ,ch] )
    np_rot180=np.zeros(shape =[n_batch , row ,col ,ch] )
    np_rot270=np.zeros(shape =[n_batch , row ,col ,ch] )

    np_lr_rot90 =np.zeros(shape =[n_batch , row ,col ,ch] )
    np_lr_rot180=np.zeros(shape =[n_batch , row ,col ,ch] )
    np_lr_rot270=np.zeros(shape =[n_batch , row ,col ,ch] )
    
    

    for batch_ind in range(n_batch):

        rot90=np.rot90(x[batch_ind,:,:,:])
        rot180=np.rot90(rot90)
        rot270=np.rot90(rot180)

        np_rot90[batch_ind,:,:,:] = rot90
        np_rot180[batch_ind,:,:,:]=rot180
        np_rot270[batch_ind,:,:,:]=rot270

        lr_rot90=np.rot90(lr_x[batch_ind,:,:,:])
        lr_rot180=np.rot90(lr_rot90)
        lr_rot270=np.rot90(lr_rot180)

        np_lr_rot90[batch_ind,:,:,:]=lr_rot90
        np_lr_rot180[batch_ind,:,:,:]=lr_rot180
        np_lr_rot90[batch_ind,:,:,:]=lr_rot270
    return x,np_rot90,np_rot180,np_rot270,lr_x,np_lr_rot90 ,np_lr_rot180 , np_lr_rot270

# %%
def aug_crop(np_img ,img_row ,img_col , color_ch, crop_img_row , crop_img_col , label):
    n_img = np.shape(np_img)[0] 
    n_ret_img = n_img*(img_row - crop_img_row) * (img_col - crop_img_col)*2
    ret_images = np.zeros([n_ret_img ,crop_img_row , crop_img_col,color_ch])
    len_label= np.shape(label)[1]
    ret_labels =  np.zeros([n_ret_img  ,len_label])
    #print "n_augmented image size : " , n_ret_img 
    #print "n classes :", len_label
    #copy label in factor by 2014

    if len(np.shape(np_img))==2:
        np_img=np.reshape(np_img , newshape = [np.shape(np_img)[0] , img_row , img_col ,color_ch])
        print np.shape(np_img)
    for n  in range(len(np_img)):
        ret_labels[n*2 , : ] = label[n,:]
        ret_labels[n*2+1 , : ] = label[n,:]
        for r in range(img_row - crop_img_row):
            for c in range(img_col - crop_img_col):

                cropped_img = np_img[n, r:crop_img_row +r , c:crop_img_col+c ,: ]

                ret_images[n*2,:,:,:]=cropped_img  
                ret_images[(n*2+1) , :,:,:] =np.fliplr(cropped_img )


    return ret_images ,ret_labels

# %%
def OPEN_TENSORBOARD(sess,tensor_info , logdir ):
    
    tensorboard_info={}
    tb_acc=tf.summary.scalar("accuarcy" ,tensor_info['accuracy'] )
    tb_loss=tf.summary.scalar("loss" ,tensor_info['cost'] )
    tb_merge = tf.summary.merge_all()
    writer=tf.train.SummaryWriter(logdir , sess.graph )
    sess.run(tf.global_variables_initializer())
    
    
    tensorboard_info['writer']=writer
    tensorboard_info['merge'] =tb_merge
  
    return tensorboard_info

# %%
tensor_info={};place_info={}
file_locate='./cifar_merge/'
dirname='./result/'

A=CONV_1(x_ , 'gpu:1' , 'CONVx5_1',16,(3,3),[1,2,2,1],'SAME')
B=CONV_5(A  , 'gpu:1' , 'CONVx5_2',16,(3,3),[1,1,1,1],'SAME')
C=CONV_1(B  , 'gpu:1' , 'CONVx5_3',32,(3,3),[1,2,2,1],'SAME')
D=CONV_5(C  , 'gpu:1' , 'CONVx5_4',32,(3,3),[1,1,1,1],'SAME')
E=CONV_1(D  , 'gpu:1' , 'CONVx5_5',64,(3,3),[1,2,2,1],'SAME')
F=CONV_5(E  , 'gpu:1' , 'CONVx5_6',64,(3,3),[1,1,1,1],'SAME')
"""
B=STEM_B(A , 'gpu:0')
C=STEM_C(B , 'gpu:0')
D=INCEPTION_MODULE_A(C,'gpu:0', 'INCEPTION_MODULE_A_1')
E=INCEPTION_MODULE_A(D,'gpu:0', 'INCEPTION_MODULE_A_2')
F=INCEPTION_MODULE_A(E,'gpu:0', 'INCEPTION_MODULE_A_3')
G=INCEPTION_MODULE_A(F,'gpu:0', 'INCEPTION_MODULE_A_4')
H=INCEPTION_REDUCTION_A(G,'gpu:0' , 'INCEPTION_REDUCTION_A_1')
I=INCEPTION_MODULE_B(H,'gpu:0' , 'INCEPTION_REDUCTION_B_1')
J=INCEPTION_MODULE_B(I,'gpu:0' , 'INCEPTION_REDUCTION_B_2')
K=INCEPTION_MODULE_B(G,'gpu:0' , 'INCEPTION_REDUCTION_B_3')
L=INCEPTION_MODULE_B(G,'gpu:0' , 'INCEPTION_REDUCTION_B_4')
M=INCEPTION_MODULE_B(G,'gpu:0' , 'INCEPTION_REDUCTION_B_5')
"""

flat_=FLAT(F)
y_conv=FC_B(flat_ , 10 ,'/gpu:1' )
#y_conv=FC_A(flat_ , n_classes ,'/gpu:1' ,dropout_rate=keep_prob)
cost , train_step ,correct_prediction , accuracy ,softmax = \
TRAIN_STRUCTURE_A(y_conv , y_ , '/gpu:1' , learning_rate = 0.0001)

tensor_info['cost']=cost
tensor_info['train_step']=train_step
tensor_info['correct_prediction']=correct_prediction
tensor_info['accuracy']=accuracy
tensor_info['softmax']=softmax

place_info['x_']=x_
place_info['y_']=y_
place_info['keep_prob']=keep_prob


logdir='./module_conv5x2'
sess=START_SESS()
tensorboard_info=OPEN_TENSORBOARD(sess ,tensor_info ,logdir)
fp=make_logdir(dirname)
BATCH_TRAINING_RANDOM(100000 , 30,file_locate , tensor_info,place_info ,fp ,tensorboard_info)
#BATCH_TRAINING_DIVIDE_RANDOM(100000 , 30,file_locate , tensor_info,place_info ,fp)
# Out:
# WARNING:tensorflow:From <ipython-input-28-1df795f13645>:4 in START_SESS.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# WARNING:tensorflow:From <ipython-input-42-83d39c357e96>:7 in OPEN_TENSORBOARD.: __init__ (from tensorflow.python.training.summary_io) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.FileWriter. The interface and behavior is the same; this is just a rename.
# it is recorded at :105
# {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# Training Data Image (50000, 32, 32, 3)
# Training Data Label (50000, 10)
# Test Data Label (5000, 10)
# Test Data Image (5000, 32, 32, 3)
# val Data Label (5000, 10)
# val Data Image (5000, 32, 32, 3)
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 0
# step 0 , training  accuracy 0.0666667
# step 0 , loss : 2.38803
# step 0 , validation  accuracy 0.111976
# step 0 , validation loss : 2.41426
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 100
# step 100 , training  accuracy 0.3
# step 100 , loss : 2.25317
# step 100 , validation  accuracy 0.229641
# step 100 , validation loss : 2.26799
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 200
# step 200 , training  accuracy 0.366667
# step 200 , loss : 2.24274
# step 200 , validation  accuracy 0.305689
# step 200 , validation loss : 2.24871
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 300
# step 300 , training  accuracy 0.3
# step 300 , loss : 2.22663
# step 300 , validation  accuracy 0.341218
# step 300 , validation loss : 2.23147
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 400
# step 400 , training  accuracy 0.5
# step 400 , loss : 2.19878
# step 400 , validation  accuracy 0.341517
# step 400 , validation loss : 2.22762
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 500
# step 500 , training  accuracy 0.266667
# step 500 , loss : 2.20752
# step 500 , validation  accuracy 0.348104
# step 500 , validation loss : 2.22253
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 600
# step 600 , training  accuracy 0.233333
# step 600 , loss : 2.27137
# step 600 , validation  accuracy 0.364771
# step 600 , validation loss : 2.2131
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 700
# step 700 , training  accuracy 0.466667
# step 700 , loss : 2.19102
# step 700 , validation  accuracy 0.376747
# step 700 , validation loss : 2.2123
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 800
# step 800 , training  accuracy 0.3
# step 800 , loss : 2.29345
# step 800 , validation  accuracy 0.36986
# step 800 , validation loss : 2.21197
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 900
# step 900 , training  accuracy 0.4
# step 900 , loss : 2.22207
# step 900 , validation  accuracy 0.381637
# step 900 , validation loss : 2.20139
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 1000
# step 1000 , training  accuracy 0.366667
# step 1000 , loss : 2.20014
# step 1000 , validation  accuracy 0.392116
# step 1000 , validation loss : 2.19698
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 1100
# step 1100 , training  accuracy 0.4
# step 1100 , loss : 2.20926
# step 1100 , validation  accuracy 0.4
# step 1100 , validation loss : 2.19614
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 1200
# step 1200 , training  accuracy 0.266667
# step 1200 , loss : 2.23232
# step 1200 , validation  accuracy 0.393713
# step 1200 , validation loss : 2.19739
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 1300
# step 1300 , training  accuracy 0.5
# step 1300 , loss : 2.14828
# step 1300 , validation  accuracy 0.402794
# step 1300 , validation loss : 2.19282
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 1400
# step 1400 , training  accuracy 0.5
# step 1400 , loss : 2.16976
# step 1400 , validation  accuracy 0.408882
# step 1400 , validation loss : 2.18811
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 1500
# step 1500 , training  accuracy 0.433333
# step 1500 , loss : 2.15398
# step 1500 , validation  accuracy 0.40998
# step 1500 , validation loss : 2.18651
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 1600
# step 1600 , training  accuracy 0.266667
# step 1600 , loss : 2.20151
# step 1600 , validation  accuracy 0.383533
# step 1600 , validation loss : 2.19309
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 1700
# step 1700 , training  accuracy 0.3
# step 1700 , loss : 2.21704
# step 1700 , validation  accuracy 0.417565
# step 1700 , validation loss : 2.18237
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 1800
# step 1800 , training  accuracy 0.366667
# step 1800 , loss : 2.19996
# step 1800 , validation  accuracy 0.405689
# step 1800 , validation loss : 2.18438
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 1900
# step 1900 , training  accuracy 0.4
# step 1900 , loss : 2.17892
# step 1900 , validation  accuracy 0.417665
# step 1900 , validation loss : 2.18173
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 2000
# step 2000 , training  accuracy 0.466667
# step 2000 , loss : 2.18918
# step 2000 , validation  accuracy 0.431836
# step 2000 , validation loss : 2.17568
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 2100
# step 2100 , training  accuracy 0.333333
# step 2100 , loss : 2.27993
# step 2100 , validation  accuracy 0.417365
# step 2100 , validation loss : 2.18051
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 2200
# step 2200 , training  accuracy 0.233333
# step 2200 , loss : 2.21755
# step 2200 , validation  accuracy 0.431637
# step 2200 , validation loss : 2.17519
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 2300
# step 2300 , training  accuracy 0.533333
# step 2300 , loss : 2.15845
# step 2300 , validation  accuracy 0.420459
# step 2300 , validation loss : 2.18392
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 2400
# step 2400 , training  accuracy 0.533333
# step 2400 , loss : 2.12322
# step 2400 , validation  accuracy 0.430639
# step 2400 , validation loss : 2.17399
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 2500
# step 2500 , training  accuracy 0.366667
# step 2500 , loss : 2.1702
# step 2500 , validation  accuracy 0.423753
# step 2500 , validation loss : 2.17601
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 2600
# step 2600 , training  accuracy 0.4
# step 2600 , loss : 2.17732
# step 2600 , validation  accuracy 0.431537
# step 2600 , validation loss : 2.1686
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 2700
# step 2700 , training  accuracy 0.666667
# step 2700 , loss : 2.05686
# step 2700 , validation  accuracy 0.444611
# step 2700 , validation loss : 2.16486
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 2800
# step 2800 , training  accuracy 0.466667
# step 2800 , loss : 2.15405
# step 2800 , validation  accuracy 0.439721
# step 2800 , validation loss : 2.16783
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 2900
# step 2900 , training  accuracy 0.466667
# step 2900 , loss : 2.12909
# step 2900 , validation  accuracy 0.426148
# step 2900 , validation loss : 2.17062
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 3000
# step 3000 , training  accuracy 0.466667
# step 3000 , loss : 2.1241
# step 3000 , validation  accuracy 0.43982
# step 3000 , validation loss : 2.16502
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 3100
# step 3100 , training  accuracy 0.566667
# step 3100 , loss : 2.08038
# step 3100 , validation  accuracy 0.438922
# step 3100 , validation loss : 2.16377
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 3200
# step 3200 , training  accuracy 0.433333
# step 3200 , loss : 2.10617
# step 3200 , validation  accuracy 0.437824
# step 3200 , validation loss : 2.1644
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 3300
# step 3300 , training  accuracy 0.6
# step 3300 , loss : 2.12365
# step 3300 , validation  accuracy 0.429641
# step 3300 , validation loss : 2.16953
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 3400
# step 3400 , training  accuracy 0.6
# step 3400 , loss : 2.1324
# step 3400 , validation  accuracy 0.452096
# step 3400 , validation loss : 2.16052
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 3500
# step 3500 , training  accuracy 0.533333
# step 3500 , loss : 2.1409
# step 3500 , validation  accuracy 0.442116
# step 3500 , validation loss : 2.16159
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 3600
# step 3600 , training  accuracy 0.4
# step 3600 , loss : 2.12576
# step 3600 , validation  accuracy 0.444212
# step 3600 , validation loss : 2.16563
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 3700
# step 3700 , training  accuracy 0.3
# step 3700 , loss : 2.21425
# step 3700 , validation  accuracy 0.439521
# step 3700 , validation loss : 2.16285
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 3800
# step 3800 , training  accuracy 0.466667
# step 3800 , loss : 2.15572
# step 3800 , validation  accuracy 0.456387
# step 3800 , validation loss : 2.15374
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 3900
# step 3900 , training  accuracy 0.566667
# step 3900 , loss : 2.1389
# step 3900 , validation  accuracy 0.442715
# step 3900 , validation loss : 2.16106
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 4000
# step 4000 , training  accuracy 0.5
# step 4000 , loss : 2.12053
# step 4000 , validation  accuracy 0.456687
# step 4000 , validation loss : 2.15728
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 4100
# step 4100 , training  accuracy 0.433333
# step 4100 , loss : 2.12556
# step 4100 , validation  accuracy 0.458483
# step 4100 , validation loss : 2.15433
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 4200
# step 4200 , training  accuracy 0.533333
# step 4200 , loss : 2.10763
# step 4200 , validation  accuracy 0.452595
# step 4200 , validation loss : 2.15832
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 4300
# step 4300 , training  accuracy 0.466667
# step 4300 , loss : 2.12643
# step 4300 , validation  accuracy 0.44511
# step 4300 , validation loss : 2.1601
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 4400
# step 4400 , training  accuracy 0.5
# step 4400 , loss : 2.08041
# step 4400 , validation  accuracy 0.457884
# step 4400 , validation loss : 2.1507
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 4500
# step 4500 , training  accuracy 0.4
# step 4500 , loss : 2.16836
# step 4500 , validation  accuracy 0.448303
# step 4500 , validation loss : 2.16012
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 4600
# step 4600 , training  accuracy 0.6
# step 4600 , loss : 2.07675
# step 4600 , validation  accuracy 0.462176
# step 4600 , validation loss : 2.14907
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 4700
# step 4700 , training  accuracy 0.433333
# step 4700 , loss : 2.13958
# step 4700 , validation  accuracy 0.457984
# step 4700 , validation loss : 2.1495
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 4800
# step 4800 , training  accuracy 0.5
# step 4800 , loss : 2.13102
# step 4800 , validation  accuracy 0.468363
# step 4800 , validation loss : 2.14622
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 4900
# step 4900 , training  accuracy 0.433333
# step 4900 , loss : 2.20162
# step 4900 , validation  accuracy 0.458882
# step 4900 , validation loss : 2.15857
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 5000
# step 5000 , training  accuracy 0.466667
# step 5000 , loss : 2.15958
# step 5000 , validation  accuracy 0.45509
# step 5000 , validation loss : 2.15551
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 5100
# step 5100 , training  accuracy 0.366667
# step 5100 , loss : 2.21189
# step 5100 , validation  accuracy 0.464371
# step 5100 , validation loss : 2.14683
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 5200
# step 5200 , training  accuracy 0.433333
# step 5200 , loss : 2.17694
# step 5200 , validation  accuracy 0.464571
# step 5200 , validation loss : 2.14667
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 5300
# step 5300 , training  accuracy 0.533333
# step 5300 , loss : 2.11983
# step 5300 , validation  accuracy 0.464471
# step 5300 , validation loss : 2.14517
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 5400
# step 5400 , training  accuracy 0.366667
# step 5400 , loss : 2.16976
# step 5400 , validation  accuracy 0.465868
# step 5400 , validation loss : 2.14275
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 5500
# step 5500 , training  accuracy 0.433333
# step 5500 , loss : 2.14615
# step 5500 , validation  accuracy 0.463174
# step 5500 , validation loss : 2.14538
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 5600
# step 5600 , training  accuracy 0.4
# step 5600 , loss : 2.16987
# step 5600 , validation  accuracy 0.468064
# step 5600 , validation loss : 2.14601
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 5700
# step 5700 , training  accuracy 0.5
# step 5700 , loss : 2.13576
# step 5700 , validation  accuracy 0.469262
# step 5700 , validation loss : 2.14396
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 5800
# step 5800 , training  accuracy 0.5
# step 5800 , loss : 2.11166
# step 5800 , validation  accuracy 0.468064
# step 5800 , validation loss : 2.14207
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 5900
# step 5900 , training  accuracy 0.433333
# step 5900 , loss : 2.13801
# step 5900 , validation  accuracy 0.483333
# step 5900 , validation loss : 2.13908
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 6000
# step 6000 , training  accuracy 0.5
# step 6000 , loss : 2.13255
# step 6000 , validation  accuracy 0.474751
# step 6000 , validation loss : 2.14558
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 6100
# step 6100 , training  accuracy 0.533333
# step 6100 , loss : 2.1405
# step 6100 , validation  accuracy 0.482335
# step 6100 , validation loss : 2.138
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 6200
# step 6200 , training  accuracy 0.466667
# step 6200 , loss : 2.17255
# step 6200 , validation  accuracy 0.473852
# step 6200 , validation loss : 2.13744
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 6300
# step 6300 , training  accuracy 0.433333
# step 6300 , loss : 2.15686
# step 6300 , validation  accuracy 0.486228
# step 6300 , validation loss : 2.13783
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 6400
# step 6400 , training  accuracy 0.466667
# step 6400 , loss : 2.12073
# step 6400 , validation  accuracy 0.471158
# step 6400 , validation loss : 2.13963
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 6500
# step 6500 , training  accuracy 0.533333
# step 6500 , loss : 2.07815
# step 6500 , validation  accuracy 0.475449
# step 6500 , validation loss : 2.13782
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 6600
# step 6600 , training  accuracy 0.533333
# step 6600 , loss : 2.11936
# step 6600 , validation  accuracy 0.478044
# step 6600 , validation loss : 2.14049
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 6700
# step 6700 , training  accuracy 0.466667
# step 6700 , loss : 2.1123
# step 6700 , validation  accuracy 0.489621
# step 6700 , validation loss : 2.13524
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 6800
# step 6800 , training  accuracy 0.5
# step 6800 , loss : 2.14348
# step 6800 , validation  accuracy 0.479741
# step 6800 , validation loss : 2.13858
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 6900
# step 6900 , training  accuracy 0.566667
# step 6900 , loss : 2.16766
# step 6900 , validation  accuracy 0.481637
# step 6900 , validation loss : 2.13663
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 7000
# step 7000 , training  accuracy 0.633333
# step 7000 , loss : 2.05072
# step 7000 , validation  accuracy 0.482435
# step 7000 , validation loss : 2.1335
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 7100
# step 7100 , training  accuracy 0.533333
# step 7100 , loss : 2.09593
# step 7100 , validation  accuracy 0.48523
# step 7100 , validation loss : 2.13236
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 7200
# step 7200 , training  accuracy 0.566667
# step 7200 , loss : 2.0703
# step 7200 , validation  accuracy 0.484132
# step 7200 , validation loss : 2.13506
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 7300
# step 7300 , training  accuracy 0.533333
# step 7300 , loss : 2.12705
# step 7300 , validation  accuracy 0.486228
# step 7300 , validation loss : 2.1338
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 7400
# step 7400 , training  accuracy 0.533333
# step 7400 , loss : 2.10791
# step 7400 , validation  accuracy 0.483034
# step 7400 , validation loss : 2.13711
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 7500
# step 7500 , training  accuracy 0.433333
# step 7500 , loss : 2.14448
# step 7500 , validation  accuracy 0.486826
# step 7500 , validation loss : 2.12938
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 7600
# step 7600 , training  accuracy 0.4
# step 7600 , loss : 2.16456
# step 7600 , validation  accuracy 0.482635
# step 7600 , validation loss : 2.133
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 7700
# step 7700 , training  accuracy 0.5
# step 7700 , loss : 2.07726
# step 7700 , validation  accuracy 0.493413
# step 7700 , validation loss : 2.12888
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 7800
# step 7800 , training  accuracy 0.366667
# step 7800 , loss : 2.19923
# step 7800 , validation  accuracy 0.478543
# step 7800 , validation loss : 2.13561
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 7900
# step 7900 , training  accuracy 0.666667
# step 7900 , loss : 2.02656
# step 7900 , validation  accuracy 0.487325
# step 7900 , validation loss : 2.13667
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 8000
# step 8000 , training  accuracy 0.5
# step 8000 , loss : 2.13912
# step 8000 , validation  accuracy 0.485828
# step 8000 , validation loss : 2.13002
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 8100
# step 8100 , training  accuracy 0.666667
# step 8100 , loss : 2.07433
# step 8100 , validation  accuracy 0.485529
# step 8100 , validation loss : 2.13004
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 8200
# step 8200 , training  accuracy 0.433333
# step 8200 , loss : 2.14366
# step 8200 , validation  accuracy 0.485429
# step 8200 , validation loss : 2.13266
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 8300
# step 8300 , training  accuracy 0.7
# step 8300 , loss : 2.04683
# step 8300 , validation  accuracy 0.48523
# step 8300 , validation loss : 2.13143
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 8400
# step 8400 , training  accuracy 0.5
# step 8400 , loss : 2.13084
# step 8400 , validation  accuracy 0.493513
# step 8400 , validation loss : 2.12746
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 8500
# step 8500 , training  accuracy 0.633333
# step 8500 , loss : 2.05148
# step 8500 , validation  accuracy 0.497106
# step 8500 , validation loss : 2.12374
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 8600
# step 8600 , training  accuracy 0.666667
# step 8600 , loss : 2.05085
# step 8600 , validation  accuracy 0.490619
# step 8600 , validation loss : 2.1311
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 8700
# step 8700 , training  accuracy 0.533333
# step 8700 , loss : 2.14117
# step 8700 , validation  accuracy 0.483234
# step 8700 , validation loss : 2.13267
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 8800
# step 8800 , training  accuracy 0.666667
# step 8800 , loss : 2.01831
# step 8800 , validation  accuracy 0.491218
# step 8800 , validation loss : 2.1315
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 8900
# step 8900 , training  accuracy 0.5
# step 8900 , loss : 2.19286
# step 8900 , validation  accuracy 0.498403
# step 8900 , validation loss : 2.12796
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 9000
# step 9000 , training  accuracy 0.533333
# step 9000 , loss : 2.06948
# step 9000 , validation  accuracy 0.487126
# step 9000 , validation loss : 2.13091
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 9100
# step 9100 , training  accuracy 0.533333
# step 9100 , loss : 2.07289
# step 9100 , validation  accuracy 0.489022
# step 9100 , validation loss : 2.13162
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 9200
# step 9200 , training  accuracy 0.6
# step 9200 , loss : 2.06353
# step 9200 , validation  accuracy 0.506387
# step 9200 , validation loss : 2.12077
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 9300
# step 9300 , training  accuracy 0.633333
# step 9300 , loss : 2.08296
# step 9300 , validation  accuracy 0.48992
# step 9300 , validation loss : 2.13044
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 9400
# step 9400 , training  accuracy 0.566667
# step 9400 , loss : 2.1416
# step 9400 , validation  accuracy 0.491417
# step 9400 , validation loss : 2.12977
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 9500
# step 9500 , training  accuracy 0.533333
# step 9500 , loss : 2.12252
# step 9500 , validation  accuracy 0.492415
# step 9500 , validation loss : 2.12933
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 9600
# step 9600 , training  accuracy 0.7
# step 9600 , loss : 2.04104
# step 9600 , validation  accuracy 0.498004
# step 9600 , validation loss : 2.12249
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 9700
# step 9700 , training  accuracy 0.366667
# step 9700 , loss : 2.18153
# step 9700 , validation  accuracy 0.488723
# step 9700 , validation loss : 2.13569
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 9800
# step 9800 , training  accuracy 0.733333
# step 9800 , loss : 2.04879
# step 9800 , validation  accuracy 0.476647
# step 9800 , validation loss : 2.13876
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 9900
# step 9900 , training  accuracy 0.466667
# step 9900 , loss : 2.11254
# step 9900 , validation  accuracy 0.500499
# step 9900 , validation loss : 2.12463
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 10000
# step 10000 , training  accuracy 0.566667
# step 10000 , loss : 2.0918
# step 10000 , validation  accuracy 0.500898
# step 10000 , validation loss : 2.12345
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 10100
# step 10100 , training  accuracy 0.666667
# step 10100 , loss : 2.05424
# step 10100 , validation  accuracy 0.499701
# step 10100 , validation loss : 2.12719
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 10200
# step 10200 , training  accuracy 0.533333
# step 10200 , loss : 2.10094
# step 10200 , validation  accuracy 0.480339
# step 10200 , validation loss : 2.13594
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 10300
# step 10300 , training  accuracy 0.466667
# step 10300 , loss : 2.09939
# step 10300 , validation  accuracy 0.496108
# step 10300 , validation loss : 2.12624
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 10400
# step 10400 , training  accuracy 0.466667
# step 10400 , loss : 2.13237
# step 10400 , validation  accuracy 0.503892
# step 10400 , validation loss : 2.12251
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 10500
# step 10500 , training  accuracy 0.633333
# step 10500 , loss : 2.06084
# step 10500 , validation  accuracy 0.500499
# step 10500 , validation loss : 2.12636
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 10600
# ...
# step 27000 , loss : 1.92943
# step 27000 , validation  accuracy 0.518064
# step 27000 , validation loss : 2.13369
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 27100
# step 27100 , training  accuracy 0.566667
# step 27100 , loss : 2.06246
# step 27100 , validation  accuracy 0.522455
# step 27100 , validation loss : 2.12474
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 27200
# step 27200 , training  accuracy 0.733333
# step 27200 , loss : 1.94928
# step 27200 , validation  accuracy 0.511876
# step 27200 , validation loss : 2.12903
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 27300
# step 27300 , training  accuracy 0.833333
# step 27300 , loss : 1.89498
# step 27300 , validation  accuracy 0.528343
# step 27300 , validation loss : 2.12796
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 27400
# step 27400 , training  accuracy 0.766667
# step 27400 , loss : 1.93275
# step 27400 , validation  accuracy 0.529242
# step 27400 , validation loss : 2.12505
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 27500
# step 27500 , training  accuracy 0.833333
# step 27500 , loss : 1.91787
# step 27500 , validation  accuracy 0.527545
# step 27500 , validation loss : 2.12418
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 27600
# step 27600 , training  accuracy 0.766667
# step 27600 , loss : 1.89814
# step 27600 , validation  accuracy 0.521757
# step 27600 , validation loss : 2.13151
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 27700
# step 27700 , training  accuracy 0.666667
# step 27700 , loss : 2.01939
# step 27700 , validation  accuracy 0.52525
# step 27700 , validation loss : 2.1247
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 27800
# step 27800 , training  accuracy 0.9
# step 27800 , loss : 1.84062
# step 27800 , validation  accuracy 0.502196
# step 27800 , validation loss : 2.14433
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 27900
# step 27900 , training  accuracy 0.866667
# step 27900 , loss : 1.90157
# step 27900 , validation  accuracy 0.52984
# step 27900 , validation loss : 2.12644
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 28000
# step 28000 , training  accuracy 0.633333
# step 28000 , loss : 1.99656
# step 28000 , validation  accuracy 0.526447
# step 28000 , validation loss : 2.13699
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 28100
# step 28100 , training  accuracy 0.733333
# step 28100 , loss : 2.00997
# step 28100 , validation  accuracy 0.525549
# step 28100 , validation loss : 2.12999
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 28200
# step 28200 , training  accuracy 0.766667
# step 28200 , loss : 1.96081
# step 28200 , validation  accuracy 0.525749
# step 28200 , validation loss : 2.1279
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 28300
# step 28300 , training  accuracy 0.833333
# step 28300 , loss : 1.87132
# step 28300 , validation  accuracy 0.522056
# step 28300 , validation loss : 2.12753
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 28400
# step 28400 , training  accuracy 0.833333
# step 28400 , loss : 1.87941
# step 28400 , validation  accuracy 0.51477
# step 28400 , validation loss : 2.13195
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 28500
# step 28500 , training  accuracy 0.766667
# step 28500 , loss : 1.90023
# step 28500 , validation  accuracy 0.522156
# step 28500 , validation loss : 2.12973
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 28600
# step 28600 , training  accuracy 0.8
# step 28600 , loss : 1.90799
# step 28600 , validation  accuracy 0.517964
# step 28600 , validation loss : 2.13422
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 28700
# step 28700 , training  accuracy 0.566667
# step 28700 , loss : 2.04724
# step 28700 , validation  accuracy 0.522355
# step 28700 , validation loss : 2.12838
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 28800
# step 28800 , training  accuracy 0.733333
# step 28800 , loss : 1.95413
# step 28800 , validation  accuracy 0.515669
# step 28800 , validation loss : 2.1309
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 28900
# step 28900 , training  accuracy 0.8
# step 28900 , loss : 1.87831
# step 28900 , validation  accuracy 0.516567
# step 28900 , validation loss : 2.13549
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 29000
# step 29000 , training  accuracy 0.833333
# step 29000 , loss : 1.93529
# step 29000 , validation  accuracy 0.525549
# step 29000 , validation loss : 2.12786
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 29100
# step 29100 , training  accuracy 0.766667
# step 29100 , loss : 1.93455
# step 29100 , validation  accuracy 0.521956
# step 29100 , validation loss : 2.13391
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 29200
# step 29200 , training  accuracy 0.633333
# step 29200 , loss : 2.03685
# step 29200 , validation  accuracy 0.521357
# step 29200 , validation loss : 2.12959
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 29300
# step 29300 , training  accuracy 0.6
# step 29300 , loss : 2.05009
# step 29300 , validation  accuracy 0.522655
# step 29300 , validation loss : 2.13503
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 29400
# step 29400 , training  accuracy 0.7
# step 29400 , loss : 1.943
# step 29400 , validation  accuracy 0.526148
# step 29400 , validation loss : 2.1297
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 29500
# step 29500 , training  accuracy 0.633333
# step 29500 , loss : 2.0442
# step 29500 , validation  accuracy 0.513872
# step 29500 , validation loss : 2.13587
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 29600
# step 29600 , training  accuracy 0.766667
# step 29600 , loss : 1.93879
# step 29600 , validation  accuracy 0.530739
# step 29600 , validation loss : 2.12715
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 29700
# step 29700 , training  accuracy 0.7
# step 29700 , loss : 1.93789
# step 29700 , validation  accuracy 0.52515
# step 29700 , validation loss : 2.12908
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 29800
# step 29800 , training  accuracy 0.8
# step 29800 , loss : 1.90654
# step 29800 , validation  accuracy 0.521258
# step 29800 , validation loss : 2.12943
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 29900
# step 29900 , training  accuracy 0.7
# step 29900 , loss : 1.99531
# step 29900 , validation  accuracy 0.525649
# step 29900 , validation loss : 2.12719
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 30000
# step 30000 , training  accuracy 0.733333
# step 30000 , loss : 1.92461
# step 30000 , validation  accuracy 0.518862
# step 30000 , validation loss : 2.14138
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 30100
# step 30100 , training  accuracy 0.766667
# step 30100 , loss : 1.94399
# step 30100 , validation  accuracy 0.53014
# step 30100 , validation loss : 2.13319
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 30200
# step 30200 , training  accuracy 0.866667
# step 30200 , loss : 1.83333
# step 30200 , validation  accuracy 0.517964
# step 30200 , validation loss : 2.13101
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 30300
# step 30300 , training  accuracy 0.6
# step 30300 , loss : 2.02566
# step 30300 , validation  accuracy 0.512575
# step 30300 , validation loss : 2.13466
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 30400
# step 30400 , training  accuracy 0.733333
# step 30400 , loss : 1.9367
# step 30400 , validation  accuracy 0.520858
# step 30400 , validation loss : 2.13295
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)
# validate tensorboard None
# b
# 30500
# step 30500 , training  accuracy 0.8
# step 30500 , loss : 1.96329
# step 30500 , validation  accuracy 0.531138
# step 30500 , validation loss : 2.12485
# validate tensorboard {'merge': <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>, 'writer': <tensorflow.python.training.summary_io.SummaryWriter object at 0x7f3b50161e90>}
# a
# Tensor("accuracy/accuracy/Mean:0", shape=(), dtype=float32, device=/device:GPU:1)

# %%
sess.close()

# %%
tensor_info={};place_info={}
file_locate='./cifar_merge/'
dirname='./result/'

A=CONV_5(x_ , 'gpu:1' , 'CONVx5_1',200,(3,3),[1,1,1,1],'SAME')
B=CONV_5(A , 'gpu:1' , 'CONVx5_2',200,(3,3),[1,1,1,1],'SAME')
"""
B=STEM_B(A , 'gpu:0')
C=STEM_C(B , 'gpu:0')
D=INCEPTION_MODULE_A(C,'gpu:0', 'INCEPTION_MODULE_A_1')
E=INCEPTION_MODULE_A(D,'gpu:0', 'INCEPTION_MODULE_A_2')
F=INCEPTION_MODULE_A(E,'gpu:0', 'INCEPTION_MODULE_A_3')
G=INCEPTION_MODULE_A(F,'gpu:0', 'INCEPTION_MODULE_A_4')
H=INCEPTION_REDUCTION_A(G,'gpu:0' , 'INCEPTION_REDUCTION_A_1')
I=INCEPTION_MODULE_B(H,'gpu:0' , 'INCEPTION_REDUCTION_B_1')
J=INCEPTION_MODULE_B(I,'gpu:0' , 'INCEPTION_REDUCTION_B_2')
K=INCEPTION_MODULE_B(G,'gpu:0' , 'INCEPTION_REDUCTION_B_3')
L=INCEPTION_MODULE_B(G,'gpu:0' , 'INCEPTION_REDUCTION_B_4')
M=INCEPTION_MODULE_B(G,'gpu:0' , 'INCEPTION_REDUCTION_B_5')
"""

flat_=FLAT(B)
y_conv=FC_A(flat_ , n_classes ,'/gpu:1' ,dropout_rate=keep_prob)
cost , train_step ,correct_prediction , accuracy ,softmax = TRAIN_STRUCTURE_A(y_conv , y_ , '/gpu:1')

tensor_info['cost']=cost
tensor_info['train_step']=train_step
tensor_info['correct_prediction']=correct_prediction
tensor_info['accuracy']=accuracy
tensor_info['softmax']=softmax

place_info['x_']=x_
place_info['y_']=y_
place_info['keep_prob']=keep_prob


logdir='./module_conv5x2'
sess=START_SESS()
tensorboard_info=OPEN_TENSORBOARD(sess ,tensor_info ,logdir)
fp=make_logdir(dirname)
BATCH_TRAINING_RANDOM(100000 , 30,file_locate , tensor_info,place_info ,fp ,tensorboard_info)
#BATCH_TRAINING_DIVIDE_RANDOM(100000 , 30,file_locate , tensor_info,place_info ,fp)
